# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import pickle
import math
import datetime as dt
import json
import requests
from tqdm import tqdm

# %%
import geopandas as gpd
import geojson
import h3
import osm2geojson
import shapely
from shapely import wkt
from shapely.geometry import Point, Polygon, LineString
from geopy.distance import geodesic, great_circle

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
import folium
from folium.plugins import MarkerCluster
from folium.plugins import HeatMap

# %%
pd.options.display.max_rows = 300
pd.options.display.max_columns = 300

# %% [markdown]
# # Login to DWH

# %%
from tochka.datalab.datasources import connect_to_dwh

# %%
dwh_login = 'BOCHKAREV_DV'

# %%
dwh_pass = 'r5eN3Y6z'

# %%
dwh_connection = connect_to_dwh(dwh_login, dwh_pass)

# %% [markdown]
# # Region

# %%
# reg = 72 # Тюмень
# reg = 45 # Курган
reg = 50 # Московская

# %% [markdown]
# # EGRUL

# %%
df_inn = pd.read_sql_query(f"""
    SELECT
          inn
        , tax_agency_code
        , begin_date
        , end_date
        , end_code
        , full_address
        , kladr_code
    FROM DATAMART.EGRUL
    where
        SUBSTR(inn, 0, 2) = '{reg}'
    """,
    dwh_connection)
# Out:
# /usr/lib64/python3.6/site-packages/sqlalchemy/dialects/oracle/base.py:1316: SAWarning: Oracle version (19, 0, 0, 0, 0) is known to have a maximum identifier length of 128, rather than the historical default of 30. SQLAlchemy 1.4 will use 128 for this database; please set max_identifier_length=128 in create_engine() in order to test the application with this new length, or set to 30 in order to assure that 30 continues to be used.  In particular, pay close attention to the behavior of database migrations as dynamically generated names may change. See the section 'Max Identifier Lengths' in the SQLAlchemy Oracle dialect documentation for background.
#   % ((self.server_version_info,))

# %%
df_inn.shape

# %%
df_inn.info()

# %%
df_inn.head()

# %%
df_inn.to_csv(f'df_inn_{reg}.csv.gz', index=False, sep=';', compression='gzip')

# %%
df_inn = pd.read_csv(
    f'df_inn_{reg}.csv.gz',
    parse_dates=['begin_date','end_date'],
    dtype={
        'inn':str,
        'tax_agency_code':str,
        'end_code':str,
        'kladr_code':str
    },
    sep=';',
    compression='gzip'
)

# %%
df_inn.shape
# Out:
# (1216616, 7)

# %%
df_inn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216616 entries, 0 to 1216615
# Data columns (total 7 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   inn              1216616 non-null  object
#  1   tax_agency_code  1179424 non-null  object
#  2   begin_date       1216616 non-null  datetime64[ns]
#  3   end_date         815783 non-null   datetime64[ns]
#  4   end_code         815783 non-null   object
#  5   full_address     1080060 non-null  object
#  6   kladr_code       445236 non-null   object
# dtypes: datetime64[ns](2), object(5)
# memory usage: 65.0+ MB

# %%
df_inn.head()
# Out:
#             inn tax_agency_code begin_date end_date end_code  \
# 0    5007115962            5007 2022-06-02      NaT      NaN
# 1    5027306482            5027 2022-06-02      NaT      NaN
# 2  505396196740            5031 2022-06-02      NaT      NaN
# 3  504408634580            5044 2022-06-02      NaT      NaN
# 4  507404399235            7751 2022-06-02      NaT      NaN
#
#                                         full_address kladr_code
# 0  141865, МОСКОВСКАЯ ОБЛАСТЬ, РП. НЕКРАСОВСКИЙ, ...        NaN
# 1  140000, МОСКОВСКАЯ ОБЛАСТЬ, Г. ЛЮБЕРЦЫ, ПРОЕЗД...        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN

# %%
df_inn.groupby(df_inn.inn.map(len)).size()
# Out:
# inn
# 10    486995
# 12    729621
# dtype: int64

# %%
df_inn.groupby(df_inn.kladr_code.apply(lambda x: len(str(x)))).size()
# Out:
# kladr_code
# 3     771380
# 11     62191
# 15    383045
# dtype: int64

# %%
df_inn.groupby([df_inn.inn.map(len), df_inn.full_address.notnull(), df_inn.kladr_code.notnull()]).size()
# Out:
# inn  full_address  kladr_code
# 10   True          False          41759
#                    True          445236
# 12   False         False         136556
#      True          False         593065
# dtype: int64

# %% [markdown]
# # KLADR_Code

# %%
len(df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull())
])
# Out:
# 445236

# %%
df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull()),
    'kladr_code'
].nunique()
# Out:
# 39356

# %%
df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull())
].groupby(df_inn.kladr_code.apply(lambda x: len(str(x)))).size()
# Out:
# kladr_code
# 11     62191
# 15    383045
# dtype: int64

# %%
df_inn['kladr_11'] = df_inn['kladr_code'].str[:11]

# %%
df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull())
].head()
# Out:
#              inn tax_agency_code begin_date   end_date end_code  \
# 1055  5029269902            5029 2022-05-30        NaT      NaN
# 5804  5029271700            5029 2022-08-18        NaT      NaN
# 8602  5052004598            5050 2002-11-29 2016-12-09      201
# 8603  5043013437            5043 2002-12-20        NaT      NaN
# 8604  5045044776            5045 2009-06-19 2015-08-28      407
#
#                                            full_address       kladr_code  \
# 1055  141031, ОБЛАСТЬ МОСКОВСКАЯ, Д БОРОДИНО, Г. МЫТ...      50000044086
# 5804  141008, ОБЛАСТЬ МОСКОВСКАЯ, Г. МЫТИЩИ, УЛ. МИР...  500000440000188
# 8602  141191, ОБЛАСТЬ МОСКОВСКАЯ, ГОРОД ФРЯЗИНО, УЛИ...  500000190000005
# 8603  142207, ОБЛАСТЬ МОСКОВСКАЯ, Г. СЕРПУХОВ, УЛ. Ц...  500000280000276
# 8604  142800, ОБЛАСТЬ МОСКОВСКАЯ, ГОРОД СТУПИНО, УЛИ...  500340010000179
#
#          kladr_11
# 1055  50000044086
# 5804  50000044000
# 8602  50000019000
# 8603  50000028000
# 8604  50034001000

# %%
for i in df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull()),
    'full_address'
][:15]:
    print(i)
# Out:
# 141031, ОБЛАСТЬ МОСКОВСКАЯ, Д БОРОДИНО, Г. МЫТИЩИ, СТР. 26 ЭТАЖ/ПОМЕЩЕНИЕ 1/1
# 141008, ОБЛАСТЬ МОСКОВСКАЯ, Г. МЫТИЩИ, УЛ. МИРА, Д. 30 ПОМЕЩ. XVII
# 141191, ОБЛАСТЬ МОСКОВСКАЯ, ГОРОД ФРЯЗИНО, УЛИЦА ГОРЬКОГО, 12 1, 4
# 142207, ОБЛАСТЬ МОСКОВСКАЯ, Г. СЕРПУХОВ, УЛ. ЦЕНТРАЛЬНАЯ, Д.160 К.8
# 142800, ОБЛАСТЬ МОСКОВСКАЯ, ГОРОД СТУПИНО, УЛИЦА БОЛЬШЕ-ОБРАЗЦОВСКАЯ, 10
# 141220, ОБЛАСТЬ МОСКОВСКАЯ, РАЙОН ПУШКИНСКИЙ, ПОСЕЛОК ЧЕЛЮСКИНСКИЙ, УЛИЦА БОЛЬШАЯ ТАРАСОВСКАЯ, 117
# 141220, ОБЛАСТЬ МОСКОВСКАЯ, Г ПУШКИНО, П ЧЕЛЮСКИНСКИЙ, УЛ. БОЛЬШАЯ ТАРАСОВСКАЯ, Д. 2/112 КВ. 24
# 140400, ОБЛАСТЬ МОСКОВСКАЯ, Г КОЛОМНА, УЛ. МОСКВОРЕЦКАЯ, Д. 14
# 141240, ОБЛАСТЬ МОСКОВСКАЯ, Г ПУШКИНО, УЛ ПИОНЕРСКАЯ (МАМОНТОВКА МКР.), Д. 15
# 142542, ОБЛАСТЬ МОСКОВСКАЯ, Д ВАСЮТИНО, Г. ПАВЛОВСКИЙ ПОСАД, ТЕР. СНТ СТРОЙБАНКОВЕЦ
# 142155, ОБЛАСТЬ МОСКОВСКАЯ, Г. ПОДОЛЬСК, УЛ ВОСТОЧНАЯ (ЛЬВОВСКИЙ МКР.), Д. 7Б СТР. 1, ОФИС 5
# 140032, ОБЛАСТЬ МОСКОВСКАЯ, РАЙОН ЛЮБЕРЕЦКИЙ, ПОСЕЛОК МАЛАХОВКА, УЛИЦА ШОССЕЙНАЯ, 40 -, -
# 443029, ОБЛАСТЬ САМАРСКАЯ, ГОРОД САМАРА, УЛИЦА СОЛНЕЧНАЯ, 53 КОМН.30
# 141231, ОБЛАСТЬ МОСКОВСКАЯ, Г ПУШКИНО, РП ЛЕСНОЙ, УЛ. МИЧУРИНА
# 142403, ОБЛАСТЬ МОСКОВСКАЯ, Г НОГИНСК, УЛ. ТИХАЯ, Д. 1А ПОМЕЩ. 147
# /tmp/ipykernel_19305/2888422273.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   for i in df_inn.loc[

# %%
df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull()),
    'kladr_11'
].nunique()
# Out:
# 10302

# %%
df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull()) &
    (df_inn.kladr_code.str[:2]==f'{reg}'),
    'kladr_11'
].nunique()
# Out:
# 9014

# %%
df_kladr = pd.DataFrame(df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull()) &
    (df_inn.kladr_code.str[:2]==f'{reg}'),
    'kladr_11'
].unique())

# %%
df_kladr.head()
# Out:
#              0
# 0  50000044086
# 1  50000044000
# 2  50000019000
# 3  50000028000
# 4  50034001000

# %%
df_kladr.rename(columns={0:'kladr_11'}, inplace=True)

# %%
df_kladr.head()
# Out:
#       kladr_11
# 0  50000044086
# 1  50000044000
# 2  50000019000
# 3  50000028000
# 4  50034001000

# %%
df_kladr.to_csv(f'df_kladr_{reg}.csv.gz', index=False, compression='gzip')

# %%
df_kladr_upd = pd.read_csv(
    f'df_kladr_{reg}_upd.csv.gz',
    sep=';',
    compression='gzip',
    dtype={'kladr_11':str, 'kladr':str}
)

# %%
df_kladr_upd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9014 entries, 0 to 9013
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   kladr_11   9014 non-null   object
#  1   kladr      9014 non-null   object
#  2   address    8337 non-null   object
#  3   latitude   8335 non-null   float64
#  4   longitude  8335 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 352.2+ KB

# %%
df_kladr_upd.head()
# Out:
#       kladr_11          kladr  \
# 0  50000044086  5000004408600
# 1  50000044000  5000004400000
# 2  50000019000  5000001900000
# 3  50000028000  5000002800000
# 4  50034001000  5003400100000
#
#                                              address   latitude  longitude
# 0  141031, Московская обл, г Мытищи, деревня Боро...  55.925117  37.661419
# 1                   141000, Московская обл, г Мытищи  55.910503  37.736330
# 2                  141190, Московская обл, г Фрязино  55.958973  38.040996
# 3                 142200, Московская обл, г Серпухов  54.922597  37.403340
# 4                  142800, Московская обл, г Ступино  54.886274  38.078228

# %% [markdown]
# # Analysis

# %%
df_inn.groupby([df_inn.inn.map(len), df_inn.full_address.notnull(), df_inn.kladr_code.notnull()]).size()
# Out:
# inn  full_address  kladr_code
# 10   True          False          41759
#                    True          445236
# 12   False         False         136556
#      True          False         593065
# dtype: int64

# %%
df_inn_ul = df_inn.loc[
    (df_inn.inn.map(len)==10) &
    (df_inn.kladr_code.notnull()) &
    (df_inn.kladr_code.str[:2]==f'{reg}')
].copy()

# %%
df_inn_ul.shape
# Out:
# (419162, 8)

# %%
df_inn_ul.head()
# Out:
#              inn tax_agency_code begin_date   end_date end_code  \
# 1055  5029269902            5029 2022-05-30        NaT      NaN
# 5804  5029271700            5029 2022-08-18        NaT      NaN
# 8602  5052004598            5050 2002-11-29 2016-12-09      201
# 8603  5043013437            5043 2002-12-20        NaT      NaN
# 8604  5045044776            5045 2009-06-19 2015-08-28      407
#
#                                            full_address       kladr_code  \
# 1055  141031, ОБЛАСТЬ МОСКОВСКАЯ, Д БОРОДИНО, Г. МЫТ...      50000044086
# 5804  141008, ОБЛАСТЬ МОСКОВСКАЯ, Г. МЫТИЩИ, УЛ. МИР...  500000440000188
# 8602  141191, ОБЛАСТЬ МОСКОВСКАЯ, ГОРОД ФРЯЗИНО, УЛИ...  500000190000005
# 8603  142207, ОБЛАСТЬ МОСКОВСКАЯ, Г. СЕРПУХОВ, УЛ. Ц...  500000280000276
# 8604  142800, ОБЛАСТЬ МОСКОВСКАЯ, ГОРОД СТУПИНО, УЛИ...  500340010000179
#
#          kladr_11
# 1055  50000044086
# 5804  50000044000
# 8602  50000019000
# 8603  50000028000
# 8604  50034001000

# %%
df_inn_ul['count_2020'] = 0
df_inn_ul.loc[
    (df_inn_ul.begin_date.dt.year <= 2020) &
    ((df_inn_ul.end_date.isnull()) | (df_inn_ul.end_date.dt.year >= 2020)),
    'count_2020'
] = 1

# %%
df_inn_ul.groupby('count_2020').size()
# Out:
# count_2020
# 0    233908
# 1    185254
# dtype: int64

# %%
df_inn_ul['count_2021'] = 0
df_inn_ul.loc[
    (df_inn_ul.begin_date.dt.year <= 2021) &
    ((df_inn_ul.end_date.isnull()) | (df_inn_ul.end_date.dt.year >= 2021)),
    'count_2021'
] = 1

# %%
df_inn_ul.groupby('count_2021').size()
# Out:
# count_2021
# 0    257001
# 1    162161
# dtype: int64

# %%
df_inn_ul['begin_2021'] = 0
df_inn_ul.loc[
    (df_inn_ul.begin_date.dt.year == 2021),
    'begin_2021'
] = 1

# %%
df_inn_ul.groupby('begin_2021').size()
# Out:
# begin_2021
# 0    416355
# 1      2807
# dtype: int64

# %%
df_inn_ul['end_2021'] = 0
df_inn_ul.loc[
    (df_inn_ul.end_date.dt.year == 2021),
    'end_2021'
] = 1

# %%
df_inn_ul.groupby('end_2021').size()
# Out:
# end_2021
# 0    401666
# 1     17496
# dtype: int64

# %%
df_inn_ul_grouped = df_inn_ul[
    ['kladr_11', 'count_2020', 'count_2021', 'begin_2021', 'end_2021']
].groupby('kladr_11', as_index=False).sum()

# %%
df_inn_ul_grouped.shape
# Out:
# (9014, 5)

# %%
df_inn_ul_grouped.head()
# Out:
#       kladr_11  count_2020  count_2021  begin_2021  end_2021
# 0  50000000000           4           4           0         1
# 1  50000000002           0           0           0         0
# 2  50000000003           9           9           0         1
# 3  50000000006           0           0           0         0
# 4  50000000008         131         122           5        14

# %%
df_inn_ul_grouped['begin_2021_rel'] = None
df_inn_ul_grouped.loc[
    df_inn_ul_grouped.count_2021 > 0,
    'begin_2021_rel'
] = df_inn_ul_grouped['begin_2021'] / df_inn_ul_grouped['count_2021']

# %%
df_inn_ul_grouped['end_2021_rel'] = None
df_inn_ul_grouped.loc[
    df_inn_ul_grouped.count_2021 > 0,
    'end_2021_rel'
] = df_inn_ul_grouped['end_2021'] / df_inn_ul_grouped['count_2021']

# %%
df_inn_ul_grouped['count_2021_2020_diff'] = df_inn_ul_grouped['count_2021'] - df_inn_ul_grouped['count_2020']

# %%
df_inn_ul_grouped['count_2021_2020_rel'] = None
df_inn_ul_grouped.loc[
    df_inn_ul_grouped.count_2020 > 0,
    'count_2021_2020_rel'
] = df_inn_ul_grouped['count_2021'] / df_inn_ul_grouped['count_2020']

# %%
df_inn_ul_grouped.head()
# Out:
#       kladr_11  count_2020  count_2021  begin_2021  end_2021 begin_2021_rel  \
# 0  50000000000           4           4           0         1            0.0
# 1  50000000002           0           0           0         0           None
# 2  50000000003           9           9           0         1            0.0
# 3  50000000006           0           0           0         0           None
# 4  50000000008         131         122           5        14       0.040984
#
#   end_2021_rel  count_2021_2020_diff count_2021_2020_rel
# 0         0.25                     0                 1.0
# 1         None                     0                None
# 2     0.111111                     0                 1.0
# 3         None                     0                None
# 4     0.114754                    -9            0.931298

# %%
df_inn_ul_grouped.shape
# Out:
# (9014, 9)

# %%
df_inn_ul.kladr_11.nunique()
# Out:
# 9014

# %%
df_kladr_upd.shape
# Out:
# (9014, 5)

# %%
df_kladr_upd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9014 entries, 0 to 9013
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   kladr_11   9014 non-null   object
#  1   kladr      9014 non-null   object
#  2   address    8337 non-null   object
#  3   latitude   8335 non-null   float64
#  4   longitude  8335 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 352.2+ KB

# %%
df_kladr_upd.head()
# Out:
#       kladr_11          kladr  \
# 0  50000044086  5000004408600
# 1  50000044000  5000004400000
# 2  50000019000  5000001900000
# 3  50000028000  5000002800000
# 4  50034001000  5003400100000
#
#                                              address   latitude  longitude
# 0  141031, Московская обл, г Мытищи, деревня Боро...  55.925117  37.661419
# 1                   141000, Московская обл, г Мытищи  55.910503  37.736330
# 2                  141190, Московская обл, г Фрязино  55.958973  38.040996
# 3                 142200, Московская обл, г Серпухов  54.922597  37.403340
# 4                  142800, Московская обл, г Ступино  54.886274  38.078228

# %%
df_kladr_ul = df_kladr_upd.merge(
    df_inn_ul_grouped,
    how='left',
    on='kladr_11'
)

# %%
df_kladr_ul.shape
# Out:
# (9014, 13)

# %%
df_kladr_ul.head().T
# Out:
#                                                                       0  \
# kladr_11                                                    50000044086
# kladr                                                     5000004408600
# address               141031, Московская обл, г Мытищи, деревня Боро...
# latitude                                                      55.925117
# longitude                                                     37.661419
# count_2020                                                           32
# count_2021                                                           24
# begin_2021                                                            0
# end_2021                                                              2
# begin_2021_rel                                                      0.0
# end_2021_rel                                                   0.083333
# count_2021_2020_diff                                                 -8
# count_2021_2020_rel                                                0.75
#
#                                                      1  \
# kladr_11                                   50000044000
# kladr                                    5000004400000
# address               141000, Московская обл, г Мытищи
# latitude                                     55.910503
# longitude                                     37.73633
# count_2020                                        5613
# count_2021                                        4881
# begin_2021                                         128
# end_2021                                           462
# begin_2021_rel                                0.026224
# end_2021_rel                                  0.094653
# count_2021_2020_diff                              -732
# count_2021_2020_rel                           0.869588
#
#                                                       2  \
# kladr_11                                    50000019000
# kladr                                     5000001900000
# address               141190, Московская обл, г Фрязино
# latitude                                      55.958973
# longitude                                     38.040996
# count_2020                                         1082
# count_2021                                          945
# begin_2021                                            9
# end_2021                                            100
# begin_2021_rel                                 0.009524
# end_2021_rel                                    0.10582
# count_2021_2020_diff                               -137
# count_2021_2020_rel                            0.873383
#
#                                                        3  \
# kladr_11                                     50000028000
# kladr                                      5000002800000
# address               142200, Московская обл, г Серпухов
# latitude                                       54.922597
# longitude                                       37.40334
# count_2020                                          2451
# count_2021                                          2219
# begin_2021                                            27
# end_2021                                             215
# begin_2021_rel                                  0.012168
# end_2021_rel                                     0.09689
# count_2021_2020_diff                                -232
# count_2021_2020_rel                             0.905345
#
#                                                       4
# kladr_11                                    50034001000
# kladr                                     5003400100000
# address               142800, Московская обл, г Ступино
# latitude                                      54.886274
# longitude                                     38.078228
# count_2020                                           15
# count_2021                                           11
# begin_2021                                            0
# end_2021                                              1
# begin_2021_rel                                      0.0
# end_2021_rel                                   0.090909
# count_2021_2020_diff                                 -4
# count_2021_2020_rel                            0.733333

# %%
df_kladr_ul[df_kladr_ul.count_2020 > 500].sort_values('count_2021_2020_rel', ascending=True)
# Out:
#         kladr_11          kladr  \
# 77   50000007000  5000000700000
# 205  50000067000  5000006700000
# 29   50000050022  5000005002200
# 78   50000023000  5000002300000
# 574  50000050019  5000005001900
# 37   50019001000  5001900100000
# 17   50000050000  5000005000000
# 200  50000013000  5000001300000
# 156  50047000000  5004700000000
# 16   50000049000  5000004900000
# 52   50000001000  5000000100000
# 201  50000032000  5000003200000
# 119  50000054000  5000005400000
# 436  50009002000  5000900200000
# 275  50000038000  5000003800000
# 76   50000049004  5000004900400
# 101  50000012000  5000001200000
# 49   50000030000  5000003000000
# 611  50000050020  5000005002000
# 25   50000030002  5000003000200
# 55   50000036000  5000003600000
# 41   50000016000  5000001600000
# 124  50000053000  5000005300000
# 1    50000044000  5000004400000
# 2    50000019000  5000001900000
# 104  50000029000  5000002900000
# 214  50000011000  5000001100000
# 85   50000009000  5000000900000
# 192  50048000000  5004800000000
# 26   50041000000  5004100000000
# 91   50020002000  5002000200000
# 146  50046000000  5004600000000
# 83   50000003000  5000000300000
# 343  50000039000  5000003900000
# 10   50000024000  5000002400000
# 56   50000014000  5000001400000
# 18   50000021000  5000002100000
# 144  50000062000  5000006200000
# 3    50000028000  5000002800000
# 700  50000050025  5000005002500
# 109  50000056000  5000005600000
# 66   50044000000  5004400000000
# 73   50000005000  5000000500000
# 127  50042004000  5004200400000
# 38   50000047000  5000004700000
# 23   50000066000  5000006600000
# 87   50042000000  5004200000000
# 190  50045000000  5004500000000
# 86   50000063000  5000006300000
# 79   50000065000  5000006500000
# 13   50043000000  5004300000000
# 163  50001000000  5000100000000
# 8    50050000000  5005000000000
# 39   50050002000  5005000200000
# 7    50051000000  5005100000000
# 69   50050003000  5005000300000
# 59   50000025000  5000002500000
#
#                                                address   latitude  longitude  \
# 77     141280, Московская обл, г Пушкино, г Ивантеевка  55.974177  37.920811
# 205                  141200, Московская обл, г Пушкино  56.010428  37.847155
# 29      140050, Московская обл, г Люберцы, дп Красково  55.658886  37.988460
# 78               140090, Московская обл, г Дзержинский  55.624118  37.844083
# 574     140070, Московская обл, г Люберцы, рп Томилино  55.661399  37.950838
# 37                    141000, Московская обл, г Мытищи  55.910503  37.736330
# 17                   140000, Московская обл, г Люберцы  55.676499  37.898125
# 200                140080, Московская обл, г Лыткарино  55.577851  37.903443
# 156                     141601, Московская обл, г Клин  56.342514  36.724060
# 16               143401, Московская обл, г Красногорск  55.831812  37.329429
# 52                142000, Московская обл, г Домодедово  55.436402  37.766567
# 201               140053, Московская обл, г Котельники  55.659840  37.863199
# 119                  142800, Московская обл, г Ступино  54.886274  38.078228
# 436         143501, Московская обл, г Истра, г Дедовск  55.870424  37.124468
# 275                   142900, Московская обл, г Кашира  54.853371  38.190455
# 76   143430, Московская обл, г Красногорск, рп Наха...  55.848751  37.187782
# 101                    141055, Московская обл, г Лобня  56.032828  37.461460
# 49                     141402, Московская обл, г Химки  55.888755  37.430337
# 611  140060, Московская обл, г Люберцы, рп Октябрьский  55.610977  37.973727
# 25                                                 NaN        NaN        NaN
# 55                  143900, Московская обл, г Балашиха  55.796339  37.938199
# 41                    143960, Московская обл, г Реутов  55.758301  37.861878
# 124                    142300, Московская обл, г Чехов  55.150717  37.453236
# 1                     141000, Московская обл, г Мытищи  55.910503  37.736330
# 2                    141190, Московская обл, г Фрязино  55.958973  38.040996
# 104             141700, Московская обл, г Долгопрудный  55.938561  37.510098
# 214           143090, Московская обл, г Краснознаменск  55.597856  37.039462
# 85                   141060, Московская обл, г Королёв  55.916224  37.854503
# 192             143300, Московская обл, г Наро-Фоминск  55.386185  36.734484
# 26             141300, Московская обл, г Сергиев Посад  56.306355  38.150274
# 91   143360, Московская обл, г Наро-Фоминск, г Апре...  55.527639  37.065104
# 146                    143500, Московская обл, г Истра  55.906136  36.860092
# 83                     141980, Московская обл, г Дубна  56.741709  37.175630
# 343                140300, Московская обл, г Егорьевск  55.383055  39.035842
# 10                  142100, Московская обл, г Подольск  55.438995  37.570344
# 56                  142280, Московская обл, г Протвино  54.870621  37.218316
# 18              144000, Московская обл, г Электросталь  55.784729  38.444651
# 144                  141100, Московская обл, г Щёлково  55.923387  37.978399
# 3                   142200, Московская обл, г Серпухов  54.922597  37.403340
# 700    140030, Московская обл, г Люберцы, рп Малаховка  55.644001  38.007102
# 109                  143200, Московская обл, г Можайск  55.507009  36.024026
# 66               140200, Московская обл, г Воскресенск  55.307086  38.702756
# 73                 140180, Московская обл, г Жуковский  55.599896  38.122336
# 127   143180, Московская обл, г Одинцово, г Звенигород  55.729686  36.855325
# 38          142500, Московская обл, г Павловский Посад  55.780641  38.659655
# 23               143600, Московская обл, г Волоколамск  56.035728  35.958537
# 87                  143000, Московская обл, г Одинцово  55.678971  37.263609
# 190                  141800, Московская обл, г Дмитров  56.347649  37.526642
# 86                 140100, Московская обл, г Раменское  55.549598  38.272961
# 79             141503, Московская обл, г Солнечногорск  56.185102  36.977631
# 13                   142400, Московская обл, г Ногинск  55.868664  38.462228
# 163            142600, Московская обл, г Орехово-Зуево  55.815137  38.986977
# 8                    141200, Московская обл, г Пушкино  56.010428  37.847155
# 39   141290, Московская обл, г Пушкино, г Красноарм...  56.105426  38.140838
# 7                    140400, Московская обл, г Коломна  55.102792  38.753088
# 69     141280, Московская обл, г Пушкино, г Ивантеевка  55.974177  37.920811
# 59                    142700, Московская обл, г Видное  55.551818  37.706254
#
#      count_2020  count_2021  begin_2021  end_2021 begin_2021_rel end_2021_rel  \
# 77          713         415          34       327       0.081928     0.787952
# 205        1215         726          64       595       0.088154     0.819559
# 29          578         449          10        61       0.022272     0.135857
# 78         1406        1103          24       101       0.021759     0.091568
# 574         790         622           9        65       0.014469     0.104502
# 37         3345        2665           0       315            0.0     0.118199
# 17         5397        4340         106       520       0.024424     0.119816
# 200         919         741          18        80       0.024291     0.107962
# 156        2328        1902          25       218       0.013144     0.114616
# 16         6545        5370          98       504        0.01825     0.093855
# 52         3703        3049          70       394       0.022958     0.129223
# 201         895         742          26        57        0.03504     0.076819
# 119        1536        1279          18       119       0.014073     0.093041
# 436         508         426           0        51            0.0     0.119718
# 275         682         573          12        55       0.020942     0.095986
# 76         1120         946          18        87       0.019027     0.091966
# 101        1682        1423          28       216       0.019677     0.151792
# 49         8201        6980         224      1232       0.032092     0.176504
# 611         574         491          16        59       0.032587     0.120163
# 25          729         626           0        90            0.0      0.14377
# 55         7624        6554         160       740       0.024413     0.112908
# 41         1689        1464          36       150        0.02459     0.102459
# 124        1519        1317          26       190       0.019742     0.144267
# 1          5613        4881         128       462       0.026224     0.094653
# 2          1082         945           9       100       0.009524      0.10582
# 104        2908        2540          53       329       0.020866     0.129528
# 214         649         569           6        44       0.010545     0.077329
# 85         5414        4752          90       459       0.018939     0.096591
# 192        1452        1282          26       114       0.020281     0.088924
# 26         3017        2666          40       327       0.015004     0.122656
# 91          526         465           0        49            0.0     0.105376
# 146        1497        1328          15       135       0.011295     0.101657
# 83         2032        1813          30       117       0.016547     0.064534
# 343         906         810           0        72            0.0     0.088889
# 10         7190        6447         110       572       0.017062     0.088723
# 56          715         643           6        48       0.009331      0.07465
# 18         2495        2248          27       228       0.012011     0.101423
# 144        3129        2826          54       292       0.019108     0.103326
# 3          2451        2219          27       215       0.012168      0.09689
# 700         541         490           8        50       0.016327     0.102041
# 109         660         600           6        57           0.01        0.095
# 66         1469        1343          21       143       0.015637     0.106478
# 73         2542        2329          31       295        0.01331     0.126664
# 127         777         712          19        77       0.026685     0.108146
# 38          855         787           4        84       0.005083     0.106734
# 23          536         497           0        51            0.0     0.102616
# 87         4792        4464         108       456       0.024194     0.102151
# 190        2073        1941          45       182       0.023184     0.093766
# 86         2465        2315          42       263       0.018143     0.113607
# 79         1702        1601          20       181       0.012492     0.113054
# 13         2577        2446          32       244       0.013083     0.099755
# 163        1485        1413          19       114       0.013447     0.080679
# 8          2518        2518           0         0            0.0          0.0
# 39          551         551           0         0            0.0          0.0
# 7          2251        2252           1         0       0.000444          0.0
# 69         1480        1481           1         0       0.000675          0.0
# 59         2102        2147          50       171       0.023288     0.079646
#
#      count_2021_2020_diff count_2021_2020_rel
# 77                   -298            0.582048
# 205                  -489            0.597531
# 29                   -129            0.776817
# 78                   -303            0.784495
# 574                  -168            0.787342
# 37                   -680            0.796712
# 17                  -1057             0.80415
# 200                  -178            0.806311
# 156                  -426             0.81701
# 16                  -1175            0.820474
# 52                   -654            0.823386
# 201                  -153             0.82905
# 119                  -257            0.832682
# 436                   -82            0.838583
# 275                  -109            0.840176
# 76                   -174            0.844643
# 101                  -259            0.846017
# 49                  -1221            0.851116
# 611                   -83            0.855401
# 25                   -103            0.858711
# 55                  -1070            0.859654
# 41                   -225            0.866785
# 124                  -202            0.867018
# 1                    -732            0.869588
# 2                    -137            0.873383
# 104                  -368            0.873453
# 214                   -80            0.876733
# 85                   -662            0.877724
# 192                  -170             0.88292
# 26                   -351            0.883659
# 91                    -61             0.88403
# 146                  -169            0.887108
# 83                   -219            0.892224
# 343                   -96             0.89404
# 10                   -743            0.896662
# 56                    -72            0.899301
# 18                   -247            0.901002
# 144                  -303            0.903164
# 3                    -232            0.905345
# 700                   -51             0.90573
# 109                   -60            0.909091
# 66                   -126            0.914227
# 73                   -213            0.916208
# 127                   -65            0.916345
# 38                    -68            0.920468
# 23                    -39            0.927239
# 87                   -328            0.931553
# 190                  -132            0.936324
# 86                   -150            0.939148
# 79                   -101            0.940658
# 13                   -131            0.949166
# 163                   -72            0.951515
# 8                       0                 1.0
# 39                      0                 1.0
# 7                       1            1.000444
# 69                      1            1.000676
# 59                     45            1.021408

# %%
df_kladr_ul.to_csv(f'df_kladr_{reg}_ul.csv.gz', sep=';', index=False, compression='gzip')

# %% [markdown]
# # Nalog
# ### https://www.nalogia.ru/useful/inspektsii/regions/66.php

# %%
df_inn.head()
# Out:
#             inn tax_agency_code begin_date end_date end_code full_address  \
# 0  450108541400            4500 2022-06-02      NaT      NaN          NaN
# 1  451104273046            4500 2022-05-26      NaT      NaN          NaN
# 2  450105604549            5032 2022-05-27      NaT      NaN          NaN
# 3  450126180298            4500 2022-05-27      NaT      NaN          NaN
# 4  451000897378            4500 2022-05-30      NaT      NaN          NaN
#
#   kladr_code kladr_11
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN

# %%
df_inn[df_inn.tax_agency_code.str[:2]==f'{reg}'].groupby('tax_agency_code').size()
# Out:
# tax_agency_code
# 4500    26797
# 4501    46007
# 4502    11296
# 4503       61
# 4504       77
# 4505       76
# 4506     2834
# 4507       73
# 4508     5439
# 4509       34
# 4510     9015
# 4511      525
# 4512     3894
# 4513      230
# 4514      171
# 4515      157
# 4516      600
# 4517      126
# 4518       93
# 4519       55
# 4520      256
# 4521      162
# 4522       48
# 4523       54
# 4524     6654
# 4525       69
# 4526     3181
# dtype: int64

# %%
with open(f'/home/tochka/Documents/Other/Work/Geo/Nalog/nalog_urls_{reg}.pkl', 'rb') as f:
    urls = pickle.load(f)
        
with open(f'/home/tochka/Documents/Other/Work/Geo/Nalog/nalog_addrs_{reg}.pkl', 'rb') as f:
    addrs = pickle.load(f)

# %%
len(urls)
# Out:
# 8

# %%
len(addrs)
# Out:
# 8

# %%
df_nalog = pd.DataFrame(list(zip(urls, addrs)), columns=['url', 'addr'])

# %%
df_nalog
# Out:
#                                                  url  \
# 0  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 1  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 2  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 3  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 4  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 5  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 6  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 7  /useful/inspektsii/html/nalogovaya_inspektsiya...
#
#                                                 addr
# 0  641018, Курганская область, г.Курган, ул.М.Гор...
# 1  641802, Курганская область, г.Шадринск, ул.Орд...
# 2  641730, Курганская область, Далматовский район...
# 3  641910, Курганская область, Каргапольский райо...
# 4  641310, Курганская область, Кетовский район, с...
# 5  641500, Курганская область, Лебяжьевский район...
# 6  641100, Курганская область, Шумихинский район,...
# 7  641200, Курганская область, Юргамышский район,...

# %%
df_nalog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     8 non-null      object
#  1   addr    8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes

# %%
df_nalog['url'][0]
# Out:
# '/useful/inspektsii/html/nalogovaya_inspektsiya_4501.php'

# %%
df_nalog['nalog_code'] = df_nalog['url'].str[-8:-4]

# %%
df_nalog.head()
# Out:
#                                                  url  \
# 0  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 1  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 2  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 3  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 4  /useful/inspektsii/html/nalogovaya_inspektsiya...
#
#                                                 addr nalog_code
# 0  641018, Курганская область, г.Курган, ул.М.Гор...       4501
# 1  641802, Курганская область, г.Шадринск, ул.Орд...       4502
# 2  641730, Курганская область, Далматовский район...       4506
# 3  641910, Курганская область, Каргапольский райо...       4508
# 4  641310, Курганская область, Кетовский район, с...       4510

# %%
df_nalog['addr'][0]
# Out:
# '641018, Курганская область, г.Курган, ул.М.Горького, 132'

# %%
api_key = '97965ebc-e14d-4585-85bf-ad2c2d64cf82'

# %%
url = 'https://geocode-maps.yandex.ru/1.x'

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
coords = []

# %%
for addr in tqdm(df_nalog['addr']):
    try:
        r = requests.get(f'{url}/?apikey={api_key}&geocode={addr}&format=json', verify=False)
        coord = r.json()['response']['GeoObjectCollection']['featureMember'][0]['GeoObject']['Point']['pos']
        coords.append(coord)
    except:
        coords.append(None)
# Out:
# 100%|█████████████████████████████████████████████| 8/8 [00:06<00:00,  1.28it/s]

# %%
coords
# Out:
# ['65.353784 55.43986',
#  '63.606328 56.081552',
#  '62.937155 56.258348',
#  '64.435383 55.952293',
#  '65.329099 55.333799',
#  '66.496208 55.273062',
#  '63.28597 55.228038',
#  '64.455721 55.375398']

# %%
df_nalog['coord'] = coords

# %%
df_nalog.head()
# Out:
#                                                  url  \
# 0  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 1  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 2  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 3  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 4  /useful/inspektsii/html/nalogovaya_inspektsiya...
#
#                                                 addr nalog_code  \
# 0  641018, Курганская область, г.Курган, ул.М.Гор...       4501
# 1  641802, Курганская область, г.Шадринск, ул.Орд...       4502
# 2  641730, Курганская область, Далматовский район...       4506
# 3  641910, Курганская область, Каргапольский райо...       4508
# 4  641310, Курганская область, Кетовский район, с...       4510
#
#                  coord
# 0   65.353784 55.43986
# 1  63.606328 56.081552
# 2  62.937155 56.258348
# 3  64.435383 55.952293
# 4  65.329099 55.333799

# %%
df_nalog['coords'] = df_nalog['coord'].str.split()

# %%
df_nalog.head()
# Out:
#                                                  url  \
# 0  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 1  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 2  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 3  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 4  /useful/inspektsii/html/nalogovaya_inspektsiya...
#
#                                                 addr nalog_code  \
# 0  641018, Курганская область, г.Курган, ул.М.Гор...       4501
# 1  641802, Курганская область, г.Шадринск, ул.Орд...       4502
# 2  641730, Курганская область, Далматовский район...       4506
# 3  641910, Курганская область, Каргапольский райо...       4508
# 4  641310, Курганская область, Кетовский район, с...       4510
#
#                  coord                  coords
# 0   65.353784 55.43986   [65.353784, 55.43986]
# 1  63.606328 56.081552  [63.606328, 56.081552]
# 2  62.937155 56.258348  [62.937155, 56.258348]
# 3  64.435383 55.952293  [64.435383, 55.952293]
# 4  65.329099 55.333799  [65.329099, 55.333799]

# %%
df_nalog['lat'] = df_nalog['coords'].apply(lambda x: x[1])
df_nalog['lon'] = df_nalog['coords'].apply(lambda x: x[0])

# %%
df_nalog.head()
# Out:
#                                                  url  \
# 0  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 1  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 2  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 3  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 4  /useful/inspektsii/html/nalogovaya_inspektsiya...
#
#                                                 addr nalog_code  \
# 0  641018, Курганская область, г.Курган, ул.М.Гор...       4501
# 1  641802, Курганская область, г.Шадринск, ул.Орд...       4502
# 2  641730, Курганская область, Далматовский район...       4506
# 3  641910, Курганская область, Каргапольский райо...       4508
# 4  641310, Курганская область, Кетовский район, с...       4510
#
#                  coord                  coords        lat        lon
# 0   65.353784 55.43986   [65.353784, 55.43986]   55.43986  65.353784
# 1  63.606328 56.081552  [63.606328, 56.081552]  56.081552  63.606328
# 2  62.937155 56.258348  [62.937155, 56.258348]  56.258348  62.937155
# 3  64.435383 55.952293  [64.435383, 55.952293]  55.952293  64.435383
# 4  65.329099 55.333799  [65.329099, 55.333799]  55.333799  65.329099

# %%
with open(f'/home/tochka/Documents/Other/Work/Geo/Nalog/df_nalog_{reg}.pkl', 'wb') as f:
    pickle.dump(df_nalog, f, pickle.HIGHEST_PROTOCOL)

# %%
df_nalog.to_csv(f'/home/tochka/Documents/Other/Work/Geo/Nalog/df_nalog_{reg}.csv', sep=';', index=False)

# %%
map_nalog = folium.Map(location=[58.5, 63], zoom_start=6, width=900, height=700, control_scale=True)

for index, row in df_nalog.iterrows():
    folium.CircleMarker(
        location=(row['lat'], row['lon']),
        radius = 4,
        popup=row['nalog_code'],
        fill_color='red',
        color=None,
        fill_opacity = 1
    ).add_to(map_nalog)

map_nalog
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d571b1662fd4cdaee0e8ef443e6c5d1 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d571b1662fd4cdaee0e8ef443e6c5d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7d571b1662fd4cdaee0e8ef443e6c5d1 = L.map(
#                 &quot;map_7d571b1662fd4cdaee0e8ef443e6c5d1&quot;,
#                 {
#                     center: [58.5, 63.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7d571b1662fd4cdaee0e8ef443e6c5d1);
#
#
#
#
#
#             var tile_layer_43ca85c0414e70e74c857c41b024a5b0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d571b1662fd4cdaee0e8ef443e6c5d1);
#
#
#             var circle_marker_76b2f27211a5889c464048382553a296 = L.circleMarker(
#                 [55.43986, 65.353784],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d571b1662fd4cdaee0e8ef443e6c5d1);
#
#
#         var popup_f909b012a1b0626694879dbb57e028cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8b0b5a4838a7d15d535a3a2d582892d = $(`&lt;div id=&quot;html_e8b0b5a4838a7d15d535a3a2d582892d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4501&lt;/div&gt;`)[0];
#                 popup_f909b012a1b0626694879dbb57e028cc.setContent(html_e8b0b5a4838a7d15d535a3a2d582892d);
#
#
#
#         circle_marker_76b2f27211a5889c464048382553a296.bindPopup(popup_f909b012a1b0626694879dbb57e028cc)
#         ;
#
#
#
#
#             var circle_marker_fd989aee65b5d7c0acf68507ba792135 = L.circleMarker(
#                 [56.081552, 63.606328],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d571b1662fd4cdaee0e8ef443e6c5d1);
#
#
#         var popup_b46e79aa7e2b7e8ec01c1b7f7bfd47c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09252955b539e0bbf730689f56ff9abe = $(`&lt;div id=&quot;html_09252955b539e0bbf730689f56ff9abe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4502&lt;/div&gt;`)[0];
#                 popup_b46e79aa7e2b7e8ec01c1b7f7bfd47c0.setContent(html_09252955b539e0bbf730689f56ff9abe);
#
#
#
#         circle_marker_fd989aee65b5d7c0acf68507ba792135.bindPopup(popup_b46e79aa7e2b7e8ec01c1b7f7bfd47c0)
#         ;
#
#
#
#
#             var circle_marker_dfcd21ec6ca1aaf71500d4dd4fba9e62 = L.circleMarker(
#                 [56.258348, 62.937155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d571b1662fd4cdaee0e8ef443e6c5d1);
#
#
#         var popup_75f61befb0246fa08c221d84bd6e7574 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c931878ea5534197150ce6b909a9d5de = $(`&lt;div id=&quot;html_c931878ea5534197150ce6b909a9d5de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4506&lt;/div&gt;`)[0];
#                 popup_75f61befb0246fa08c221d84bd6e7574.setContent(html_c931878ea5534197150ce6b909a9d5de);
#
#
#
#         circle_marker_dfcd21ec6ca1aaf71500d4dd4fba9e62.bindPopup(popup_75f61befb0246fa08c221d84bd6e7574)
#         ;
#
#
#
#
#             var circle_marker_071079d7777c1baecd5b5df4ee7f431d = L.circleMarker(
#                 [55.952293, 64.435383],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;l

# %%
df_inn_ul.head()
# Out:
#             inn tax_agency_code begin_date   end_date end_code  \
# 674  4501142934            4501 2008-07-25 2015-01-13      304
# 675  4501110570            4501 2004-09-28 2016-07-26      407
# 705  4511001298            4500 2002-12-02 2022-04-07      201
# 712  4501002454            4501 2011-08-03 2011-08-03      407
# 720  4501108700            4501 2004-05-28 2018-11-30      201
#
#                                           full_address       kladr_code  \
# 674  640003, ОБЛАСТЬ КУРГАНСКАЯ, Г. КУРГАН, УЛ. КОЛ...  450000010000187
# 675  640000, ОБЛАСТЬ КУРГАНСКАЯ, Г. КУРГАН, УЛ. ГОГ...  450000010000059
# 705  641431, ОБЛАСТЬ КУРГАНСКАЯ, Р-Н КУРТАМЫШСКИЙ, ...  450100010000090
# 712  640023, ОБЛАСТЬ КУРГАНСКАЯ, П ЗАОЗЕРНЫЙ, Г. КУ...  450000010100002
# 720  640011, ОБЛАСТЬ КУРГАНСКАЯ, ГОРОД КУРГАН, УЛИЦ...  450000010000209
#
#         kladr_11  count_2020  count_2021  begin_2021  end_2021
# 674  45000001000           0           0           0         0
# 675  45000001000           0           0           0         0
# 705  45010001000           1           1           0         0
# 712  45000001010           0           0           0         0
# 720  45000001000           0           0           0         0

# %%
df_kladr_upd.head()
# Out:
#       kladr_11          kladr  \
# 0  45000001000  4500000100000
# 1  45010001000  4501000100000
# 2  45000001010  4500000101000
# 3  45000001023  4500000102300
# 4  45009000007  4500900000700
#
#                                              address   latitude  longitude
# 0                   640002, Курганская обл, г Курган  55.444415  65.316199
# 1  641430, Курганская обл, Куртамышский р-н, г Ку...  54.936930  64.420330
# 2                                                NaN        NaN        NaN
# 3  640016, Курганская обл, г Курган, тер Увал пос...  55.382314  65.382459
# 4  641322, Курганская обл, Кетовский р-н, село Вв...  55.471449  65.087452

# %%
df_nalog.head()
# Out:
#                                                  url  \
# 0  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 1  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 2  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 3  /useful/inspektsii/html/nalogovaya_inspektsiya...
# 4  /useful/inspektsii/html/nalogovaya_inspektsiya...
#
#                                                 addr nalog_code  \
# 0  641018, Курганская область, г.Курган, ул.М.Гор...       4501
# 1  641802, Курганская область, г.Шадринск, ул.Орд...       4502
# 2  641730, Курганская область, Далматовский район...       4506
# 3  641910, Курганская область, Каргапольский райо...       4508
# 4  641310, Курганская область, Кетовский район, с...       4510
#
#                  coord                  coords        lat        lon
# 0   65.353784 55.43986   [65.353784, 55.43986]   55.43986  65.353784
# 1  63.606328 56.081552  [63.606328, 56.081552]  56.081552  63.606328
# 2  62.937155 56.258348  [62.937155, 56.258348]  56.258348  62.937155
# 3  64.435383 55.952293  [64.435383, 55.952293]  55.952293  64.435383
# 4  65.329099 55.333799  [65.329099, 55.333799]  55.333799  65.329099

# %%
df_nalog_zone = df_inn_ul.loc[
    df_inn_ul.tax_agency_code.str[:2]==f'{reg}',
    ['tax_agency_code', 'kladr_11', 'count_2021']
].groupby(['tax_agency_code', 'kladr_11'], as_index=False).count().merge(
    df_kladr_upd[['kladr_11', 'latitude', 'longitude']],
    how='left',
    on='kladr_11'
).merge(
    df_nalog[['nalog_code', 'lat', 'lon']],
    how='left',
    left_on='tax_agency_code',
    right_on='nalog_code'
)

# %%
df_nalog_zone.head(10)
# Out:
#   tax_agency_code     kladr_11  count_2021   latitude  longitude nalog_code  \
# 0            4500  45000001000        5183  55.444415  65.316199        NaN
# 1            4500  45000001002           1  55.379224  65.212425        NaN
# 2            4500  45000001010           2        NaN        NaN        NaN
# 3            4500  45000002000         773  56.087042  63.629747        NaN
# 4            4500  45002000001          29  54.944409  63.580402        NaN
# 5            4500  45002000005           3  54.903516  62.927210        NaN
# 6            4500  45002000009           3  55.040905  63.429180        NaN
# 7            4500  45002000012           4  54.800315  63.242591        NaN
# 8            4500  45002000016           1  54.995447  63.027390        NaN
# 9            4500  45002000017           3  54.930310  63.419550        NaN
#
#    lat  lon
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
# 5  NaN  NaN
# 6  NaN  NaN
# 7  NaN  NaN
# 8  NaN  NaN
# 9  NaN  NaN

# %%
df_nalog_zone.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1917 entries, 0 to 1916
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tax_agency_code  1917 non-null   object
#  1   kladr_11         1917 non-null   object
#  2   count_2021       1917 non-null   int64
#  3   latitude         1878 non-null   float64
#  4   longitude        1878 non-null   float64
#  5   nalog_code       1028 non-null   object
#  6   lat              1028 non-null   object
#  7   lon              1028 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 134.8+ KB

# %%
df_nalog_gr = df_nalog_zone.loc[
    df_nalog_zone.nalog_code.notnull(),
    ['tax_agency_code', 'count_2021', 'lat', 'lon']
].groupby(['tax_agency_code', 'lat', 'lon'], as_index=False).sum()

# %%
df_nalog_gr
# Out:
#   tax_agency_code        lat        lon  count_2021
# 0            4501   55.43986  65.353784       12711
# 1            4502  56.081552  63.606328        1976
# 2            4506  56.258348  62.937155         470
# 3            4508  55.952293  64.435383        1312
# 4            4510  55.333799  65.329099        2175
# 5            4512  55.273062  66.496208        1225
# 6            4524  55.228038   63.28597        1428
# 7            4526  55.375398  64.455721         678

# %%
df_inn_ul[df_inn_ul.tax_agency_code.str[:2]==f'{reg}'].groupby('tax_agency_code').size()
# Out:
# tax_agency_code
# 4500     9061
# 4501    12711
# 4502     1976
# 4503       25
# 4504       46
# 4505       53
# 4506      470
# 4507       36
# 4508     1312
# 4509       29
# 4510     2175
# 4511      130
# 4512     1225
# 4513       59
# 4514       95
# 4515       29
# 4516      187
# 4517       77
# 4518       81
# 4519       35
# 4520      131
# 4521       76
# 4522       40
# 4523       32
# 4524     1428
# 4525       47
# 4526      678
# dtype: int64

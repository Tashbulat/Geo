# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import pickle
import math
import datetime as dt
import json
import requests
from tqdm import tqdm
import os

# %%
import geopandas as gpd
import geojson
import h3
import osmnx as ox
import osm2geojson
import shapely
from shapely import wkt
from shapely.geometry import Point, Polygon, LineString
from geopy.distance import geodesic, great_circle

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
import folium
from folium.plugins import MarkerCluster
from folium.plugins import HeatMap

# %%
pd.options.display.max_rows = 300
pd.options.display.max_columns = 300

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Region

# %%
regions = [
    '50', # Москва
    '23', # Краснодар
    '66', # Екатеринбург
    '61', # Ростов-на-Дону
    '02', # Уфа
    '16', # Казань
    '72', # Тюмень
    '74', # Челябинск
    '52', # Нижний Новгород
    '63', # Самара
    '24', # Красноярск
    '26', # Ставрополь
    '54', # Новосибирск
    '42', # Кемерово
    '59', # Пермь
    '34', # Волгоград
    '64', # Саратов
    '38', # Иркутск
    '22', # Барнаул
    '36', # Воронеж
    '56', # Оренбург
    '55', # Омск
    '25', # Владивосток
    '47', # Санкт-Петербург
    '86', # Ханты-Мансийск
    '31', # Белгород
    '18', # Ижевск
    '71', # Тула
    '33', # Владимир
    '58', # Пенза
    '27', # Хабаровск
    '69', # Тверь
    '43', # Киров
    '76', # Ярославль
    '73', # Ульяновск
    '21', # Чебоксары
    '32', # Брянск
    '35', # Вологда
    '29', # Архангельск
    '48', # Липецк
    '62', # Рязань
    '46', # Курск
    '75', # Чита
    '70', # Томск
    '68', # Тамбов
    '37', # Иваново
    '30', # Астрахань
    '40', # Калуга
    '03', # Улан-Удэ
    '39', # Калининград
    '67', # Смоленск
    '14', # Якутск
    '45', # Курган
    '11', # Сыктывкар
    '28', # Благовещенск
    '13', # Саранск
    '51', # Мурманск
    '57', # Орёл
    '12', # Йошкар-Ола
    '44', # Кострома
    '60', # Псков
    '10', # Петрозаводск
    '53', # Великий Новгород
    '89', # Салехард
    '19', # Абакан
    '65', # Южно-Сахалинск
    '41', # Петропавловск-Камчатский
    '17', # Кызыл
    '08', # Элиста
    '04', # Горно-Алтайск
    '79', # Биробиджан
    '49', # Магадан
    '87', # Анадырь
    # '83', # Нарьян-Мар
]

# %%
len(regions)
# Out:
# 73

# %%
regions_bad = [
    '77',
    '78',
    '05',
    '91',
    '20',
    '07',
    '15',
    '09',
    '06',
    '01',
    '92',
    '83'
]

# %% [markdown]
# # Hexes

# %%
h3_resolution = 5

# %%
path = '/home/tochka/Documents/Other/Work/Geo/EGRUL/'

# %%
hexes = {}
shape = 0

for reg in regions:
    
    try:
        hexes_gdf_reg = gpd.read_parquet(f'{path}/egrul_hexes/hexes_{reg}_ul_3.parquet.gzip')
        hexes_gdf_reg['region'] = reg
        hexes[reg] = hexes_gdf_reg
        shape += hexes_gdf_reg.shape[0]
        print(f'{reg}: OK, shape: {hexes_gdf_reg.shape}')
    
    except:
        print(f'{reg}: ERROR load hexes file')
        continue

print(f'result shape: {shape}')
# Out:
# 50: OK, shape: (191, 23)
# 23: OK, shape: (399, 23)
# 66: OK, shape: (690, 23)
# 61: OK, shape: (406, 23)
# 02: OK, shape: (503, 23)
# 16: OK, shape: (247, 23)
# 72: OK, shape: (551, 23)
# 74: OK, shape: (305, 23)
# 52: OK, shape: (301, 23)
# 63: OK, shape: (200, 23)
# 24: OK, shape: (9259, 23)
# 26: OK, shape: (259, 23)
# 54: OK, shape: (608, 23)
# 42: OK, shape: (344, 23)
# 59: OK, shape: (585, 23)
# 34: OK, shape: (436, 23)
# 64: OK, shape: (377, 23)
# 38: OK, shape: (3112, 23)
# 22: OK, shape: (575, 23)
# 36: OK, shape: (209, 23)
# 56: OK, shape: (430, 23)
# 55: OK, shape: (482, 23)
# 25: OK, shape: (938, 23)
# 47: OK, shape: (452, 23)
# 86: OK, shape: (1978, 23)
# 31: OK, shape: (114, 23)
# 18: OK, shape: (157, 23)
# 71: OK, shape: (110, 23)
# 33: OK, shape: (114, 23)
# 58: OK, shape: (170, 23)
# 27: OK, shape: (3489, 23)
# 69: OK, shape: (370, 23)
# 43: OK, shape: (465, 23)
# 76: OK, shape: (153, 23)
# 73: OK, shape: (136, 23)
# 21: OK, shape: (70, 23)
# 32: OK, shape: (152, 23)
# 35: OK, shape: (609, 23)
# 29: OK, shape: (1481, 23)
# 48: OK, shape: (99, 23)
# 62: OK, shape: (158, 23)
# 46: OK, shape: (123, 23)
# 75: OK, shape: (1883, 23)
# 70: OK, shape: (1123, 23)
# 68: OK, shape: (136, 23)
# 37: OK, shape: (88, 23)
# 30: OK, shape: (217, 23)
# 40: OK, shape: (125, 23)
# 03: OK, shape: (1489, 23)
# 39: OK, shape: (85, 23)
# 67: OK, shape: (219, 23)
# 14: OK, shape: (11213, 23)
# 45: OK, shape: (246, 23)
# 11: OK, shape: (1652, 23)
# 28: OK, shape: (1506, 23)
# 13: OK, shape: (102, 23)
# 51: OK, shape: (880, 23)
# 57: OK, shape: (105, 23)
# 12: OK, shape: (88, 23)
# 44: OK, shape: (239, 23)
# 60: OK, shape: (260, 23)
# 10: OK, shape: (855, 23)
# 53: OK, shape: (253, 23)
# 89: OK, shape: (3113, 23)
# 19: OK, shape: (220, 23)
# 65: OK, shape: (569, 23)
# 41: OK, shape: (2190, 23)
# 17: OK, shape: (628, 23)
# 08: OK, shape: (277, 23)
# 04: OK, shape: (322, 23)
# 79: OK, shape: (164, 23)
# 49: OK, shape: (1811, 23)
# 87: OK, shape: (2251, 23)
# result shape: 66116

# %%
hexes_gdf = gpd.GeoDataFrame()

for r, h in hexes.items():
    hexes_gdf = pd.concat(
        [hexes_gdf, h],
        axis=0,
        join='outer',
        ignore_index=True
    )

# %%
hexes_gdf.shape
# Out:
# (66116, 23)

# %%
hexes_gdf.head()
# Out:
#                                             geometry           hex_id  \
# 0  POLYGON ((35.71650 55.75433, 35.73023 55.84282...  8511ae47fffffff
# 1  POLYGON ((39.51699 55.12472, 39.53917 55.21416...  85118ebbfffffff
# 2  POLYGON ((35.53238 55.36132, 35.40295 55.32229...  85118583fffffff
# 3  POLYGON ((38.36203 56.24641, 38.24364 56.29859...  85118c97fffffff
# 4  POLYGON ((38.24346 55.71194, 38.37996 55.74853...  85118cd7fffffff
#
#    assets_balance  short_borrowed_funds  long_borrowed_funds       revenue  \
# 0    1.916502e+07          6.910000e+05         1.000000e+00  6.368800e+07
# 1    2.949380e+09          3.913802e+08         4.342243e+08  4.922620e+09
# 2    0.000000e+00          0.000000e+00         0.000000e+00  0.000000e+00
# 3    1.571703e+09          3.590204e+07         1.946471e+07  1.060409e+09
# 4    5.838688e+10          1.862619e+09         1.053472e+10  6.773559e+10
#
#    net_profit_loss  count_2020  count_2021  begin_2021  end_2021  \
# 0     6.498900e+04        15.0        16.0         1.0       4.0
# 1     2.222459e+08        81.0        81.0         2.0       3.0
# 2     0.000000e+00         3.0         3.0         0.0       0.0
# 3    -3.015769e+08       157.0       146.0         4.0      14.0
# 4     4.400965e+09      1276.0      1266.0       113.0      93.0
#
#    begin_2021_rel  end_2021_rel  count_2021_2020_rel  \
# 0        0.062500      0.250000             1.066667
# 1        0.024691      0.037037             1.000000
# 2        0.000000      0.000000             1.000000
# 3        0.027397      0.095890             0.929936
# 4        0.089258      0.073460             0.992163
#
#    net_profit_loss_to_revenue_2020  net_profit_loss_to_assets_2020  \
# 0                         0.001020                        0.003391
# 1                         0.045148                        0.075353
# 2                        -3.000000                       -3.000000
# 3                        -0.284397                       -0.191879
# 4                         0.064973                        0.075376
#
#    short_borrowed_funds_to_revenue_2020  long_borrowed_funds_to_revenue_2020  \
# 0                              0.010850                         1.570155e-08
# 1                              0.079506                         8.820999e-02
# 2                             -3.000000                        -3.000000e+00
# 3                              0.033857                         1.835586e-02
# 4                              0.027498                         1.555271e-01
#
#    revenue_to_assets_2020  assets_to_count_2020  \
# 0                3.323139          1.277668e+06
# 1                1.669035          3.641210e+07
# 2               -3.000000          0.000000e+00
# 3                0.674688          1.001085e+07
# 4                1.160117          4.575774e+07
#
#    net_profit_loss_to_count_2020  revenue_to_count_2020 region
# 0                   4.332600e+03           4.245867e+06     50
# 1                   2.743777e+06           6.077309e+07     50
# 2                   0.000000e+00           0.000000e+00     50
# 3                  -1.920872e+06           6.754195e+06     50
# 4                   3.449032e+06           5.308432e+07     50

# %%
hexes_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 66116 entries, 0 to 66115
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   geometry                              66116 non-null  geometry
#  1   hex_id                                66116 non-null  object
#  2   assets_balance                        66116 non-null  float64
#  3   short_borrowed_funds                  66116 non-null  float64
#  4   long_borrowed_funds                   66116 non-null  float64
#  5   revenue                               66116 non-null  float64
#  6   net_profit_loss                       66116 non-null  float64
#  7   count_2020                            66116 non-null  float64
#  8   count_2021                            66116 non-null  float64
#  9   begin_2021                            66116 non-null  float64
#  10  end_2021                              66116 non-null  float64
#  11  begin_2021_rel                        66116 non-null  float64
#  12  end_2021_rel                          66116 non-null  float64
#  13  count_2021_2020_rel                   66116 non-null  float64
#  14  net_profit_loss_to_revenue_2020       66116 non-null  float64
#  15  net_profit_loss_to_assets_2020        66115 non-null  float64
#  16  short_borrowed_funds_to_revenue_2020  66116 non-null  float64
#  17  long_borrowed_funds_to_revenue_2020   66116 non-null  float64
#  18  revenue_to_assets_2020                66115 non-null  float64
#  19  assets_to_count_2020                  66116 non-null  float64
#  20  net_profit_loss_to_count_2020         66116 non-null  float64
#  21  revenue_to_count_2020                 66116 non-null  float64
#  22  region                                66116 non-null  object
# dtypes: float64(20), geometry(1), object(2)
# memory usage: 11.6+ MB

# %%
hexes_gdf[hexes_gdf['revenue_to_assets_2020'].isnull()]
# Out:
#                                                 geometry           hex_id  \
# 19915  POLYGON ((57.37499 51.68984, 57.22418 51.67614...  8521204ffffffff
#
#        assets_balance  short_borrowed_funds  long_borrowed_funds  revenue  \
# 19915         -2000.0                   0.0                  0.0      0.0
#
#        net_profit_loss  count_2020  count_2021  begin_2021  end_2021  \
# 19915        -259000.0         4.0         5.0         1.0       0.0
#
#        begin_2021_rel  end_2021_rel  count_2021_2020_rel  \
# 19915             0.2           0.0                 1.25
#
#        net_profit_loss_to_revenue_2020  net_profit_loss_to_assets_2020  \
# 19915                             -3.0                             NaN
#
#        short_borrowed_funds_to_revenue_2020  \
# 19915                                  -3.0
#
#        long_borrowed_funds_to_revenue_2020  revenue_to_assets_2020  \
# 19915                                 -3.0                     NaN
#
#        assets_to_count_2020  net_profit_loss_to_count_2020  \
# 19915                -500.0                       -64750.0
#
#        revenue_to_count_2020 region
# 19915                    0.0     56

# %%
hexes_gdf[hexes_gdf['assets_balance'] < 0]
# Out:
#                                                 geometry           hex_id  \
# 19915  POLYGON ((57.37499 51.68984, 57.22418 51.67614...  8521204ffffffff
#
#        assets_balance  short_borrowed_funds  long_borrowed_funds  revenue  \
# 19915         -2000.0                   0.0                  0.0      0.0
#
#        net_profit_loss  count_2020  count_2021  begin_2021  end_2021  \
# 19915        -259000.0         4.0         5.0         1.0       0.0
#
#        begin_2021_rel  end_2021_rel  count_2021_2020_rel  \
# 19915             0.2           0.0                 1.25
#
#        net_profit_loss_to_revenue_2020  net_profit_loss_to_assets_2020  \
# 19915                             -3.0                             NaN
#
#        short_borrowed_funds_to_revenue_2020  \
# 19915                                  -3.0
#
#        long_borrowed_funds_to_revenue_2020  revenue_to_assets_2020  \
# 19915                                 -3.0                     NaN
#
#        assets_to_count_2020  net_profit_loss_to_count_2020  \
# 19915                -500.0                       -64750.0
#
#        revenue_to_count_2020 region
# 19915                    0.0     56

# %%
hexes_gdf.loc[
    19915,
    [
        'assets_balance',
        'net_profit_loss_to_assets_2020',
        'revenue_to_assets_2020',
        'assets_to_count_2020',
    ]
] = 0

# %%
feature_columns = [f for f in hexes_gdf.columns if f not in ['geometry','hex_id','region']]
feature_columns
# Out:
# ['assets_balance',
#  'short_borrowed_funds',
#  'long_borrowed_funds',
#  'revenue',
#  'net_profit_loss',
#  'count_2020',
#  'count_2021',
#  'begin_2021',
#  'end_2021',
#  'begin_2021_rel',
#  'end_2021_rel',
#  'count_2021_2020_rel',
#  'net_profit_loss_to_revenue_2020',
#  'net_profit_loss_to_assets_2020',
#  'short_borrowed_funds_to_revenue_2020',
#  'long_borrowed_funds_to_revenue_2020',
#  'revenue_to_assets_2020',
#  'assets_to_count_2020',
#  'net_profit_loss_to_count_2020',
#  'revenue_to_count_2020']

# %%
X = hexes_gdf[feature_columns].copy()

# %% [markdown]
# # KMeans

# %%
# %%time
kmeans = KMeans(
    n_clusters=5,
    random_state=0,
    max_iter=1000
).fit(X)
# Out:
# CPU times: user 11.5 s, sys: 5.46 s, total: 16.9 s
# Wall time: 1.52 s

# %%
kmeans_labels = kmeans.labels_

# %%
hexes_gdf['kmeans_labels'] = kmeans.labels_

# %%
# %%time
silhouette_score(X, kmeans_labels, metric='euclidean')
# Out:
# CPU times: user 2min, sys: 6min 4s, total: 8min 5s
# Wall time: 1min 16s
# 0.9968287740692953

# %%
hexes_gdf.groupby('kmeans_labels').size()
# Out:
# kmeans_labels
# 0    66031
# 1        1
# 2        1
# 3       12
# 4       71
# dtype: int64

# %%
reg = '66'

map_hexes_kmeans = folium.Map(location=[58.5, 63], zoom_start=5, width=900, height=700, control_scale=True)

map_hexes_kmeans.choropleth(
    geo_data = hexes_gdf.loc[hexes_gdf['region']==reg, ['hex_id', 'geometry']].to_json(),
    name = 'choropleth',
    data = hexes_gdf.loc[hexes_gdf['region']==reg, ['hex_id', 'kmeans_labels']],
    key_on = 'feature.properties.hex_id',
    columns = ['hex_id', 'kmeans_labels'],
    fill_color = 'YlGnBu',
    color = "blue",
    line_weight = 1,
    fill_opacity = 0.8,
    line_opacity = 0.2,
    legend_name = 'type',
    highlight = True
)

map_hexes_kmeans
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad680a2cbd4dbfe5886b729d76c4fa69 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad680a2cbd4dbfe5886b729d76c4fa69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ad680a2cbd4dbfe5886b729d76c4fa69 = L.map(
#                 &quot;map_ad680a2cbd4dbfe5886b729d76c4fa69&quot;,
#                 {
#                     center: [58.5, 63.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#
#
#
#             var tile_layer_95d103ed28d8697b27b731298e4c2ef9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#             var choropleth_227a8d64e185c936dbd7031e0494b29e = L.featureGroup(
#                 {}
#             ).addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_styler(feature) {
#             switch(feature.id) {
#                 case &quot;619&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;974&quot;: case &quot;1160&quot;: case &quot;1215&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5dcba922c4448ccc1cd04a11c5bd9495.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5dcba922c4448ccc1cd04a11c5bd9495_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5dcba922c4448ccc1cd04a11c5bd9495 = L.geoJson(null, {
#                 onEachFeature: geo_json_5dcba922c4448ccc1cd04a11c5bd9495_onEachFeature,
#
#                 style: geo_json_5dcba922c4448ccc1cd04a11c5bd9495_styler,
#         });
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_add (data) {
#             geo_json_5dcba922c4448ccc1cd04a11c5bd9495
#                 .addData(data)
#                 .addTo(choropleth_227a8d64e185c936dbd7031e0494b29e);
#         }
#             geo_json_5dcba922c4448ccc1cd04a11c5bd9495_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[63.885768838636714, 57.68140514659854], [63.96741801712475, 57.76497825550983], [63.87166564501032, 57.84254567101787], [63.69403006733051, 57.83638353953081], [63.612831712877934, 57.75269266471177], [63.70881597943329, 57.67528157783615], [63.885768838636714, 57.68140514659854]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;590&quot;, &quot;properties&quot;: {&quot;hex_id&quot;: &quot;8510ce6bfffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[59.87681068566876, 58.28886470748814], [59.80328491743288, 58.20345427523636], [59.90651600558175, 58.129636129572546], [60.083133000270195, 58.141066438389466], [60.15718782009433, 58.22637891375512], [60.054098615251355, 58.300359228425634], [59.87681068566876, 58.28886470748814]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;591&quot;, &quot;properties&quot;: {&quot;hex_id&quot;: &quot;8510c033fffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[60.581007255773805, 58.895368087443565], [60.504731525238775, 58.81061285857745], [60.60841975590877, 58.73657314115767], [60.78822134710956, 58.74712568154418], [60.8650302144417, 58.831777192306774], [60.761506511168506, 58.905980062652304], [60.581007255773805, 58.895368087443565]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;592&quot;, &quot;properties

# %% [markdown]
# # DBScan

# %%
# %%time
dbscan = DBSCAN(
    eps=3,
    min_samples=3,
    metric='euclidean',
    algorithm='brute',
    leaf_size=30,
    n_jobs=-1
).fit(X)

# %%
dbscan_labels = dbscan.labels_

# %%
hexes_gdf['dbscan_labels'] = dbscan.labels_

# %%
# %%time
silhouette_score(X, dbscan_labels, metric='euclidean')
# Out:
# CPU times: user 2min, sys: 6min 4s, total: 8min 5s
# Wall time: 1min 16s
# 0.9968287740692953

# %%
hexes_gdf.groupby('dbscan_labels').size()
# Out:
# kmeans_labels
# 0    66031
# 1        1
# 2        1
# 3       12
# 4       71
# dtype: int64

# %%
reg = '66'

map_hexes_dbscan = folium.Map(location=[58.5, 63], zoom_start=5, width=900, height=700, control_scale=True)

map_hexes_dbscan.choropleth(
    geo_data = hexes_gdf.loc[hexes_gdf['region']==reg, ['hex_id', 'geometry']].to_json(),
    name = 'choropleth',
    data = hexes_gdf.loc[hexes_gdf['region']==reg, ['hex_id', 'dbscan_labels']],
    key_on = 'feature.properties.hex_id',
    columns = ['hex_id', 'dbscan_labels'],
    fill_color = 'YlGnBu',
    color = "blue",
    line_weight = 1,
    fill_opacity = 0.8,
    line_opacity = 0.2,
    legend_name = 'type',
    highlight = True
)

map_hexes_dbscan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad680a2cbd4dbfe5886b729d76c4fa69 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad680a2cbd4dbfe5886b729d76c4fa69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ad680a2cbd4dbfe5886b729d76c4fa69 = L.map(
#                 &quot;map_ad680a2cbd4dbfe5886b729d76c4fa69&quot;,
#                 {
#                     center: [58.5, 63.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#
#
#
#             var tile_layer_95d103ed28d8697b27b731298e4c2ef9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#             var choropleth_227a8d64e185c936dbd7031e0494b29e = L.featureGroup(
#                 {}
#             ).addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_styler(feature) {
#             switch(feature.id) {
#                 case &quot;619&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;974&quot;: case &quot;1160&quot;: case &quot;1215&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5dcba922c4448ccc1cd04a11c5bd9495.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5dcba922c4448ccc1cd04a11c5bd9495_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5dcba922c4448ccc1cd04a11c5bd9495 = L.geoJson(null, {
#                 onEachFeature: geo_json_5dcba922c4448ccc1cd04a11c5bd9495_onEachFeature,
#
#                 style: geo_json_5dcba922c4448ccc1cd04a11c5bd9495_styler,
#         });
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_add (data) {
#             geo_json_5dcba922c4448ccc1cd04a11c5bd9495
#                 .addData(data)
#                 .addTo(choropleth_227a8d64e185c936dbd7031e0494b29e);
#         }
#             geo_json_5dcba922c4448ccc1cd04a11c5bd9495_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[63.885768838636714, 57.68140514659854], [63.96741801712475, 57.76497825550983], [63.87166564501032, 57.84254567101787], [63.69403006733051, 57.83638353953081], [63.612831712877934, 57.75269266471177], [63.70881597943329, 57.67528157783615], [63.885768838636714, 57.68140514659854]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;590&quot;, &quot;properties&quot;: {&quot;hex_id&quot;: &quot;8510ce6bfffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[59.87681068566876, 58.28886470748814], [59.80328491743288, 58.20345427523636], [59.90651600558175, 58.129636129572546], [60.083133000270195, 58.141066438389466], [60.15718782009433, 58.22637891375512], [60.054098615251355, 58.300359228425634], [59.87681068566876, 58.28886470748814]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;591&quot;, &quot;properties&quot;: {&quot;hex_id&quot;: &quot;8510c033fffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[60.581007255773805, 58.895368087443565], [60.504731525238775, 58.81061285857745], [60.60841975590877, 58.73657314115767], [60.78822134710956, 58.74712568154418], [60.8650302144417, 58.831777192306774], [60.761506511168506, 58.905980062652304], [60.581007255773805, 58.895368087443565]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;592&quot;, &quot;properties

# %% [markdown]
# # Agglomerative

# %%
# %%time
agglomerative = AgglomerativeClustering(
    n_clusters=5,
    affinity='euclidean',
    linkage='ward'
).fit(X)

# %%
agglomerative_labels = agglomerative.labels_

# %%
hexes_gdf['agglomerative_labels'] = agglomerative.labels_

# %%
# %%time
silhouette_score(X, agglomerative_labels, metric='euclidean')
# Out:
# CPU times: user 2min, sys: 6min 4s, total: 8min 5s
# Wall time: 1min 16s
# 0.9968287740692953

# %%
hexes_gdf.groupby('agglomerative_labels').size()
# Out:
# kmeans_labels
# 0    66031
# 1        1
# 2        1
# 3       12
# 4       71
# dtype: int64

# %%
reg = '66'

map_hexes_agglomerative = folium.Map(location=[58.5, 63], zoom_start=5, width=900, height=700, control_scale=True)

map_hexes_agglomerative.choropleth(
    geo_data = hexes_gdf.loc[hexes_gdf['region']==reg, ['hex_id', 'geometry']].to_json(),
    name = 'choropleth',
    data = hexes_gdf.loc[hexes_gdf['region']==reg, ['hex_id', 'agglomerative_labels']],
    key_on = 'feature.properties.hex_id',
    columns = ['hex_id', 'agglomerative_labels'],
    fill_color = 'YlGnBu',
    color = "blue",
    line_weight = 1,
    fill_opacity = 0.8,
    line_opacity = 0.2,
    legend_name = 'type',
    highlight = True
)

map_hexes_agglomerative
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad680a2cbd4dbfe5886b729d76c4fa69 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad680a2cbd4dbfe5886b729d76c4fa69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ad680a2cbd4dbfe5886b729d76c4fa69 = L.map(
#                 &quot;map_ad680a2cbd4dbfe5886b729d76c4fa69&quot;,
#                 {
#                     center: [58.5, 63.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#
#
#
#             var tile_layer_95d103ed28d8697b27b731298e4c2ef9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#             var choropleth_227a8d64e185c936dbd7031e0494b29e = L.featureGroup(
#                 {}
#             ).addTo(map_ad680a2cbd4dbfe5886b729d76c4fa69);
#
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_styler(feature) {
#             switch(feature.id) {
#                 case &quot;619&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;974&quot;: case &quot;1160&quot;: case &quot;1215&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5dcba922c4448ccc1cd04a11c5bd9495.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5dcba922c4448ccc1cd04a11c5bd9495_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5dcba922c4448ccc1cd04a11c5bd9495 = L.geoJson(null, {
#                 onEachFeature: geo_json_5dcba922c4448ccc1cd04a11c5bd9495_onEachFeature,
#
#                 style: geo_json_5dcba922c4448ccc1cd04a11c5bd9495_styler,
#         });
#
#         function geo_json_5dcba922c4448ccc1cd04a11c5bd9495_add (data) {
#             geo_json_5dcba922c4448ccc1cd04a11c5bd9495
#                 .addData(data)
#                 .addTo(choropleth_227a8d64e185c936dbd7031e0494b29e);
#         }
#             geo_json_5dcba922c4448ccc1cd04a11c5bd9495_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[63.885768838636714, 57.68140514659854], [63.96741801712475, 57.76497825550983], [63.87166564501032, 57.84254567101787], [63.69403006733051, 57.83638353953081], [63.612831712877934, 57.75269266471177], [63.70881597943329, 57.67528157783615], [63.885768838636714, 57.68140514659854]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;590&quot;, &quot;properties&quot;: {&quot;hex_id&quot;: &quot;8510ce6bfffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[59.87681068566876, 58.28886470748814], [59.80328491743288, 58.20345427523636], [59.90651600558175, 58.129636129572546], [60.083133000270195, 58.141066438389466], [60.15718782009433, 58.22637891375512], [60.054098615251355, 58.300359228425634], [59.87681068566876, 58.28886470748814]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;591&quot;, &quot;properties&quot;: {&quot;hex_id&quot;: &quot;8510c033fffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[60.581007255773805, 58.895368087443565], [60.504731525238775, 58.81061285857745], [60.60841975590877, 58.73657314115767], [60.78822134710956, 58.74712568154418], [60.8650302144417, 58.831777192306774], [60.761506511168506, 58.905980062652304], [60.581007255773805, 58.895368087443565]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;592&quot;, &quot;properties

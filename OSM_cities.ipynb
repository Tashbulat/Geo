# %%
import pandas as pd
import numpy as np
from numpy import inf, mean, median
import math
import datetime
import json
import os
import glob
import pickle
import requests
# import requests_cache
import plotly.graph_objects as go
import plotly.express as px
import folium
from folium.plugins import MarkerCluster, HeatMap
import geopandas as gpd
import osm2geojson
import geojson
from shapely import wkt
from shapely.geometry import Point, Polygon, LineString
from geopy.distance import geodesic

# %%
pd.options.display.max_rows = 100

# %% [markdown]
# # Load Data

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

# %% [markdown]
# ## Regions

# %%
overpass_query_regions = """
[out:json];
area["ISO3166-1"="RU"][admin_level=2];
(
    node["place"="state"](area);
    way["place"="state"](area);
    relation["place"="state"](area);
);
out center;
"""

# %%
response_regions = requests.get(overpass_url, 
                                params={'data': overpass_query_regions})

# %%
osm_regions = response_regions.json()

# %%
osm_regions['elements'][0]
# Out:
# {'type': 'node',
#  'id': 502842538,
#  'lat': 45.0819456,
#  'lon': 134.726645,
#  'tags': {'name': 'Приморский край',
#   'name:be': 'Прыморскі край',
#   'name:da': 'Primorskij kraj',
#   'name:de': 'Region Primorje',
#   'name:en': 'Primorsky Krai',
#   'name:eo': 'Ĉemara Regiono',
#   'name:es': 'Primorie',
#   'name:fr': 'Primorie',
#   'name:he': 'מחוז פרימוריה',
#   'name:hr': 'Primorski kraj',
#   'name:hu': 'Tengermelléki határterület',
#   'name:ja': '沿海地方',
#   'name:ko': '프리모르스키 지방',
#   'name:lt': 'Primorės kraštas',
#   'name:pl': 'Kraj Nadmorski',
#   'name:ru': 'Приморский край',
#   'name:sk': 'Prímorský kraj',
#   'name:tt': 'Диңгез буе крае',
#   'name:uk': 'Приморський край',
#   'name:zh': '滨海边疆区',
#   'official_name:es': 'Krai de Primorie',
#   'official_name:fr': 'Kraï du Primorie',
#   'place': 'state',
#   'ref': 'ПРИ',
#   'ref:en': 'PRI',
#   'wikidata': 'Q4341',
#   'wikipedia': 'ru:Приморский край'}}

# %%
len(osm_regions['elements'])
# Out:
# 85

# %%
with open("osm_regions.json", "w") as f:
    json.dump(data_8, f)

# %%
type_regions = []
lon_regions = []
lat_regions = []
name_regions = []
population_regions = []

for element in osm_regions['elements']:
  
    if element['type'] == 'node':
        
        type_regions.append(element['type'])        
        lon_regions.append(element['lon'])
        lat_regions.append(element['lat'])
        name_regions.append(element['tags']['name'])

        try:
            population_regions.append(element['tags']['population'])
        except Exception:
            population_regions.append(None)
 
    elif 'center' in element:

        type_regions.append(element['type'])        
        lon_regions.append(element['center']['lon'])
        lat_regions.append(element['center']['lat'])
        name_regions.append(element['tags']['name'])

        try:
            population_regions.append(element['population'])
        except Exception:
            population_regions.append(None)

# %%
osm_regions = pd.DataFrame(data={'type':type_regions,'lon':lon_regions,'lat':lat_regions,'name':name_regions,'population':population_regions})

# %%
osm_regions
# Отутствует 'Дагестан'
# 'Республика Бурятия', 'Республика Коми' называются 'Бурятия' и 'Коми'
# Out:
#     type         lon        lat                                      name  \
# 0   node  134.726645  45.081946                           Приморский край
# 1   node  128.437295  52.803237                          Амурская область
# 2   node   82.047532  58.612428                           Томская область
# 3   node   74.341549  67.147163           Ямало-Ненецкий автономный округ
# 4   node   68.641816  61.879343  Ханты-Мансийский автономный округ — Югра
# 5   node   70.365884  58.820649                         Тюменская область
# 6   node   73.509994  56.093526                            Омская область
# 7   node   79.481392  54.972017                     Новосибирская область
# 8   node   87.342861  54.533578                       Кемеровская область
# 9   node   82.693142  52.693224                            Алтайский край
# 10  node   86.857219  50.711410                          Республика Алтай
# 11  node   90.066430  53.439938                        Республика Хакасия
# 12  node   93.858259  51.401715                           Республика Тыва
# 13  node   97.097997  63.323381                         Красноярский край
# 14  node  104.719221  56.637012                         Иркутская область
# 15  node  109.492143  52.718243                                   Бурятия
# 16  node  115.956325  52.248521                        Забайкальский край
# 17  node  129.642371  66.941626                  Республика Саха (Якутия)
# 18  node   40.570525  54.422673                         Рязанская область
# 19  node  132.277566  48.560161              Еврейская автономная область
# 20  node  136.121524  51.631268                          Хабаровский край
# 21  node  143.448533  49.721967                       Сахалинская область
# 22  node  160.038382  57.191488                           Камчатский край
# 23  node  154.014726  63.551503                       Магаданская область
# 24  node  169.490087  66.000647                Чукотский автономный округ
# 25  node   21.148947  54.729304                   Калининградская область
# 26  node   32.516976  58.284383                      Новгородская область
# 27  node   50.891463  53.212881                         Самарская область
# 28  node   33.999915  68.000042                        Мурманская область
# 29  node   61.802155  58.641475                      Свердловская область
# 30  node   56.315955  58.595160                             Пермский край
# 31  node   54.332607  63.988142                                      Коми
# 32  node   33.492027  62.619403                        Республика Карелия
# 33  node   50.476359  55.448217                                 Татарстан
# 34  node   55.978458  54.474755                              Башкортостан
# 35  node   52.695983  57.196117                                  Удмуртия
# 36  node   43.121521  60.039146                       Вологодская область
# 37  node   47.232492  54.146318                       Ульяновская область
# 38  node   47.084943  55.425992                                   Чувашия
# 39  node   54.727665  52.026926                      Оренбургская область
# 40  node   47.881751  56.576750                                  Марий Эл
# 41  node   57.062685  67.678325                 Ненецкий автономный округ
# 42  node   32.392533  60.185330                     Ленинградская область
# 43  node   28.858683  57.535873                         Псковская область
# 44  node   35.174443  57.113447                          Тверская область
# 45  node   64.563268  55.765530                        Курганская область
# 46  node   39.112266  52.693518                          Липецкая область
# 47  node   40.150651  50.980039                       Воронежская область
# 48  node   41.357892  52.901957                        Тамбовская область
# 49  node   38.035393  55.504316                        Московская область
# 50  node   33.003199  45.535917                 Автономна Республіка Крим
# 51  node   40.795794  47.622245                        Ростовская область
# 52  node   44.787918  53.165542                        Пензенская область
# 53  node   44.253327  58.424756                       Костромская область
# 54  node   39.002110  57.778198                       Ярославская область
# 55  node   33.019207  55.034350                        Смоленская область
# 56  node   36.425171  52.839276                         Орловская область
# 57  node   33.415853  52.887332                          Брянская область
# 58  node   44.290358  49.604834                     Волгоградская область
# 59  node   47.608851  47.187819                      Астраханская область
# 60  node   45.327574  46.231302                       Республика Калмыкия
# 61  node   37.583762  50.708012                      Белгородская область
# 62  node   36.485270  51.656845                           Курская область
# 63  node   35.527285  54.438277                         Калужская область
# 64  node   37.369091  53.957070                          Тульская область
# 65  node   40.656163  56.050334                      Владимирская область
# 66  node   44.091159  55.471803                     Нижегородская область
# 67  node   46.863195  51.652056                       Саратовская область
# 68  node   43.440691  44.863258                       Ставропольский край
# 69  node   40.152042  44.693901                                    Адыгея
# 70  node   41.726799  43.736833                        Карачаево-Черкесия
# 71  node   45.698501  43.397615                                     Чечня
# 72  node   44.979682  43.165531                                 Ингушетия
# 73  node   44.263635  42.992071                  Северная Осетия — Алания
# 74  node   43.420481  43.442829                        Кабардино-Балкария
# 75  node   49.407460  57.966559                         Кировская область
# 76  node   61.186585  54.422395                       Челябинская область
# 77  node   41.435214  56.916745                        Ивановская область
# 78  node   30.158655  59.960674                           Санкт-Петербург
# 79  node   37.327330  55.479205                                    Москва
# 80  node   34.740110  45.189003                           Республика Крым
# 81  node   39.026104  45.768401                        Краснодарский край
# 82  node   33.472024  44.554729                               Севастополь
# 83  node   44.466114  54.441983                                  Мордовия
# 84  node   43.122165  63.558969                     Архангельская область
#
#    population
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21     490181
# 22     319864
# 23       None
# 24       None
# 25     937000
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
# 31       None
# 32       None
# 33       None
# 34       None
# 35       None
# 36       None
# 37       None
# 38       None
# 39       None
# 40       None
# 41       None
# 42       None
# 43       None
# 44       None
# 45       None
# 46       None
# 47    2328959
# 48       None
# 49       None
# 50       None
# 51       None
# 52       None
# 53       None
# 54       None
# 55       None
# 56       None
# 57       None
# 58       None
# 59       None
# 60       None
# 61       None
# 62       None
# 63       None
# 64       None
# 65       None
# 66       None
# 67       None
# 68       None
# 69       None
# 70       None
# 71       None
# 72       None
# 73       None
# 74       None
# 75       None
# 76    3466369
# 77       None
# 78       None
# 79       None
# 80       None
# 81       None
# 82     402135
# 83       None
# 84       None

# %%
osm_regions['type'].unique()
# Out:
# array(['node'], dtype=object)

# %%
osm_regions.to_csv('osm_regions.csv', sep=';')

# %% [markdown]
# ## Cities

# %%
directory = './osm_cities'

# %%
regions_to_load = df_regions['name'] + ['Республика Бурятия', 'Республика Коми', 'Дагестан']

# %%
for r in regions_to_load:
    
    files = os.listdir(directory)
    files_json = [f for f in os.listdir(directory) if f.endswith('.json')]
    
    if f'{r}.json' in files_json:
        pass

    else:
        _response = requests.get(overpass_url, 
                            params={'data': 
                                        '''
                                        [out:json][timeout:1500];
                                        area
                                            ["boundary"="administrative"]
                                            ["name"="''' + r + '''"]
                                            ->.a;
                                        (
                                            node["place"~"town|city"](area.a);
                                            way["place"~"town|city"](area.a);
                                            relation["place"~"town|city"](area.a);
                                        );
                                        out center;
                                        '''
                                    })

        try:
            _osm_cities = _response.json()
        except Exception:
            _osm_cities = None

        if _osm_cities:           
            with open(f'{directory}/{r}.json', "w") as f:
                json.dump(_osm_cities, f)

# %% [markdown]
# # Combine Data

# %%
files = os.listdir(directory)

# %%
len(files)
# Out:
# 86

# %%
files_json = [f for f in os.listdir(directory) if f.endswith('.json')]

# %%
len(files_json)
# Out:
# 86

# %%
type_ = []
lon_ = []
lat_ = []
region_ = []
region2_ = []
name_ = []
population_ = []


for f in files_json:
        
    with open(f'./{directory}/{f}', "r") as file_json_i:
        
        data_ = json.load(file_json_i)
        
        for element in data_['elements']:

            if element['type'] == 'node':

                region_.append(f[12:-5])   
                type_.append(element['type'])
                lon_.append(element['lon'])
                lat_.append(element['lat'])

                try:
                    region2_.append(element['tags']['addr:region'])
                except Exception:
                    region2_.append('n/d')

                try:
                    name_.append(element['tags']['name'])
                except Exception:
                    name_.append('n/d')

                try:
                    population_.append(element['tags']['population'])
                except Exception:
                    population_.append('n/d')

            elif 'center' in element:

                region_.append(f[12:-5])               
                type_.append(element['type'])
                lon_.append(element['center']['lon'])
                lat_.append(element['center']['lat'])

                try:
                    region2_.append(element['tags']['addr:region'])
                except Exception:
                    region2_.append('n/d')

                try:
                    name_.append(element['tags']['name'])
                except Exception:
                    name_.append('n/d')

                try:
                    population_.append(element['population'])
                except Exception:
                    population_.append('n/d')

# %%
osm_cities = pd.DataFrame(data={'type':type_,'lon':lon_,'lat':lat_,'region':region_,'region2':region2_,'name':name_,'population':population_})

# %%
osm_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5386 entries, 0 to 5385
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   type        5386 non-null   object
#  1   lon         5386 non-null   float64
#  2   lat         5386 non-null   float64
#  3   region      5386 non-null   object
#  4   region2     5386 non-null   object
#  5   name        5386 non-null   object
#  6   population  5386 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 294.7+ KB

# %%
osm_cities.groupby('region').size()
# Out:
# region
# Автономна Республіка Крим                   142
# Адыгея                                       24
# Алтайский край                              122
# Амурская область                             46
# Архангельская область                        50
# Астраханская область                         25
# Башкортостан                                117
# Белгородская область                         58
# Брянская область                             56
# Владимирская область                         56
# Волгоградская область                        80
# Вологодская область                          54
# Воронежская область                          74
# Дагестан                                     98
# Еврейская автономная область                 14
# Забайкальский край                           62
# Ивановская область                           46
# Ингушетия                                    26
# Иркутская область                            95
# Кабардино-Балкария                           32
# Калининградская область                      48
# Калужская область                            64
# Камчатский край                              12
# Карачаево-Черкесия                           18
# Кемеровская область                          74
# Кировская область                           104
# Костромская область                          50
# Краснодарский край                          194
# Красноярский край                           112
# Курганская область                           51
# Курская область                              58
# Ленинградская область                       124
# Липецкая область                             28
# Магаданская область                          20
# Марий Эл                                     32
# Мордовия                                     38
# Москва                                       18
# Московская область                          254
# Мурманская область                           44
# Ненецкий автономный округ                     6
# Нижегородская область                       128
# Новгородская область                         32
# Новосибирская область                        74
# Омская область                               68
# Оренбургская область                         77
# Орловская область                            45
# Пензенская область                           65
# Пермский край                               104
# Приморский край                              87
# Псковская область                            48
# Республика Алтай                             22
# Республика Бурятия                           58
# Республика Калмыкия                          24
# Республика Карелия                           32
# Республика Коми                              59
# Республика Крым                             142
# Республика Саха (Якутия)                     78
# Республика Тыва                              15
# Республика Хакасия                           30
# Ростовская область                          104
# Рязанская область                            60
# Самарская область                            69
# Санкт-Петербург                              34
# Саратовская область                          74
# Сахалинская область                          38
# Свердловская область                        146
# Севастополь                                   8
# Северная Осетия — Алания                     14
# Смоленская область                           50
# Ставропольский край                          69
# Тамбовская область                           41
# Татарстан                                   101
# Тверская область                             90
# Томская область                              41
# Тульская область                             60
# Тюменская область                            48
# Удмуртия                                     50
# Ульяновская область                          56
# Хабаровский край                             52
# Ханты-Мансийский автономный округ — Югра     82
# Челябинская область                         105
# Чечня                                        70
# Чувашия                                      44
# Чукотский автономный округ                    8
# Ямало-Ненецкий автономный округ              30
# Ярославская область                          28
# dtype: int64

# %%
def f_space(text):
    if pd.isnull(text):
        b = None
    elif text == 'n/d':
        b = None
    else:
        b = text.split()
        b = ''.join(b)
    return b

# %%
osm_cities['population'] = osm_cities['population'].apply(f_space)

# %%
osm_cities['population'] = pd.to_numeric(osm_cities['population'], downcast='float')

# %%
osm_cities.to_csv('osm_cities.csv', sep=';')

# %% [markdown]
# # Prepare Data

# %%
osm_cities = pd.read_csv('osm_cities.csv', sep=';', low_memory=False)

# %%
osm_cities.shape
# Out:
# (5386, 8)

# %%
osm_cities.head()
# Out:
#    Unnamed: 0  type        lon        lat                     region region2  \
# 0           0  node  33.367905  45.190764  Автономна Республіка Крим     n/d
# 1           1  node  34.102486  44.952146  Автономна Республіка Крим     n/d
# 2           2  node  34.409539  44.677112  Автономна Республіка Крим     n/d
# 3           3  node  34.389913  45.709376  Автономна Республіка Крим     n/d
# 4           4  node  33.035764  45.308062  Автономна Республіка Крим     n/d
#
#           name  population
# 0    Евпатория    105719.0
# 1  Симферополь    341799.0
# 2       Алушта     28919.0
# 3      Джанкой     36665.0
# 4       Мирный      4210.0

# %%
len(osm_cities.groupby('region').size())
# Out:
# 86

# %%
osm_cities.groupby('region').size()
# Out:
# region
# Автономна Республіка Крим                   142
# Адыгея                                       24
# Алтайский край                              122
# Амурская область                             46
# Архангельская область                        50
# Астраханская область                         25
# Башкортостан                                117
# Белгородская область                         58
# Брянская область                             56
# Владимирская область                         56
# Волгоградская область                        80
# Вологодская область                          54
# Воронежская область                          74
# Дагестан                                     98
# Еврейская автономная область                 14
# Забайкальский край                           62
# Ивановская область                           46
# Ингушетия                                    26
# Иркутская область                            95
# Кабардино-Балкария                           32
# Калининградская область                      48
# Калужская область                            64
# Камчатский край                              12
# Карачаево-Черкесия                           18
# Кемеровская область                          74
# Кировская область                           104
# Костромская область                          50
# Краснодарский край                          194
# Красноярский край                           112
# Курганская область                           51
# Курская область                              58
# Ленинградская область                       124
# Липецкая область                             28
# Магаданская область                          20
# Марий Эл                                     32
# Мордовия                                     38
# Москва                                       18
# Московская область                          254
# Мурманская область                           44
# Ненецкий автономный округ                     6
# Нижегородская область                       128
# Новгородская область                         32
# Новосибирская область                        74
# Омская область                               68
# Оренбургская область                         77
# Орловская область                            45
# Пензенская область                           65
# Пермский край                               104
# Приморский край                              87
# Псковская область                            48
# Республика Алтай                             22
# Республика Бурятия                           58
# Республика Калмыкия                          24
# Республика Карелия                           32
# Республика Коми                              59
# Республика Крым                             142
# Республика Саха (Якутия)                     78
# Республика Тыва                              15
# Республика Хакасия                           30
# Ростовская область                          104
# Рязанская область                            60
# Самарская область                            69
# Санкт-Петербург                              34
# Саратовская область                          74
# Сахалинская область                          38
# Свердловская область                        146
# Севастополь                                   8
# Северная Осетия — Алания                     14
# Смоленская область                           50
# Ставропольский край                          69
# Тамбовская область                           41
# Татарстан                                   101
# Тверская область                             90
# Томская область                              41
# Тульская область                             60
# Тюменская область                            48
# Удмуртия                                     50
# Ульяновская область                          56
# Хабаровский край                             52
# Ханты-Мансийский автономный округ — Югра     82
# Челябинская область                         105
# Чечня                                        70
# Чувашия                                      44
# Чукотский автономный округ                    8
# Ямало-Ненецкий автономный округ              30
# Ярославская область                          28
# dtype: int64

# %%
osm_cities.loc[osm_cities['name']=='Керчь']
# Out:
#       Unnamed: 0      type        lon        lat                     region  \
# 66            66      node  36.453865  45.353400  Автономна Республіка Крим
# 95            95  relation  36.493756  45.304022  Автономна Республіка Крим
# 3615        3615      node  36.453865  45.353400            Республика Крым
# 3644        3644  relation  36.493756  45.304022            Республика Крым
#
#               region2   name  population
# 66    Республика Крым  Керчь    148932.0
# 95    Республика Крым  Керчь         NaN
# 3615  Республика Крым  Керчь    148932.0
# 3644  Республика Крым  Керчь         NaN

# %%
osm_cities = osm_cities.loc[osm_cities['region']!='Автономна Республіка Крим']

# %%
osm_cities = osm_cities[['lon', 'lat', 'region', 'name', 'population']].groupby(['region', 'name']).mean().reset_index()

# %%
osm_cities.loc[osm_cities['name']=='Керчь']
# Out:
#                region   name       lon        lat  population
# 1751  Республика Крым  Керчь  36.47381  45.328711    148932.0

# %%
osm_cities.loc[osm_cities['name']=='Москва']
# Out:
#                   region    name        lon        lat  population
# 1104              Москва  Москва  37.623230  55.737493  12630289.0
# 1176  Московская область  Москва  37.628965  55.724540         NaN

# %%
osm_cities.loc[osm_cities['name']=='Санкт-Петербург']
# Out:
#                      region             name        lon        lat  population
# 1019  Ленинградская область  Санкт-Петербург  30.305254  59.917442         NaN
# 1993        Санкт-Петербург  Санкт-Петербург  30.310742  59.928087   5381736.0

# %%
osm_cities.drop([1176, 1019], inplace=True)

# %%
map_osm_cities = folium.Map(width=1200, height=700, zoom_start=5, location=[55.75, 37.60])

for index, row in osm_cities.iterrows():
    try:
        radius = int(math.log(float(row['population'])/50000+1)) + 1
    except Exception:
        radius = 1
    folium.CircleMarker(location=tuple(row[['lat', 'lon']]),
                        radius=radius,
                        fill_color='red',
                        color=None,
                        fill_opacity=1,
                        popup=row['name'],
                       ).add_to(map_osm_cities)

# %%
map_osm_cities.save('map_osm_cities.html')

# %%
with open('osm_cities.pickle', 'wb') as _f:
    pickle.dump(osm_cities, _f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('osm_cities.pickle', 'rb') as _f:
    osm_cities = pickle.load(_f)

# %% [markdown]
# # Regions

# %%
data_regions = pd.read_excel('spr_regions.xlsx')

# %%
data_regions.shape
# Out:
# (85, 7)

# %%
data_regions.head()
# Out:
#             Name        Type         Center    Area  Population  Code  \
# 0         Адыгея  республика         Майкоп    7792      449171     1
# 1          Алтай  республика  Горно-Алтайск   92903      213703     4
# 2      Алтайский        край        Барнаул  167996     2384812    22
# 3       Амурская     область   Благовещенск  361913      809873    28
# 4  Архангельская     область    Архангельск  589913     1183323    29
#
#                 FO
# 0            Южный
# 1        Сибирский
# 2        Сибирский
# 3  Дальневосточный
# 4  Северо-Западный

# %%
data_regions['density'] = data_regions['Population'] / data_regions['Area']

# %%
data_regions.rename(columns={'Center':'name'}, inplace=True)

# %%
data_regions = data_regions.merge(osm_cities, left_on='name', right_on='name', how='left')

# %%
data_regions.shape
# Out:
# (87, 12)

# %%
data_regions.rename(columns={'name':'center_name', 'population':'center_population', 'lon':'center_lon', 'lat':'center_lat'}, inplace=True)

# %%
a = data_regions.groupby('center_name').size().reset_index(name='count')
data_regions.loc[data_regions['center_name'].isin(a.loc[a['count']>1, 'center_name'])]
# Out:
#                Name                         Type      center_name    Area  \
# 3          Амурская                      область     Благовещенск  361913
# 4          Амурская                      область     Благовещенск  361913
# 29        Кировская                      область            Киров  120374
# 30        Кировская                      область            Киров  120374
# 38    Ленинградская                      область  Санкт-Петербург   83908
# 43           Москва  город федерального значения           Москва    2511
# 44       Московская                      область           Москва   44379
# 60  Санкт-Петербург  город федерального значения  Санкт-Петербург    1439
#
#     Population  Code               FO      density             region  \
# 3       809873    28  Дальневосточный     2.237756   Амурская область
# 4       809873    28  Дальневосточный     2.237756       Башкортостан
# 29     1304348    43      Приволжский    10.835795  Калужская область
# 30     1304348    43      Приволжский    10.835795  Кировская область
# 38     1775540    47  Северо-Западный    21.160557    Санкт-Петербург
# 43    12197596    77      Центральный  4857.664675             Москва
# 44     7231068    50      Центральный   162.938958             Москва
# 60     5191690    78  Северо-Западный  3607.845726    Санкт-Петербург
#
#     center_lon  center_lat  center_population
# 3   127.544173   50.320583           225091.0
# 4    55.982946   55.038172            35037.0
# 29   34.312939   54.071468            31039.0
# 30   49.619912   58.597838           496986.0
# 38   30.310742   59.928087          5381736.0
# 43   37.623230   55.737493         12630289.0
# 44   37.623230   55.737493         12630289.0
# 60   30.310742   59.928087          5381736.0

# %%
data_regions = data_regions.drop([4, 29]).reset_index(drop=True)

# %%
data_regions
# Out:
#                         Name                         Type  \
# 0                     Адыгея                   республика
# 1                      Алтай                   республика
# 2                  Алтайский                         край
# 3                   Амурская                      область
# 4              Архангельская                      область
# 5               Астраханская                      область
# 6               Башкортостан                   республика
# 7               Белгородская                      область
# 8                   Брянская                      область
# 9                    Бурятия                   республика
# 10              Владимирская                      область
# 11             Волгоградская                      область
# 12               Вологодская                      область
# 13               Воронежская                      область
# 14                  Дагестан                   республика
# 15                 Еврейская           автономная область
# 16             Забайкальский                         край
# 17                Ивановская                      область
# 18                 Ингушетия                   республика
# 19                 Иркутская                      область
# 20      Кабардино-Балкарская                   республика
# 21           Калининградская                      область
# 22                  Калмыкия                   республика
# 23                 Калужская                      область
# 24                Камчатский                         край
# 25      Карачаево-Черкесская                   республика
# 26                   Карелия                   республика
# 27               Кемеровская                      область
# 28                 Кировская                      область
# 29                      Коми                   республика
# 30               Костромская                      область
# 31             Краснодарский                         край
# 32              Красноярский                         край
# 33                      Крым                   республика
# 34                Курганская                      область
# 35                   Курская                      область
# 36             Ленинградская                      область
# 37                  Липецкая                      область
# 38               Магаданская                      область
# 39                  Марий Эл                   республика
# 40                  Мордовия                   республика
# 41                    Москва  город федерального значения
# 42                Московская                      область
# 43                Мурманская                      область
# 44                  Ненецкий             автономный округ
# 45             Нижегородская                      область
# 46              Новгородская                      область
# 47             Новосибирская                      область
# 48                    Омская                      область
# 49              Оренбургская                      область
# 50                 Орловская                      область
# 51                Пензенская                      область
# 52                  Пермский                         край
# 53                Приморский                         край
# 54                 Псковская                      область
# 55                Ростовская                      область
# 56                 Рязанская                      область
# 57                 Самарская                      область
# 58           Санкт-Петербург  город федерального значения
# 59               Саратовская                      область
# 60             Саха (Якутия)                   республика
# 61               Сахалинская                      область
# 62              Свердловская                      область
# 63               Севастополь  город федерального значения
# 64  Северная Осетия - Алания                   республика
# 65                Смоленская                      область
# 66            Ставропольский                         край
# 67                Тамбовская                      область
# 68                 Татарстан                   республика
# 69                  Тверская                      область
# 70                   Томская                      область
# 71                  Тульская                      область
# 72                      Тыва                   республика
# 73                 Тюменская                      область
# 74                Удмуртская                   республика
# 75               Ульяновская                      область
# 76               Хабаровский                         край
# 77                   Хакасия                   республика
# 78   Ханты-Мансийский - Югра             автономный округ
# 79               Челябинская                      область
# 80                 Чеченская                   республика
# 81                 Чувашская                   республика
# 82                 Чукотский             автономный округ
# 83            Ямало-Ненецкий             автономный округ
# 84               Ярославская                      область
#
#                  center_name     Area  Population  Code                 FO  \
# 0                     Майкоп     7792      449171     1              Южный
# 1              Горно-Алтайск    92903      213703     4          Сибирский
# 2                    Барнаул   167996     2384812    22          Сибирский
# 3               Благовещенск   361913      809873    28    Дальневосточный
# 4                Архангельск   589913     1183323    29    Северо-Западный
# 5                  Астрахань    49024     1021287    30              Южный
# 6                        Уфа   142947     4071987     2        Приволжский
# 7                   Белгород    27134     1547936    31        Центральный
# 8                     Брянск    34857     1232940    32        Центральный
# 9                   Улан-Удэ   351334      978495     3    Дальневосточный
# 10                  Владимир    29084     1405613    33        Центральный
# 11                 Волгоград   112877     2557397    34              Южный
# 12                   Вологда   144527     1191010    35    Северо-Западный
# 13                   Воронеж    52216     2331147    36        Центральный
# 14                 Махачкала    50270     2990371     5  Северо-Кавказский
# 15                Биробиджан    36266      168368    79    Дальневосточный
# 16                      Чита   431892     1087452    75    Дальневосточный
# 17                   Иваново    21437     1036909    37        Центральный
# 18                     Магас     3628      463893     6  Северо-Кавказский
# 19                   Иркутск   774846     2414913    38          Сибирский
# 20                   Нальчик    12470      860709     7  Северо-Кавказский
# 21               Калининград    15125      968944    39    Северо-Западный
# 22                    Элиста    74731      280564     8              Южный
# 23                    Калуга    29777     1010486    40        Центральный
# 24  Петропавловск-Камчатский   464275      317269    41    Дальневосточный
# 25                  Черкесск    14277      469060     9  Северо-Кавказский
# 26              Петрозаводск   180520      632533    10    Северо-Западный
# 27                  Кемерово    95725     2724990    42          Сибирский
# 28                     Киров   120374     1304348    43        Приволжский
# 29                 Сыктывкар   416774      864424    11    Северо-Западный
# 30                  Кострома    60211      654390    44        Центральный
# 31                 Краснодар    75485     5453329    23              Южный
# 32                Красноярск  2366797     2858773    24          Сибирский
# 33               Симферополь    26081     1895915    91              Южный
# 34                    Курган    71488      869814    45          Уральский
# 35                     Курск    29997     1117378    46        Центральный
# 36           Санкт-Петербург    83908     1775540    47    Северо-Западный
# 37                    Липецк    24047     1157865    48        Центральный
# 38                   Магадан   462464      148071    49    Дальневосточный
# 39                Йошкар-Ола    23375      687435    12        Приволжский
# 40                   Саранск    26128      808888    13        Приволжский
# 41                    Москва     2511    12197596    77        Центральный
# 42                    Москва    44379     7231068    50        Центральный
# 43                  Мурманск   144902      766281    51    Северо-Западный
# 44                Нарьян-Мар   176810       43373    83    Северо-Западный
# 45           Нижний Новгород    76624     3270203    52        Приволжский
# 46          Великий Новгород    54501      618703    53    Северо-Западный
# 47               Новосибирск   177756     2746822    54          Сибирский
# 48                      Омск   141140     1978183    55          Сибирский
# 49                  Оренбург   123702     2001110    56        Приволжский
# 50                      Орёл    24652      765231    57        Центральный
# 51                     Пенза    43352     1355618    58        Приволжский
# 52                     Пермь   160236     2637032    59        Приволжский
# 53               Владивосток   164673     1933308    25    Дальневосточный
# 54                     Псков    55399      651108    60    Северо-Западный
# 55            Ростов-на-Дону   100967     4242080    61              Южный
# 56                    Рязань    39605     1135438    62        Центральный
# 57                    Самара    53565     3212676    63        Приволжский
# 58           Санкт-Петербург     1439     5191690    78    Северо-Западный
# 59                   Саратов   101240     2493024    64        Приволжский
# 60                    Якутск  3083523      956896    14    Дальневосточный
# 61            Южно-Сахалинск    87101      488391    65    Дальневосточный
# 62              Екатеринбург   194307     4327472    66          Уральский
# 63               Севастополь     1080      398973    92              Южный
# 64               Владикавказ     7987      705270    15  Северо-Кавказский
# 65                  Смоленск    49779      964791    67        Центральный
# 66                Ставрополь    66160     2799473    26  Северо-Кавказский
# 67                    Тамбов    34462     1062421    68        Центральный
# 68                    Казань    67847     3855037    16        Приволжский
# 69                     Тверь    84201     1315071    69        Центральный
# 70                     Томск   314391     1074453    70          Сибирский
# 71                      Тула    25679     1513570    71        Центральный
# 72                     Кызыл   168604      313777    17          Сибирский
# 73                    Тюмень  1464173     3581293    72          Уральский
# 74                    Ижевск    42061     1517472    18        Приволжский
# 75                 Ульяновск    37181     1262549    73        Приволжский
# 76                 Хабаровск   787633     1338305    27    Дальневосточный
# 77                    Абакан    61569      535796    19          Сибирский
# 78            Ханты-Мансийск   534801     1612076    86          Уральский
# 79                 Челябинск    88529     3497274    74          Уральский
# 80                   Грозный    15647     1370268    20  Северо-Кавказский
# 81                 Чебоксары    18343     1238071    21        Приволжский
# 82                   Анадырь   721481       50540    87    Дальневосточный
# 83                  Салехард   769250      539985    89          Уральский
# 84                 Ярославль    36177     1271629    76        Центральный
#
#         density                                    region  center_lon  \
# 0     57.645149                                    Адыгея   40.104261
# 1      2.300281                          Республика Алтай   85.968646
# 2     14.195648                            Алтайский край   83.749388
# 3      2.237756                          Амурская область  127.544173
# 4      2.005928                     Архангельская область   40.548922
# 5     20.832388                      Астраханская область   48.034561
# 6     28.485991                              Башкортостан   55.993042
# 7     57.047837                      Белгородская область   36.585442
# 8     35.371374                          Брянская область   34.350404
# 9      2.785085                        Республика Бурятия  107.633582
# 10    48.329425                      Владимирская область   40.410532
# 11    22.656493                     Волгоградская область   44.457531
# 12     8.240744                       Вологодская область   39.885706
# 13    44.644304                       Воронежская область   39.268513
# 14    59.486195                                  Дагестан   47.486925
# 15     4.642585              Еврейская автономная область  132.929310
# 16     2.517879                        Забайкальский край  113.507762
# 17    48.370061                        Ивановская область   40.985498
# 18   127.864664                                 Ингушетия   44.811613
# 19     3.116636                         Иркутская область  104.267539
# 20    69.022374                        Кабардино-Балкария   43.606571
# 21    64.062413                   Калининградская область   20.491354
# 22     3.754319                       Республика Калмыкия   44.269381
# 23    33.935118                         Калужская область   36.227944
# 24     0.683364                           Камчатский край  158.700447
# 25    32.854241                        Карачаево-Черкесия   42.053736
# 26     3.503950                        Республика Карелия   34.403248
# 27    28.466858                       Кемеровская область   86.094075
# 28    10.835795                         Кировская область   49.619912
# 29     2.074083                           Республика Коми   50.804080
# 30    10.868280                       Костромская область   40.914048
# 31    72.243876                        Краснодарский край   38.986224
# 32     1.207866                         Красноярский край   92.885181
# 33    72.693340                           Республика Крым   34.108203
# 34    12.167273                        Курганская область   65.358621
# 35    37.249658                           Курская область   36.180843
# 36    21.160557                           Санкт-Петербург   30.310742
# 37    48.150081                          Липецкая область   39.605271
# 38     0.320178                       Магаданская область  150.809352
# 39    29.408984                                  Марий Эл   47.931730
# 40    30.958665                                  Мордовия   45.177034
# 41  4857.664675                                    Москва   37.623230
# 42   162.938958                                    Москва   37.623230
# 43     5.288271                        Мурманская область   33.094238
# 44     0.245309                 Ненецкий автономный округ   53.017756
# 45    42.678573                     Нижегородская область   43.961504
# 46    11.352140                      Новгородская область   31.293512
# 47    15.452767                     Новосибирская область   82.939565
# 48    14.015750                            Омская область   73.375132
# 49    16.176861                      Оренбургская область   55.130848
# 50    31.041335                         Орловская область   36.082888
# 51    31.270022                        Пензенская область   45.015147
# 52    16.457176                             Пермский край   56.238324
# 53    11.740285                           Приморский край  131.962360
# 54    11.753064                         Псковская область   28.346708
# 55    42.014520                        Ростовская область   39.669740
# 56    28.669057                         Рязанская область   39.730343
# 57    59.977149                         Самарская область   50.091143
# 58  3607.845726                           Санкт-Петербург   30.310742
# 59    24.624891                       Саратовская область   46.021099
# 60     0.310326                  Республика Саха (Якутия)  129.713566
# 61     5.607180                       Сахалинская область  142.746529
# 62    22.271313                      Свердловская область   60.614827
# 63   369.419444                               Севастополь   33.508117
# 64    88.302241                  Северная Осетия — Алания   44.677707
# 65    19.381486                        Смоленская область   32.022536
# 66    42.313679                       Ставропольский край   41.965890
# 67    30.828768                        Тамбовская область   41.428089
# 68    56.819565                                 Татарстан   49.112571
# 69    15.618235                          Тверская область   35.907820
# 70     3.417569                           Томская область   84.970517
# 71    58.941937                          Тульская область   37.618069
# 72     1.861029                           Республика Тыва   94.443033
# 73     2.445949                         Тюменская область   65.541354
# 74    36.077887                                  Удмуртия   53.204193
# 75    33.956833                       Ульяновская область   48.426107
# 76     1.699148                          Хабаровский край  135.068078
# 77     8.702366                        Республика Хакасия   91.434757
# 78     3.014347  Ханты-Мансийский автономный округ — Югра   69.046762
# 79    39.504275                       Челябинская область   61.385077
# 80    87.573848                                     Чечня   45.658680
# 81    67.495557                                   Чувашия   47.253359
# 82     0.070050                Чукотский автономный округ  177.501829
# 83     0.701963           Ямало-Ненецкий автономный округ   66.616353
# 84    35.150206                       Ярославская область   39.880260
#
#     center_lat  center_population
# 0    44.605519           144055.0
# 1    51.944865            63845.0
# 2    53.340879           632723.0
# 3    50.320583           225091.0
# 4    64.564142           350982.0
# 5    46.357556           532699.0
# 6    54.728227          1110976.0
# 7    50.590793           384425.0
# 8    53.260919           406553.0
# 9    51.850729           431922.0
# 10   56.125405           356168.0
# 11   48.678127          1013468.0
# 12   59.222924           311166.0
# 13   51.677170          1023570.0
# 14   43.001387           587876.0
# 15   48.785440            73623.0
# 16   52.036434           347088.0
# 17   57.003519           409285.0
# 18   43.169262             6880.0
# 19   52.302370           623736.0
# 20   43.483236           239040.0
# 21   54.707853           453461.0
# 22   46.309227           104005.0
# 23   54.523311           342936.0
# 24   53.012931           181181.0
# 25   44.226918           123128.0
# 26   61.788226           280170.0
# 27   55.377936           558662.0
# 28   58.597838           496986.0
# 29   61.705358           243536.0
# 30   57.782069           277796.0
# 31   45.047522          1405000.0
# 32   56.015957          1095286.0
# 33   44.949842           341799.0
# 34   55.433221           312364.0
# 35   51.733270           443212.0
# 36   59.928087          5381736.0
# 37   52.603626           510152.0
# 38   59.584170            92782.0
# 39   56.640039           263190.0
# 40   54.194329           302285.0
# 41   55.737493         12630289.0
# 42   55.737493         12630289.0
# 43   68.972069           292465.0
# 44   67.637940            23939.0
# 45   56.311694          1252236.0
# 46   58.540773           224297.0
# 47   54.998039          1625600.0
# 48   55.058339          1164815.0
# 49   51.779133           564443.0
# 50   52.968292           319550.0
# 51   53.197021           523726.0
# 52   58.019277          1055397.0
# 53   43.144412           604901.0
# 54   57.814489           210116.0
# 55   47.241220          1114806.0
# 56   54.649923           538962.0
# 57   53.259918          1156644.0
# 58   59.928087          5381736.0
# 59   51.534441           842097.0
# 60   62.037467           311760.0
# 61   46.957273           198973.0
# 62   56.830374          1468833.0
# 63   44.611320           416283.0
# 64   43.024852           308190.0
# 65   54.780187           330049.0
# 66   45.041948           425853.0
# 67   52.736441           293661.0
# 68   55.776602          1251969.0
# 69   56.859184           420850.0
# 70   56.486973           576624.0
# 71   54.186848           479105.0
# 72   51.700151           117904.0
# 73   57.146439           744554.0
# 74   56.863569           646277.0
# 75   54.309284           619492.0
# 76   48.473097           618150.0
# 77   53.700678           186201.0
# 78   61.004233           101466.0
# 79   55.157857          1200719.0
# 80   43.313224           283659.0
# 81   56.117377           473895.0
# 82   64.729882            15604.0
# 83   66.540844            48313.0
# 84   57.638161           603961.0

# %%
with open('data_regions.pickle', 'wb') as _f:
    pickle.dump(data_regions, _f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('data_regions.pickle', 'rb') as _f:
    data_regions = pickle.load(_f)

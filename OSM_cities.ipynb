# %%
import json
import os

import requests
import requests_cache

import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 100

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

# %%
overpass_query_regions = """
[out:json];
area["ISO3166-1"="RU"][admin_level=2];
(
    node["place"="state"](area);
    way["place"="state"](area);
    relation["place"="state"](area);
);
out center;
"""

# %%
response_regions = requests.get(overpass_url, 
                                params={'data': overpass_query_regions})

# %%
data_regions = response_regions.json()

# %%
data_regions
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.56.8 7d656e78',
#  'osm3s': {'timestamp_osm_base': '2021-02-08T16:20:03Z',
#   'timestamp_areas_base': '2021-02-08T15:28:02Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 502842538,
#    'lat': 45.0819456,
#    'lon': 134.726645,
#    'tags': {'name': 'Приморский край',
#     'name:be': 'Прыморскі край',
#     'name:da': 'Primorskij kraj',
#     'name:de': 'Region Primorje',
#     'name:en': 'Primorsky Krai',
#     'name:eo': 'Ĉemara Regiono',
#     'name:es': 'Primorie',
#     'name:fr': 'Primorie',
#     'name:he': 'מחוז פרימוריה',
#     'name:hr': 'Primorski kraj',
#     'name:hu': 'Tengermelléki határterület',
#     'name:ja': '沿海地方',
#     'name:ko': '프리모르스키 지방',
#     'name:lt': 'Primorės kraštas',
#     'name:pl': 'Kraj Nadmorski',
#     'name:ru': 'Приморский край',
#     'name:sk': 'Prímorský kraj',
#     'name:tt': 'Диңгез буе крае',
#     'name:uk': 'Приморський край',
#     'name:zh': '滨海边疆区',
#     'official_name:es': 'Krai de Primorie',
#     'official_name:fr': 'Kraï du Primorie',
#     'place': 'state',
#     'ref': 'ПРИ',
#     'ref:en': 'PRI',
#     'wikidata': 'Q4341',
#     'wikipedia': 'ru:Приморский край'}},
#   {'type': 'node',
#    'id': 502842672,
#    'lat': 52.8032368,
#    'lon': 128.437295,
#    'tags': {'name': 'Амурская область',
#     'name:be': 'Амурская вобласць',
#     'name:da': 'Amur oblast',
#     'name:de': 'Oblast Amur',
#     'name:en': 'Amur Oblast',
#     'name:eo': 'Amura Provinco',
#     'name:es': 'Óblast de Amur',
#     'name:fr': "Oblast d'Amour",
#     'name:he': 'מחוז אמור',
#     'name:hr': 'Amurska oblast',
#     'name:hu': 'Amuri terület',
#     'name:ja': 'アムール州',
#     'name:lt': 'Amūro sritis',
#     'name:pl': 'Obwód amurski',
#     'name:ru': 'Амурская область',
#     'name:sk': 'Amurská oblasť',
#     'name:uk': 'Амурська область',
#     'place': 'state',
#     'ref': 'АМУ',
#     'ref:en': 'AMU',
#     'wikidata': 'Q6886',
#     'wikipedia': 'ru:Амурская область'}},
#   {'type': 'node',
#    'id': 502842918,
#    'lat': 58.6124279,
#    'lon': 82.0475315,
#    'tags': {'is_in:country': 'Россия',
#     'name': 'Томская область',
#     'name:ar': 'تومسك أوبلاست',
#     'name:az': 'Tomsk vilayəti',
#     'name:be': 'Томская вобласць',
#     'name:bg': 'Томска област',
#     'name:ca': 'Província de Tomsk',
#     'name:cs': 'Tomská oblast',
#     'name:cv': 'Томск облаҫӗ',
#     'name:de': 'Oblast Tomsk',
#     'name:el': 'Περιφέρεια Τομσκ',
#     'name:en': 'Tomsk Oblast',
#     'name:eo': 'Tomska Provinco',
#     'name:es': 'Óblast de Tomsk',
#     'name:et': 'Tomski oblast',
#     'name:fa': 'استان تومسک',
#     'name:fi': 'Tomskin alue',
#     'name:fr': 'Oblast de Tomsk',
#     'name:ga': 'Cúige Thomsk',
#     'name:he': 'מחוז טומסק',
#     'name:hr': 'Tomska oblast',
#     'name:hu': 'Tomszki terület',
#     'name:it': "Oblast' di Tomsk",
#     'name:ja': 'トムスク州',
#     'name:ka': 'ტომსკის ოლქი',
#     'name:ko': '톰스크 주',
#     'name:kv': 'Томск обласьт',
#     'name:lt': 'Tomsko sritis',
#     'name:lv': 'Tomskas apgabals',
#     'name:mk': 'Томска област',
#     'name:mr': 'तोम्स्क ओब्लास्त',
#     'name:nl': 'Oblast Tomsk',
#     'name:nn': 'Tomsk oblast',
#     'name:no': 'Tomsk oblast',
#     'name:os': 'Томсчы облæст',
#     'name:pl': 'Obwód tomski',
#     'name:pt': 'Oblast de Tomsk',
#     'name:ro': 'Regiunea Tomsk',
#     'name:ru': 'Томская область',
#     'name:sah': 'Томскай уобалас',
#     'name:sh': 'Tomska oblast',
#     'name:sk': 'Tomská oblasť',
#     'name:sl': 'Tomska oblast',
#     'name:sr': 'Томска област',
#     'name:sv': 'Tomsk oblast',
#     'name:sw': 'Tomsk Oblast',
#     'name:tl': 'Tomsk_Oblast',
#     'name:tr': 'Tomsk Oblastı',
#     'name:tt': 'Томск өлкәсе',
#     'name:udm': 'Томск улос',
#     'name:uk': 'Томська область',
#     'name:vi': 'Tomsk',
#     'name:xal': 'Томин төгәлң',
#     'name:zh': '托木斯克州',
#     'place': 'state',
#     'ref': 'ТОМ',
#     'ref:en': 'TOM',
#     'wikidata': 'Q5884',
#     'wikipedia': 'ru:Томская область'}},
#   {'type': 'node',
#    'id': 503045144,
#    'lat': 67.1471631,
#    'lon': 74.3415488,
#    'tags': {'is_in:country': 'Россия',
#     'name': 'Ямало-Ненецкий автономный округ',
#     'name:be': 'Ямала-Ненецкая аўтаномная акруга',
#     'name:de': 'Autonomer Kreis der Jamal-Nenzen',
#     'name:en': 'Yamalo-Nenets Autonomous Okrug',
#     'name:eo': 'Jamalo-Neneca aŭtonoma distrikto',
#     'name:es': 'Yamalia-Nenetsia',
#     'name:fr': 'Iamalie',
#     'name:hr': 'Jamalskonenečki autonomni okrug',
#     'name:hu': 'Jamali Nyenyecföld',
#     'name:ja': 'ヤマロ・ネネツ自治管区',
#     'name:lt': 'Jamalo Nencų autonominė apygarda',
#     'name:pl': 'Jamalsko-Nieniecki Okręg Autonomiczny',
#     'name:ru': 'Ямало-Ненецкий автономный округ',
#     'name:sk': 'Jamalskonenecký autonómny okruh',
#     'name:tt': 'Ямал-Ненец автономияле округы',
#     'name:uk': 'Ямало-Ненецький автономний округ',
#     'official_name:es': 'Distrito autónomo de Yamalia-Nenetsia',
#     'official_name:fr': 'District autonome de Iamalo-Nénétsie',
#     'place': 'state',
#     'ref': 'ЯМА',
#     'ref:en': 'YAN',
#     'wikidata': 'Q6407',
#     'wikipedia': 'ru:Ямало-Ненецкий автономный округ'}},
#   {'type': 'node',
#    'id': 503046328,
#    'lat': 61.8793428,
#    'lon': 68.6418156,
#    'tags': {'alt_name': 'Ханты-Мансийский автономный округ - Югра',
#     'alt_name2': 'Югра',
#     'is_in': 'Россия',
#     'name': 'Ханты-Мансийский автономный округ — Югра',
#     'name:be': 'Ханты-Мансійская аўтаномная акруга',
#     'name:de': 'Autonomer Kreis der Chanten und Mansen - Jugra',
#     'name:en': 'Khanty-Mansiysk Autonomous Okrug – Ugra',
#     'name:eo': 'Ĥanti-Mansa aŭtonoma distrikto — Jugra',
#     'name:es': 'Janti-Mansi',
#     'name:fr': 'Khantys-Mansis',
#     'name:hr': 'Hantijsko-Mansijski autonomni okrug',
#     'name:hu': 'Hanti- és Manysiföld',
#     'name:ja': 'ハンティ・マンシ自治管区・ユグラ',
#     'name:lt': 'Chantų Mansija',
#     'name:pl': 'Chanty-Mansyjski Okręg Autonomiczny - Jugra',
#     'name:ru': 'Ханты-Мансийский автономный округ — Югра',
#     'name:sk': 'Chantyjsko-mansijský autonómny okruh',
#     'name:tt': 'Хант-Манси — Югра автономияле округы',
#     'name:uk': 'Ханти-Мансійський автономний округ — Югра',
#     'official_name:es': 'Distrito autónomo de Jantý-Mansí - Yugrá',
#     'official_name:fr': 'District autonome des Khantys-Mansis — Iougra',
#     'place': 'state',
#     'ref': 'ХАН',
#     'ref:en': 'KHM',
#     'wikidata': 'Q6320',
#     'wikipedia': 'ru:Ханты-Мансийский автономный округ — Югра'}},
#   {'type': 'node',
#    'id': 503047594,
#    'lat': 58.8206488,
#    'lon': 70.3658837,
#    'tags': {'name': 'Тюменская область',
#     'name:be': 'Цюменская вобласць',
#     'name:de': 'Oblast Tjumen',
#     'name:en': 'Tyumen Oblast',
#     'name:eo': 'Tjumena Provinco',
#     'name:es': 'Óblast de Tiumén',
#     'name:fr': 'Oblast de Tioumen',
#     'name:hr': 'Tjumenjska oblast',
#     'name:hu': 'Tyumenyi terület',
#     'name:ja': 'チュメニ州',
#     'name:lt': 'Tiumenės sritis',
#     'name:pl': 'Obwód tiumeński',
#     'name:ru': 'Тюменская область',
#     'name:sk': 'Ťumenská oblasť',
#     'name:tt': 'Төмән өлкәсе',
#     'name:uk': 'Тюменська область',
#     'place': 'state',
#     'ref': 'ТЮМ',
#     'ref:en': 'TYU',
#     'wikidata': 'Q5824',
#     'wikipedia': 'ru:Тюменская область'}},
#   {'type': 'node',
#    'id': 503050374,
#    'lat': 56.0935263,
#    'lon': 73.5099936,
#    'tags': {'is_in': 'Россия',
#     'name': 'Омская область',
#     'name:af': 'Omsk-oblast',
#     'name:be': 'Омская вобласць',
#     'name:de': 'Oblast Omsk',
#     'name:en': 'Omsk Oblast',
#     'name:eo': 'Omska Provinco',
#     'name:es': 'Óblast de Omsk',
#     'name:fr': "Oblast d'Omsk",
#     'name:he': 'מחוז אומסק',
#     'name:hr': 'Omska oblast',
#     'name:hu': 'Omszki terület',
#     'name:ja': 'オムスク州',
#     'name:lt': 'Omsko sritis',
#     'name:pl': 'Obwód omski',
#     'name:ru': 'Омская область',
#     'name:sk': 'Omská oblasť',
#     'name:tt': 'Омск өлкәсе',
#     'name:uk': 'Омська область',
#     'place': 'state',
#     'ref': 'ОМС',
#     'ref:en': 'OMS',
#     'wikidata': 'Q5835',
#     'wikipedia': 'ru:Омская область'}},
#   {'type': 'node',
#    'id': 503051686,
#    'lat': 54.9720169,
#    'lon': 79.4813924,
#    'tags': {'is_in:country': 'Россия',
#     'name': 'Новосибирская область',
#     'name:be': 'Новасібірская вобласць',
#     'name:de': 'Oblast Nowosibirsk',
#     'name:en': 'Novosibirsk Oblast',
#     'name:eo': 'Novosibirska Provinco',
#     'name:es': 'Óblast de Novosibirsk',
#     'name:et': 'Novosibirski oblast',
#     'name:fr': 'Oblast de Novossibirsk',
#     'name:he': 'מחוז נובוסיבירסק',
#     'name:hr': 'Novosibirska oblast',
#     'name:hu': 'Novoszibirszki terület',
#     'name:ja': 'ノヴォシビルスク州',
#     'name:lt': 'Novosibirsko sritis',
#     'name:pl': 'Obwód nowosybirski',
#     'name:ru': 'Новосибирская область',
#     'name:sk': 'Novosibirská oblasť',
#     'name:tt': 'Новосибирск өлкәсе',
#     'name:uk': 'Новосибірська область',
#     'place': 'state',
#     'ref': 'НСО',
#     'ref:en': 'NVS',
#     'wikidata': 'Q5851',
#     'wikipedia': 'ru:Новосибирская область'}},
#   {'type': 'node',
#    'id': 503055077,
#    'lat': 54.5335781,
#    'lon': 87.342861,
#    'tags': {'name': 'Кемеровская область',
#     'name:af': 'Kemerowo-oblast',
#     'name:be': 'Кемераўская вобласць',
#     'name:de': 'Oblast Kemerowo',
#     'name:en': 'Kuzbass',
#     'name:eo': 'Kemerova Provinco',
#     'name:es': 'Óblast de Kémerovo',
#     'name:fr': 'Oblast de Kemerovo',
#     'name:he': 'מחוז קמרובו',
#     'name:hr': 'Kemerovska oblast',
#     'name:hu': 'Kemerovói terület',
#     'name:ja': 'ケメロヴォ州',
#     'name:lt': 'Kemerovo sritis',
#     'name:pl': 'Obwód kemerowski',
#     'name:ru': 'Кемеровская область',
#     'name:sk': 'Kemerovská oblasť',
#     'name:tt': 'Кемерово өлкәсе',
#     'name:uk': 'Кемеровська область',
#     'official_name': 'Кемеровская область — Кузбасс',
#     'place': 'state',
#     'ref': 'КЕМ',
#     'ref:en': 'KEM',
#     'wikidata': 'Q6076',
#     'wikipedia': 'ru:Кемеровская область'}},
#   {'type': 'node',
#    'id': 503057596,
#    'lat': 52.6932243,
#    'lon': 82.6931424,
#    'tags': {'is_in:country': 'Россия',
#     'name': 'Алтайский край',
#     'name:be': 'Алтайскі край',
#     'name:de': 'Region Altai',
#     'name:en': 'Altai Krai',
#     'name:eo': 'Altaja Regiono',
#     'name:es': 'Krai de Altái',
#     'name:fr': "Kraï de l'Altaï",
#     'name:hr': 'Altajski kraj',
#     'name:hu': 'Altaji határterület',
#     'name:ja': 'アルタイ地方',
#     'name:lt': 'Altajaus kraštas',
#     'name:pl': 'Kraj Ałtajski',
#     'name:ru': 'Алтайский край',
#     'name:sk': 'Altajský kraj',
#     'name:tt': 'Алтай крае',
#     'name:uk': 'Алтайський край',
#     'place': 'state',
#     'ref': 'АЛТ',
#     'ref:en': 'ALT',
#     'wikidata': 'Q5942',
#     'wikipedia': 'ru:Алтайский край'}},
#   {'type': 'node',
#    'id': 503059916,
#    'lat': 50.7114101,
#    'lon': 86.8572186,
#    'tags': {'addr:country': 'RU',
#     'addr:postcode': '649000',
#     'addr:region': 'Республика Алтай',
#     'name': 'Республика Алтай',
#     'name:be': 'Алтай',
#     'name:de': 'Republik Altai',
#     'name:en': 'Altai Republic',
#     'name:eo': 'Respubliko Altaj',
#     'name:es': 'Altái',
#     'name:fr': 'Altaï',
#     'name:hr': 'Altajska republika',
#     'name:hu': 'Altaj Köztársaság',
#     'name:lt': 'Altajaus Respublika',
#     'name:pl': 'Republika Ałtaju',
#     'name:ru': 'Республика Алтай',
#     'name:sk': 'Altajsko',
#     'name:tt': 'Алтай Республикасы',
#     'name:uk': 'Республіка Алтай',
#     'official_name:be': 'Рэспубліка Алтай',
#     'official_name:es': 'República de Altái',
#     'official_name:fr': "République de l'Altaï",
#     'official_name:ru': 'Республика Алтай',
#     'place': 'state',
#     'ref': 'АЛР',
#     'ref:en': 'AL',
#     'wikidata': 'Q5971',
#     'wikipedia': 'ru:Республика Алтай'}},
#   {'type': 'node',
#    'id': 503064678,
#    'lat': 53.4399379,
#    'lon': 90.0664303,
#    'tags': {'name': 'Республика Хакасия',
#     'name:be': 'Хакасія',
#     'name:da': 'Khakasien',
#     'name:de': 'Chakassien',
#     'name:en': 'Khakassia',
#     'name:eo': 'Respubliko Ĥakasio',
#     'name:es': 'Jakasia',
#     'name:fr': 'Khakassie',
#     'name:hr': 'Hakasija',
#     'name:hu': 'Hakaszföld',
#     'name:ja': 'ハカス共和国',
#     'name:lt': 'Chakasija',
#     'name:pl': 'Chakasja',
#     'name:ru': 'Республика Хакасия',
#     'name:sk': 'Chakasko',
#     'name:uk': 'Хакасія',
#     'official_name': 'Республика Хакасия',
#     'official_name:be': 'Рэспубліка Хакасія',
#     'official_name:en': 'Republic of Khakassia',
#     'official_name:es': 'República de Jakasia',
#     'official_name:fr': 'République de Khakassie',
#     'official_name:ru': 'Республика Хакасия',
#     'official_name:sk': 'Chakaská republika',
#     'place': 'state',
#     'ref': 'ХАК',
#     'ref:en': 'KK',
#     'wikidata': 'Q6543',
#     'wikipedia': 'ru:Хакасия'}},
#   {'type': 'node',
#    'id': 503068230,
#    'lat': 51.4017149,
#    'lon': 93.8582593,
#    'tags': {'is_in:country': 'Россия',
#     'name': 'Республика Тыва',
#     'name:be': 'Тува',
#     'name:de': 'Tuwa',
#     'name:en': 'Tuva',
#     'name:eo': 'Tuvio',
#     'name:es': 'Tuvá',
#     'name:fr': 'Touva',
#     'name:hr': 'Tuva',
#     'name:hu': 'Tuva',
#     'name:ru': 'Республика Тыва',
#     'name:sk': 'Tuviansko',
#     'official_name': 'Республика Тува',
#     'official_name:be': 'Рэспубліка Тува',
#     'official_name:de': 'Republik Tuwa',
#     'official_name:es': 'República Tuvá',
#     'official_name:fr': 'République de Touva',
#     'official_name:ru': 'Республика Тува',
#     'place': 'state',
#     'ref': 'ТУВ',
#     'ref:en': 'TY',
#     'wikidata': 'Q960',
#     'wikipedia': 'ru:Тыва'}},
#   {'type': 'node',
#    'id': 503073143,
#    'lat': 63.3233807,
#    'lon': 97.0979974,
#    'tags': {'is_in:country': 'Россия',
#     'name': 'Красноярский край',
#     'name:be': 'Краснаярскі край',
#     'name:da': 'Krasnojarsk kraj',
#     'name:de': 'Region Krasnojarsk',
#     'name:en': 'Krasnoyarsk Krai',
#     'name:eo': 'Krasnojarska Regiono',
#     'name:es': 'Krai de Krasnoyarsk',
#     'name:fr': 'Kraï de Krasnoïarsk',
#     'name:he': 'מחוז קרסנויארסק',
#     'name:hr': 'Krasnojarski kraj',
#     'name:hu': 'Krasznojarszki határterület',
#     'name:ja': 'クラスノヤルスク地方',
#     'name:lt': 'Krasnojarsko kraštas',
#     'name:pl': 'Kraj Krasnojarski',
#     'name:ru': 'Красноярский край',
#     'name:sk': 'Krasnojarský kraj',
#     'name:tt': 'Красноярск крае',
#     'name:uk': 'Красноярський край',
#     'place': 'state',
#     'ref': 'КРН',
#     'ref:en': 'KYA',
#     'wikidata': 'Q6563',
#     'wikipedia': 'ru:Красноярский край'}},
#   {'type': 'node',
#    'id': 503077246,
#    'lat': 56.6370122,
#    'lon': 104.719221,
#    'tags': {'int_name': 'Irkutsk Oblast',
#     'is_in:country': 'Россия',
#     'name': 'Иркутская область',
#     'name:be': 'Іркуцкая вобласць',
#     'name:da': 'Irkutsk oblast',
#     'name:de': 'Oblast Irkutsk',
#     'name:en': 'Irkutsk Oblast',
#     'name:eo': 'Irkutska Provinco',
#     'name:es': 'Óblast de Irkutsk',
#     'name:fr': "Oblast d'Irkoutsk",
#     'name:hr': 'Irkutska oblast',
#     'name:hu': 'Irkutszki terület',
#     'name:ja': 'イルクーツク州',
#     'name:lt': 'Irkutsko sritis',
#     'name:pl': 'Obwód irkucki',
#     'name:ru': 'Иркутская область',
#     'name:sk': 'Irkutská oblasť',
#     'name:tt': 'Иркутск өлкәсе',
#     'name:uk': 'Іркутська область',
#     'place': 'state',
#     'ref': 'ИРК',
#     'ref:en': 'IRK',
#     'wikidata': 'Q6585',
#     'wikipedia': 'ru:Иркутская область'}},
#   {'type': 'node',
#    'id': 503080952,
#    'lat': 52.7182426,
#    'lon': 109.492143,
#    'tags': {'is_in': 'Россия',
#     'name': 'Бурятия',
#     'name:be': 'Бурація',
#     'name:de': 'Burjatien',
#     'name:en': 'Buryatia',
#     'name:eo': 'Burjatio',
#     'name:es': 'Buriatia',
#     'name:fr': 'Bouriatie',
#     'name:hr': 'Burjatska',
#     'name:hu': 'Burjátföld',
#     'name:ja': 'ブリヤート共和国',
#     'name:lt': 'Buriatija',
#     'name:pl': 'Buriacja',
#     'name:ru': 'Бурятия',
#     'name:sk': 'Buriatsko',
#     'name:uk': 'Бурятія',
#     'official_name:be': 'Рэспубліка Бурація',
#     'official_name:en': 'Buryat Republic',
#     'official_name:es': 'República de Buriatia',
#     'official_name:fr': 'République de Bouriatie',
#     'official_name:ru': 'Республика Бурятия',
#     'place': 'state',
#     'ref': 'БУР',
#     'ref:en': 'BU',
#     'wikidata': 'Q6809',
#     'wikipedia': 'ru:Бурятия'}},
#   {'type': 'node',
#    'id': 503087444,
#    'lat': 52.248521,
#    'lon': 115.956325,
#    'tags': {'is_in:country': 'Россия',
#     'name': 'Забайкальский край',
#     'name:ar': 'زابايكالسكي كراي',
#     'name:be': 'Забайкальскі край',
#     'name:de': 'Region Transbaikalien',
#     'name:en': 'Zabaykalsky Krai',
#     'name:eo': 'Transbajkalo Regiono',
#     'name:es': 'Krai de Zabaikalie',
#     'name:fr': 'Kraï de Transbaïkalie',
#     'name:he': 'מחוז עבר הבאיקל',
#     'name:hr': 'Zabajkalski kraj',
#     'name:hu': 'Bajkálontúli határterület',
#     'name:ja': 'ザバイカリエ地方',
#     'name:lt': 'Užbaikalės kraštas',
#     'name:pl': 'Kraj Zabajkalski',
#     'name:ru': 'Забайкальский край',
#     'name:sk': 'Zabajkalský kraj',
#     'name:uk': 'Забайкальський край',
#     'place': 'state',
#     'ref': 'ЗАБ',
#     'ref:en': 'ZAB',
#     'wikidata': 'Q6838',
#     'wikipedia': 'ru:Забайкальский край'}},
#   {'type': 'node',
#    'id': 503088681,
#    'lat': 66.941626,
#    'lon': 129.642371,
#    'tags': {'name': 'Республика Саха (Якутия)',
#     'name:ba': 'Яҡут Республикаһы',
#     'name:be': 'Саха (Якуція)',
#     'name:da': 'Sakha',
#     'name:de': 'Sacha (Jakutien)',
#     'name:en': 'Sakha (Yakutia)',
#     'name:eo': 'Jakutio',
#     'name:es': 'Saĥa (Jakutio)',
#     'name:fr': 'Iakoutie',
#     'name:hr': 'Jakutska',
#     'name:hu': 'Jakutföld',
#     'name:ja': 'サハ共和国 (ヤクーティア)',
#     'name:lt': 'Jakutija',
#     'name:pl': 'Jakucja',
#     'name:ru': 'Республика Саха (Якутия)',
#     'name:sah': 'Саха',
#     'name:sk': 'Republika Sacha (Jakutsko)',
#     'name:tt': 'Якутия',
#     'name:uk': 'Республіка Саха',
#     'name:zh': '萨哈（雅库特）共和国',
#     'official_name:be': 'Рэспубліка Саха (Якуція)',
#     'official_name:de': 'Republik Sacha (Jakutien)',
#     'official_name:en': 'Sakha (Yakutia) Republic',
#     'official_name:es': 'Respubliko Saĥa (Jakutio)',
#     'official_name:fr': 'République de Sakha (Iakoutie)',
#     'official_name:ru': 'Республика Саха (Якутия)',
#     'official_name:sah': 'Саха Республиката',
#     'place': 'state',
#     'ref': 'ЯКУ',
#     'ref:en': 'SA',
#     'wikidata': 'Q6605',
#     'wikipedia': 'ru:Якутия'}},
#   {'type': 'node',
#    'id': 505006802,
#    'lat': 54.4226732,
#    'lon': 40.5705246,
#    'tags': {'int_name': 'Ryazan Oblast',
#     'is_in': 'Россия',
#     'name': 'Рязанская область',
#     'name:be': 'Разанская вобласць',
#     'name:de': 'Oblast Rjasan',
#     'name:en': 'Ryazan region',
#     'name:eo': 'Rjazanja Provinco',
#     'name:es': 'Óblast de Riazán',
#     'name:fr': 'Oblast de Riazan',
#     'name:hr': 'Rjazanjska oblast',
#     'name:hu': 'Rjazanyi terület',
#     'name:ja': 'リャザン州',
#     'name:lt': 'Riazanės sritis',
#     'name:pl': 'Obwód riazański',
#     'name:ru': 'Рязанская область',
#     'name:sk': 'Riazanská oblasť',
#     'name:tt': 'Рязань өлкәсе',
#     'name:uk': 'Рязанська область',
#     'place': 'state',
#     'ref': 'РЯЗ',
#     'ref:en': 'RYA',
#     'wikidata': 'Q2753',
#     'wikipedia': 'ru:Рязанская область'}},
#   {'type': 'node',
#    'id': 508056667,
#    'lat': 48.5601613,
#    'lon': 132.2775662,
#    'tags': {'name': 'Еврейская автономная область',
#     'name:af': 'Joodse Outonome Oblast',
#     'name:be': 'Яўрэйская аўтаномная вобласць',
#     'name:da': 'Jødiske autonome oblast',
#     'name:de': 'Jüdisches Autonomes Gebiet',
#     'name:en': 'Jewish region',
#     'name:eo': 'Hebrea Aŭtonomio',
#     'name:es': 'Óblast Autónomo Hebreo',
#     'name:et': 'Juudi autonoomne oblast',
#     'name:fr': 'Oblast autonome juif',
#     'name:he': 'המחוז היהודי האוטונומי',
#     'name:hr': 'Židovska autonomna oblast',
#     'name:hu': 'Zsidó autonóm terület',
#     'name:ja': 'ユダヤ自治州',
#     'name:lt': 'Žydų autonominė sritis',
#     'name:nl': 'Joodse Autonome Oblast',
#     'name:pl': 'Żydowski Obwód Autonomiczny',
#     'name:ru': 'Еврейская автономная область',
#     'name:sk': 'Židovská autonómna oblasť',
#     'name:uk': 'Єврейська автономна область',
#     'place': 'state',
#     'ref': 'ЕВР',
#     'ref:en': 'JEW',
#     'wikidata': 'Q7730',
#     'wikipedia': 'ru:Еврейская автономная область'}},
#   {'type': 'node',
#    'id': 508056994,
#    'lat': 51.6312684,
#    'lon': 136.121524,
#    'tags': {'name': 'Хабаровский край',
#     'name:be': 'Хабараўскі край',
#     'name:da': 'Khabarovsk kraj',
#     'name:de': 'Region Chabarowsk',
#     'name:en': 'Khabarovsk Krai',
#     'name:eo': 'Ĥabarovska Regiono',
#     'name:es': 'Krai de Jabárovsk',
#     'name:fr': 'Kraï de Khabarovsk',
#     'name:he': 'מחוז חברובסק',
#     'name:hr': 'Habarovski kraj',
#     'name:hu': 'Habarovszki határterület',
#     'name:ja': 'ハバロフスク地方',
#     'name:lt': 'Chabarovsko kraštas',
#     'name:pl': 'Kraj Chabarowski',
#     'name:ru': 'Хабаровский край',
#     'name:sk': 'Chabarovský kraj',
#     'name:uk': 'Хабаровський край',
#     'place': 'state',
#     'ref': 'ХАБ',
#     'ref:en': 'KHA',
#     'wikidata': 'Q7788',
#     'wikipedia': 'ru:Хабаровский край'}},
#   {'type': 'node',
#    'id': 508057236,
#    'lat': 49.7219665,
#    'lon': 143.448533,
#    'tags': {'name': 'Сахалинская область',
#     'name:be': 'Сахалінская вобласць',
#     'name:de': 'Sachalin',
#     'name:en': 'Sakhalin Oblast',
#     'name:eo': 'Saĥalena Provinco',
#     'name:es': 'Óblast de Sajalín',
#     'name:fr': 'Oblast de Sakhaline',
#     'name:hr': 'Sahalinska oblast',
#     'name:hu': 'Szahalini terület',
#     'name:ja': 'サハリン州',
#     'name:ko': '사할린 주',
#     'name:lt': 'Sachalino sritis',
#     'name:ms': 'Wilayah Sakhalin',
#     'name:pl': 'Obwód sachaliński',
#     'name:ru': 'Сахалинская область',
#     'name:sk': 'Sachalinská oblasť',
#     'name:ta': 'சகாலின் மாகாணம்',
#     'name:uk': 'Сахалінська область',
#     'name:zh': '萨哈林州',
#     'official_name:de': 'Oblast Sachalin',
#     'place': 'state',
#     'population': '490181',
#     'population:date': '2018',
#     'ref': 'САХ',
#     'ref:en': 'SAK',
#     'wikidata': 'Q7797',
#     'wikipedia': 'ru:Сахалинская область'}},
#   {'type': 'node',
#    'id': 508057529,
#    'lat': 57.1914882,
#    'lon': 160.0383819,
#    'tags': {'ISO3166-2': 'RU-KAM',
#     'addr:country': 'RU',
#     'admin_level': '4',
#     'alt_name': 'Камчатка',
#     'int_name': 'Kamchatkiy Kray',
#     'name': 'Камчатский край',
#     'name:be': 'Камчатка',
#     'name:br': 'Kamtchatka',
#     'name:ca': 'Territori de Kamtxatka',
#     'name:de': 'Region Kamtschatka',
#     'name:en': 'Kamchatka Krai',
#     'name:eo': 'Kamĉatko Regiono',
#     'name:es': 'Krai de Kamchatka',
#     'name:et': 'Kamtšatka krai',
#     'name:fr': 'Kraï du Kamtchatka',
#     'name:he': "מחוז קמצ'טקה",
#     'name:hr': 'Kamačatski kraj',
#     'name:hu': 'Kamcsatkai határterület',
#     'name:ja': 'カムチャツカ地方',
#     'name:lt': 'Kamčiatkos kraštas',
#     'name:nl': 'Kraj Kamtsjatka',
#     'name:pl': 'Kraj Kamczacki',
#     'name:pt': 'Krai de Kamtchatka',
#     'name:ru': 'Камчатский край',
#     'name:sk': 'Kamčatský kraj',
#     'name:sv': 'Kamtjatka kraj',
#     'name:uk': 'Камчатський край',
#     'name:vi': 'Kamchatka (vùng)',
#     'name:zh': '堪察加邊疆區',
#     'official_name': 'Камчатский край',
#     'official_name:be': 'Камчацкі край',
#     'official_name:de': 'Region Kamtschatka',
#     'official_name:es': 'Krai de Kamchatka',
#     'official_name:fr': 'Kraï du Kamtchatka',
#     'official_name:ru': 'Камчатский край',
#     'official_status': 'ru:край',
#     'place': 'state',
#     'population': '319864',
#     'population:date': '2014-01-01',
#     'ref': 'RU-KAM',
#     'ref:en': 'KAM',
#     'source:name:br': 'ofis publik ar brezhoneg',
#     'timezone': 'Asia/Kamchatka',
#     'wikidata': 'Q7948',
#     'wikipedia': 'ru:Камчатский край'}},
#   {'type': 'node',
#    'id': 508057745,
#    'lat': 63.5515028,
#    'lon': 154.014726,
#    'tags': {'name': 'Магаданская область',
#     'name:be': 'Магаданская вобласць',
#     'name:de': 'Oblast Magadan',
#     'name:en': 'Magadan region',
#     'name:eo': 'Magadana Provinco',
#     'name:es': 'Óblast de Magadán',
#     'name:fr': 'Oblast de Magadan',
#     'name:hr': 'Magadanska oblast',
#     'name:hu': 'Magadani terület',
#     'name:ja': 'マガダン州',
#     'name:lt': 'Magadano sritis',
#     'name:pl': 'Obwód magadański',
#     'name:ru': 'Магаданская область',
#     'name:sk': 'Magadanská oblasť',
#     'name:tt': 'Магадан өлкәсе',
#     'name:uk': 'Магаданська область',
#     'place': 'state',
#     'ref': 'МАГ',
#     'ref:en': 'MAG',
#     'wikidata': 'Q7971',
#     'wikipedia': 'ru:Магаданская область'}},
#   {'type': 'node',
#    'id': 508057959,
#    'lat': 66.0006475,
#    'lon': 169.4900869,
#    'tags': {'gost_7.67-2003': 'РОФ-ЧУК',
#     'int_name': 'Chukotka Autonomous Okrug',
#     'int_ref': 'RU-CHU',
#     'name': 'Чукотский автономный округ',
#     'name:be': 'Чукотка',
#     'name:ca': 'Txukotka',
#     'name:cs': 'Čukotský autonomní okruh',
#     'name:de': 'Autonomer Kreis der Tschuktschen',
#     'name:en': 'Chukotka Autonomous Okrug',
#     'name:eo': 'Ĉukotko',
#     'name:es': 'Chukotka',
#     'name:et': 'Tšuktšimaa',
#     'name:fr': 'Tchoukotka',
#     'name:hr': 'Čukotski autonomni okrug',
#     'name:hu': 'Csukcsföld',
#     'name:it': 'Circondario autonomo della Čukotka',
#     'name:ja': 'チュクチ自治管区',
#     'name:lt': 'Čiukčių autonominė apygarda',
#     'name:nl': 'Tsjoekotka',
#     'name:pl': 'Czukocki Okręg Autonomiczny',
#     'name:ru': 'Чукотский автономный округ',
#     'name:sk': 'Čukotský autonómny okruh',
#     'name:sv': 'Tjuktjien',
#     'name:tt': 'Чукотка автономияле округы',
#     'name:uk': 'Чукотський автономний округ',
#     'name:vi': 'Khu tự trị Chukotka',
#     'name:zh': '楚科奇自治区',
#     'official_name': 'Чукотский автономный округ',
#     'official_name:be': 'Чукоцкая аўтаномная акруга',
#     'official_name:de': 'Autonomer Kreis der Tschuktschen',
#     'official_name:en': 'Chukotka Autonomous Okrug',
#     'official_name:es': 'Distrito autónomo de Chukotka',
#     'official_name:fr': 'District autonome de Tchoukotka',
#     'official_name:ru': 'Чукотский автономный округ',
#     'place': 'state',
#     'ref': 'ЧУК',
#     'ref:en': 'CHU',
#     'wikidata': 'Q7984',
#     'wikipedia': 'ru:Чукотский автономный округ'}},
#   {'type': 'node',
#    'id': 516618494,
#    'lat': 54.7293041,
#    'lon': 21.1489473,
#    'tags': {'int_name': 'Kaliningrad region',
#     'name': 'Калининградская область',
#     'name:be': 'Калінінградская вобласць',
#     'name:de': 'Oblast Kaliningrad',
#     'name:en': 'Kaliningrad Oblast',
#     'name:eo': 'Kaliningrada Provinco',
#     'name:fr': 'Oblast de Kaliningrad',
#     'name:hr': 'Kaljingradska oblast',
#     'name:hu': 'Kalinyingrád',
#     'name:ku': 'Oblasta Kaliningradê',
#     'name:lt': 'Kaliningrado sritis',
#     'name:pl': 'obwód kaliningradzki',
#     'name:ru': 'Калининградская область',
#     'name:sk': 'Kaliningradská oblasť',
#     'name:uk': 'Калінінградська область',
#     'name:zh': '加里宁格勒州',
#     'place': 'state',
#     'population': '937000',
#     'ref': 'КЛН',
#     'wikidata': 'Q1749',
#     'wikipedia': 'ru:Калининградская область'}},
#   {'type': 'node',
#    'id': 533634715,
#    'lat': 58.2843833,
#    'lon': 32.5169757,
#    'tags': {'admin_level': '4',
#     'is_in': 'Российская Федерация',
#     'name': 'Новгородская область',
#     'name:be': 'Наўгародская вобласць',
#     'name:cs': 'Novgorodská oblast',
#     'name:de': 'Oblast Nowgorod',
#     'name:en': 'Novgorod Oblast',
#     'name:eo': 'Novgoroda Provinco',
#     'name:es': 'Óblast de Nóvgorod',
#     'name:et': 'Novgorodi oblast',
#     'name:fr': 'Oblast de Novgorod',
#     'name:hr': 'Novgorodska oblast',
#     'name:hu': 'Velikij Novgorod',
#     'name:ja': 'ノヴゴロド州',
#     'name:lt': 'Novgorodo sritis',
#     'name:pl': 'Obwód nowogrodzki',
#     'name:ru': 'Новгородская область',
#     'name:sk': 'Novgorodská oblasť',
#     'name:sr': 'Новгородска област',
#     'name:uk': 'Новгородська область',
#     'place': 'state',
#     'ref': 'НОВ',
#     'ref:en': 'NGR',
#     'wikidata': 'Q2240',
#     'wikipedia': 'ru:Новгородская область'}},
#   {'type': 'node',
#    'id': 533719181,
#    'lat': 53.2128813,
#    'lon': 50.8914633,
#    'tags': {'int_name': 'Samara Oblast',
#     'name': 'Самарская область',
#     'name:be': 'Самарская вобласць',
#     'name:cs': 'Samarská oblast',
#     'name:de': 'Oblast Samara',
#     'name:en': 'Samara Oblast',
#     'name:eo': 'Samara Provinco',
#     'name:es': 'Óblast de Samara',
#     'name:fr': 'Oblast de Samara',
#     'name:hr': 'Samarska oblast',
#     'name:hu': 'Szamarai terület',
#     'name:ja': 'サマーラ州',
#     'name:lt': 'Samaros sritis',
#     'name:pl': 'Obwód samarski',
#     'name:ru': 'Самарская область',
#     'name:sk': 'Samarská oblasť',
#     'name:tt': 'Самара өлкәсе',
#     'name:uk': 'Самарська область',
#     'place': 'state',
#     'ref': 'САМ',
#     'ref:en': 'SAM',
#     'wikidata': 'Q1727',
#     'wikipedia': 'ru:Самарская область'}},
#   {'type': 'node',
#    'id': 535136806,
#    'lat': 68.0000418,
#    'lon': 33.9999151,
#    'tags': {'admin_level': '4',
#     'int_name': 'Murmansk Oblast',
#     'is_in': 'Россия',
#     'name': 'Мурманская область',
#     'name:be': 'Мурманская вобласць',
#     'name:cs': 'Murmanská oblast',
#     'name:de': 'Oblast Murmansk',
#     'name:en': 'Murmansk Oblast',
#     'name:eo': 'Murmanska Provinco',
#     'name:es': 'Óblast de Múrmansk',
#     'name:fi': 'Murmanskin alue',
#     'name:fr': 'Oblast de Mourmansk',
#     'name:hr': 'Murmanska oblast',
#     'name:hu': 'Murmanszk Oblast',
#     'name:ja': 'ムルマンスク州',
#     'name:lt': 'Murmansko sritis',
#     'name:pl': 'Obwód murmański',
#     'name:ru': 'Мурманская область',
#     'name:sk': 'Murmanská oblasť',
#     'name:sr': 'Мурманска област',
#     'name:sv': 'Murmansk oblast',
#     'name:uk': 'Мурманська область',
#     'place': 'state',
#     'ref': 'МУР',
#     'ref:en': 'MUR',
#     'wikidata': 'Q1759',
#     'wikipedia': 'ru:Мурманская область'}},
#   {'type': 'node',
#    'id': 535182674,
#    'lat': 58.6414755,
#    'lon': 61.8021546,
#    'tags': {'addr:country': 'RU',
#     'addr:postcode': '620000',
#     'addr:region': 'Свердловская область',
#     'admin_level': '4',
#     'int_name': 'Sverdlovsk Oblast',
#     'name': 'Свердловская область',
#     'name:be': 'Свярдлоўская вобласць',
#     'name:cs': 'Sverdlovská oblast',
#     'name:de': 'Oblast Swerdlowsk',
#     'name:en': 'Sverdlovsk Oblast',
#     'name:eo': 'Sverdlovska Provinco',
#     'name:es': 'Óblast de Sverdlovsk',
#     'name:fr': 'Oblast de Sverdlovsk',
#     'name:hr': 'Sverdlovska oblast',
#     'name:hu': 'Szverdlovszki terület',
#     'name:ja': 'スヴェルドロフスク州',
#     'name:pl': 'Obwód swierdłowski',
#     'name:ru': 'Свердловская область',
#     'name:sk': 'Sverdlovská oblasť',
#     'place': 'state',
#     'ref': 'СВЕ',
#     'ref:en': 'SVE',
#     'wikidata': 'Q5462',
#     'wikipedia': 'ru:Свердловская область'}},
#   {'type': 'node',
#    'id': 540553503,
#    'lat': 58.5951603,
#    'lon': 56.3159546,
#    'tags': {'is_in:country': 'Россия',
#     'name': 'Пермский край',
#     'name:be': 'Пермскі край',
#     'name:de': 'Region Perm',
#     'name:en': 'Perm Krai',
#     'name:eo': 'Permja Regiono',
#     'name:es': 'Krai de Perm',
#     'name:fr': 'Kraï de Perm',
#     'name:hr': 'Permski kraj',
#     'name:hu': 'Permi határterület',
#     'name:ja': 'ペルミ地方',
#     'name:lt': 'Permės kraštas',
#     'name:pl': 'Kraj Permski',
#     'name:ru': 'Пермский край',
#     'name:sk': 'Permský kraj',
#     'name:tt': 'Пермь крае',
#     'name:uk': 'Пермський край',
#     'place': 'state',
#     'ref': 'ПЕР',
#     'ref:en': 'PER',
#     'wikidata': 'Q5400',
#     'wikipedia': 'ru:Пермский край'}},
#   {'type': 'node',
#    'id': 559621143,
#    'lat': 63.9881421,
#    'lon': 54.3326073,
#    'tags': {'addr:country': 'RU',
#     'name': 'Коми',
#     'name:be': 'Комі',
#     'name:de': 'Republik Komi',
#     'name:en': 'Komi',
#     'name:eo': 'Komiio',
#     'name:es': 'Komi',
#     'name:fr': 'République des Komis',
#     'name:hr': 'Republika Komi',
#     'name:hu': 'Komiföld',
#     'name:ja': 'コミ共和国',
#     'name:lt': 'Komijos Respublika',
#     'name:pl': 'Republika Komi',
#     'name:ru': 'Коми',
#     'name:sk': 'Komijsko',
#     'name:tt': 'Коми Республикасы',
#     'name:uk': 'Республіка Комі',
#     'official_name': 'Республика Коми',
#     'official_name:be': 'Рэспубліка Комі',
#     'official_name:en': 'Komi Republic',
#     'official_name:ru': 'Республика Коми',
#     'official_name:sk': 'Komijská republika',
#     'place': 'state',
#     'ref': 'КОМ',
#     'ref:en': 'KO',
#     'wikidata': 'Q2073',
#     'wikipedia': 'ru:Республика Коми'}},
#   {'type': 'node',
#    'id': 567535537,
#    'lat': 62.6194031,
#    'lon': 33.4920267,
#    'tags': {'addr:country': 'RU',
#     'alt_name': 'Карелия',
#     'name': 'Республика Карелия',
#     'name:be': 'Карэлія',
#     'name:da': 'Karelen',
#     'name:de': 'Republik Karelien',
#     'name:en': 'Karjala',
#     'name:eo': 'Respubliko Karelio',
#     'name:es': 'Carelia',
#     'name:et': 'Karjala',
#     'name:fi': 'Karjala',
#     'name:fr': 'Carélie',
#     'name:he': 'קריאלה',
#     'name:ja': 'カレリア共和国',
#     'name:lt': 'Karelijos Respublika',
#     'name:pl': 'Karjala',
#     'name:ru': 'Карелия',
#     'name:sk': 'Karelsko',
#     'name:sv': 'Karelska republiken',
#     'name:tt': 'Karjala',
#     'name:uk': 'Республіка Карелія',
#     'official_name': 'Республика Карелия',
#     'official_name:be': 'Рэспубліка Карэлія',
#     'official_name:en': 'Republic of Karelia',
#     'official_name:es': 'República de Carelia',
#     'official_name:fr': 'République de Carélie',
#     'official_name:ru': 'Республика Карелия',
#     'official_name:sk': 'Karelská republika',
#     'place': 'state',
#     'ref': 'КАР',
#     'ref:en': 'KR',
#     'wikidata': 'Q1914',
#     'wikipedia': 'ru:Республика Карелия'}},
#   {'type': 'node',
#    'id': 573226686,
#    'lat': 55.448217,
#    'lon': 50.4763591,
#    'tags': {'admin_level': '4',
#     'alt_name': 'Татария',
#     'alt_name:eo': 'Tatarujo;Tatarstano',
#     'int_name': 'Tatarstan',
#     'name': 'Татарстан',
#     'name:ba': 'Татарстан Республикаһы',
#     'name:be': 'Татарстан',
#     'name:da': 'Tatarstan',
#     'name:de': 'Tatarstan',
#     'name:en': 'Tatarstan',
#     'name:eo': 'Tatario',
#     'name:es': 'Tartaristán',
#     'name:fr': 'Tatarstan',
#     'name:he': 'טטרסטן',
#     'name:hu': 'Tatárföld',
#     'name:ja': 'タタールスタン共和国',
#     'name:lt': 'Tatarstanas',
#     'name:pl': 'Tatarstan',
#     'name:ru': 'Татарстан',
#     'name:sk': 'Tatársko',
#     'official_name': 'Республика Татарстан',
#     'official_name:be': 'Рэспубліка Татарстан',
#     'official_name:de': 'Republik Tatarstan',
#     'official_name:en': 'Republic of Tatarstan',
#     'official_name:eo': 'Respubliko Tatario',
#     'official_name:es': 'República de Tartaristán',
#     'official_name:fr': 'République du Tatarstan',
#     'official_name:ru': 'Республика Татарстан',
#     'official_name:sk': 'Tatárska republika',
#     'place': 'state',
#     'ref': 'ТАТ',
#     'ref:en': 'TA',
#     'wikidata': 'Q5481',
#     'wikipedia': 'ru:Татарстан'}},
#   {'type': 'node',
#    'id': 573226687,
#    'lat': 54.4747553,
#    'lon': 55.9784582,
#    'tags': {'alt_name': 'Башкирия',
#     'alt_name:de': 'Baschkirien',
#     'int_name': 'Bashkortostan',
#     'name': 'Башкортостан',
#     'name:af': 'Basjkortostan',
#     'name:ba': 'Башҡортостан',
#     'name:be': 'Башкартастан',
#     'name:cs': 'Baškortostán',
#     'name:de': 'Baschkortostan',
#     'name:en': 'Bashkortostan',
#     'name:eo': 'Baŝkirio',
#     'name:es': 'Bashkortostán',
#     'name:fr': 'Bachkirie',
#     'name:hu': 'Baskíria',
#     'name:ja': 'バシコルトスタン共和国',
#     'name:lt': 'Baškirija',
#     'name:pl': 'Baszkiria',
#     'name:ru': 'Башкортостан',
#     'name:sk': 'Baškirsko',
#     'name:tt': 'Башкортстан',
#     'official_name': 'Республика Башкортостан',
#     'official_name:be': 'Рэспубліка Башкартастан',
#     'official_name:de': 'Republik Baschkortostan',
#     'official_name:en': 'Republic of Bashkortostan',
#     'official_name:fr': 'République de Bachkirie',
#     'official_name:ru': 'Республика Башкортостан',
#     'official_name:sk': 'Baškirská republika',
#     'place': 'state',
#     'ref': 'БАШ',
#     'ref:en': 'BA',
#     'wikidata': 'Q5710',
#     'wikipedia': 'ru:Башкортостан'}},
#   {'type': 'node',
#    'id': 573226688,
#    'lat': 57.1961165,
#    'lon': 52.6959832,
#    'tags': {'admin_level': '4',
#     'alt_name': 'Удмуртская республика',
#     'int_name': 'Udmurtia',
#     'name': 'Удмуртия',
#     'name:ba': 'Удмурт Республикаһы',
#     'name:be': 'Удмуртыя',
#     'name:de': 'Udmurtien',
#     'name:en': 'Udmurtia',
#     'name:eo': 'Udmurtio',
#     'name:es': 'República de Udmurtia',
#     'name:fr': 'Oudmourtie',
#     'name:hu': 'Udmurtföld',
#     'name:ja': 'ウドムルト共和国',
#     'name:lt': 'Udmurtija',
#     'name:pl': 'Udmurcja',
#     'name:ru': 'Удмуртия',
#     'name:sk': 'Udmurtsko',
#     'name:uk': 'Удмуртія',
#     'official_name': 'Удмуртская Республика',
#     'official_name:be': 'Удмуртская Рэспубліка',
#     'official_name:de': 'Republik Udmurtien',
#     'official_name:en': 'Udmurt Republic',
#     'official_name:fr': "République d'Oudmourtie",
#     'official_name:ru': 'Удмуртская Республика',
#     'official_name:sk': 'Udmurtská republika',
#     'place': 'state',
#     'ref': 'УДМ',
#     'ref:en': 'UD',
#     'wikidata': 'Q5422',
#     'wikipedia': 'ru:Удмуртия'}},
#   {'type': 'node',
#    'id': 577359740,
#    'lat': 60.0391461,
#    'lon': 43.1215213,
#    'tags': {'name': 'Вологодская область',
#     'name:be': 'Валагодская вобласць',
#     'name:de': 'Oblast Wologda',
#     'name:en': 'Vologda Oblast',
#     'name:eo': 'Vologda Provinco',
#     'name:es': 'Óblast de Vólogda',
#     'name:fr': 'Oblast de Vologda',
#     'name:ja': 'ヴォログダ州',
#     'name:lt': 'Vologdos sritis',
#     'name:pl': 'Obwód wołogodzki',
#     'name:ru': 'Вологодская область',
#     'name:tt': 'Вологда өлкәсе',
#     'name:uk': 'Вологодська область',
#     'place': 'state',
#     'ref': 'ВОЛ',
#     'ref:en': 'VLG',
#     'wikidata': 'Q2015',
#     'wikipedia': 'ru:Вологодская область'}},
#   {'type': 'node',
#    'id': 607014861,
#    'lat': 54.1463177,
#    'lon': 47.2324921,
#    'tags': {'name': 'Ульяновская область',
#     'name:be': 'Ульянаўская вобласць',
#     'name:cs': 'Uljanovská oblast',
#     'name:de': 'Oblast Uljanowsk',
#     'name:en': 'Ulyanovsk Oblast',
#     'name:eo': 'Uljanovska Provinco',
#     'name:es': 'Óblast de Uliánovsk',
#     'name:fr': "Oblast d'Oulianovsk",
#     'name:hu': 'Uljanovszki terület',
#     'name:ja': 'ウリヤノフスク州',
#     'name:lt': 'Uljanovsko sritis',
#     'name:pl': 'Obwód uljanowski',
#     'name:ru': 'Ульяновская область',
#     'name:sk': 'Ulianovská oblasť',
#     'name:tt': 'Сембер өлкәсе',
#     'name:uk': 'Ульяновська область',
#     'place': 'state',
#     'ref': 'УЛЬ',
#     'ref:en': 'ULY',
#     'wikidata': 'Q5634',
#     'wikipedia': 'ru:Ульяновская область'}},
#   {'type': 'node',
#    'id': 607014868,
#    'lat': 55.4259922,
#    'lon': 47.0849429,
#    'tags': {'admin_level': '4',
#     'name': 'Чувашия',
#     'name:be': 'Чувашыя',
#     'name:cs': 'Čuvašsko',
#     'name:de': 'Tschuwaschien',
#     'name:en': 'Chuvashia',
#     'name:eo': 'Ĉuvaŝio',
#     'name:es': 'Chuvasia',
#     'name:fr': 'Tchouvachie',
#     'name:hu': 'Csuvasföld',
#     'name:ja': 'チュヴァシ共和国',
#     'name:lt': 'Čiuvašija',
#     'name:pl': 'Czuwaszja',
#     'name:ru': 'Чувашия',
#     'name:sk': 'Čuvašsko',
#     'name:tt': 'Чуаш Республикасы',
#     'name:uk': 'Чуваська Республіка',
#     'official_name': 'Чувашская Республика',
#     'official_name:be': 'Чувашская Рэспубліка',
#     'official_name:de': 'Republik Tschuwaschien',
#     'official_name:en': 'Chuvash Republic — Chuvashia',
#     'official_name:es': 'República de Chuvasia',
#     'official_name:fr': 'République de Tchouvachie',
#     'official_name:ru': 'Чувашская Республика',
#     'official_name:sk': 'Čuvašská republika',
#     'place': 'state',
#     'ref': 'ЧУВ',
#     'ref:en': 'CU',
#     'wikidata': 'Q5466',
#     'wikipedia': 'ru:Чувашия'}},
#   {'type': 'node',
#    'id': 607014871,
#    'lat': 52.0269262,
#    'lon': 54.7276647,
#    'tags': {'name': 'Оренбургская область',
#     'name:ba': 'Ырымбур өлкәһе',
#     'name:be': 'Арэнбургская вобласць',
#     'name:cs': 'Orenburská oblast',
#     'name:de': 'Oblast Orenburg',
#     'name:en': 'Orenburg Oblast',
#     'name:eo': 'Orenburga Provinco',
#     'name:es': 'Óblast de Oremburgo',
#     'name:fr': "Oblast d'Orenbourg",
#     'name:hu': 'Orenburgi terület',
#     'name:ja': 'オレンブルク州',
#     'name:lt': 'Orenburgo sritis',
#     'name:pl': 'Obwód orenburski',
#     'name:ru': 'Оренбургская область',
#     'name:sk': 'Orenburská oblasť',
#     'name:tt': 'Ырынбур өлкәсе',
#     'name:uk': 'Оренбурзька область',
#     'place': 'state',
#     'ref': 'ОРЕ',
#     'ref:en': 'ORE',
#     'wikidata': 'Q5338',
#     'wikipedia': 'ru:Оренбургская область'}},
#   {'type': 'node',
#    'id': 607014878,
#    'lat': 56.5767504,
#    'lon': 47.8817512,
#    'tags': {'addr:country': 'RU',
#     'addr:region': 'Марий Эл',
#     'admin_level': '4',
#     'alt_name': 'Республика Марий Эл',
#     'alt_name:be': 'Рэспубліка Марый Эл',
#     'alt_name:de': 'Republik Mari El',
#     'alt_name:en': 'Mari El Republic',
#     'alt_name:ru': 'Республика Марий Эл',
#     'name': 'Марий Эл',
#     'name:be': 'Марый Эл',
#     'name:cs': 'Marijsko',
#     'name:de': 'Mari El',
#     'name:en': 'Mari El',
#     'name:eo': 'Mariio',
#     'name:es': 'Mari-El',
#     'name:fr': 'République des Maris',
#     'name:hu': 'Mariföld',
#     'name:ja': 'マリ・エル共和国',
#     'name:lt': 'Marių Respublika',
#     'name:ru': 'Марий Эл',
#     'name:sk': 'Marijsko',
#     'name:tt': 'Мари Ил',
#     'name:uk': 'Марій Ел',
#     'official_name:sk': 'Marijská republika',
#     'place': 'state',
#     'ref': 'МАР',
#     'ref:en': 'ME',
#     'wikidata': 'Q5446',
#     'wikipedia': 'ru:Марий Эл'}},
#   {'type': 'node',
#    'id': 608648126,
#    'lat': 67.6783253,
#    'lon': 57.0626853,
#    'tags': {'name': 'Ненецкий автономный округ',
#     'name:be': 'Ненецкая аўтаномная акруга',
#     'name:de': 'Autonomer Kreis der Nenzen',
#     'name:en': 'Nenets autonomous district',
#     'name:eo': 'Nenecio',
#     'name:es': 'Nenetsia',
#     'name:fr': 'Nénétsie',
#     'name:hu': 'Nyenyecföld',
#     'name:ja': 'ネネツ自治管区',
#     'name:lt': 'Nencų autonominė apygarda',
#     'name:pl': 'Nieniecki Okręg Autonomiczny',
#     'name:ru': 'Ненецкий автономный округ',
#     'name:tt': 'Ненец автономияле округы',
#     'name:uk': 'Ненецький автономний округ',
#     'official_name:es': 'Distrito autónomo de Nenetsia',
#     'official_name:fr': 'District autonome de Nénétsie',
#     'place': 'state',
#     'ref': 'НЕН',
#     'ref:en': 'NEN',
#     'wikidata': 'Q2164',
#     'wikipedia': 'ru:Ненецкий автономный округ'}},
#   {'type': 'node',
#    'id': 610739435,
#    'lat': 60.1853296,
#    'lon': 32.3925325,
#    'tags': {'addr:country': 'RU',
#     'name': 'Ленинградская область',
#     'name:be': 'Ленінградская вобласць',
#     'name:de': 'Oblast Leningrad',
#     'name:en': 'Leningrad Oblast',
#     'name:eo': 'Leningrada Provinco',
#     'name:es': 'Óblast de Leningrado',
#     'name:et': 'Leningradi oblast',
#     'name:fr': 'Oblast de Léningrad',
#     'name:pl': 'Obwód leningradzki',
#     'name:ru': 'Ленинградская область',
#     'name:sk': 'Leningradská oblasť',
#     'place': 'state',
#     'ref': 'ЛЕН',
#     'ref:en': 'LEN',
#     'wikidata': 'Q2191',
#     'wikipedia': 'ru:Ленинградская область'}},
#   {'type': 'node',
#    'id': 610739454,
#    'lat': 57.5358729,
#    'lon': 28.8586826,
#    'tags': {'is_in': 'Российская Федерация',
#     'name': 'Псковская область',
#     'name:be': 'Пскоўская вобласць',
#     'name:de': 'Oblast Pskow',
#     'name:en': 'Pskov Oblast',
#     'name:eo': 'Pskova Provinco',
#     'name:es': 'Óblast de Pskov',
#     'name:et': 'Pihkva oblast',
#     'name:fr': 'Oblast de Pskov',
#     'name:lt': 'Pskovo sritis',
#     'name:pl': 'Obwód pskowski',
#     'name:ru': 'Псковская область',
#     'name:uk': 'Псковська область',
#     'place': 'state',
#     'ref': 'ПСК',
#     'ref:en': 'PSK',
#     'wikidata': 'Q2218',
#     'wikipedia': 'ru:Псковская область'}},
#   {'type': 'node',
#    'id': 610739465,
#    'lat': 57.1134475,
#    'lon': 35.1744428,
#    'tags': {'is_in': 'Российская Федерация',
#     'name': 'Тверская область',
#     'name:be': 'Цвярская вобласць',
#     'name:de': 'Oblast Twer',
#     'name:en': 'Tver Oblast',
#     'name:eo': 'Tverja Provinco',
#     'name:es': 'Óblast de Tver',
#     'name:fr': 'Oblast de Tver',
#     'name:ja': 'トヴェリ州',
#     'name:lt': 'Tverės sritis',
#     'name:pl': 'Obwód twerski',
#     'name:ru': 'Тверская область',
#     'name:uk': 'Тверська область',
#     'place': 'state',
#     'ref': 'ТВЕ',
#     'ref:en': 'TVE',
#     'wikidata': 'Q2292',
#     'wikipedia': 'ru:Тверская область'}},
#   {'type': 'node',
#    'id': 618016965,
#    'lat': 55.7655302,
#    'lon': 64.5632681,
#    'tags': {'name': 'Курганская область',
#     'name:be': 'Курганская вобласць',
#     'name:de': 'Oblast Kurgan',
#     'name:en': 'Kurgan Oblast',
#     'name:eo': 'Kurgana Provinco',
#     'name:es': 'Óblast de Kurgán',
#     'name:fr': 'Oblast de Kourgan',
#     'name:hu': 'Kurgani terület',
#     'name:ja': 'クルガン州',
#     'name:lt': 'Kurgano sritis',
#     'name:pl': 'Obwód kurgański',
#     'name:ru': 'Курганская область',
#     'name:uk': 'Курганська область',
#     'place': 'state',
#     'ref': 'КУР',
#     'ref:en': 'KUG',
#     'wikidata': 'Q5741',
#     'wikipedia': 'ru:Курганская область'}},
#   {'type': 'node',
#    'id': 648753997,
#    'lat': 52.6935178,
#    'lon': 39.1122664,
#    'tags': {'addr:country': 'RU',
#     'name': 'Липецкая область',
#     'name:be': 'Ліпецкая вобласць',
#     'name:de': 'Oblast Lipezk',
#     'name:en': 'Lipetsk Oblast',
#     'name:eo': 'Lipecka Provinco',
#     'name:es': 'Óblast de Lípetsk',
#     'name:fr': 'Oblast de Lipetsk',
#     'name:ja': 'リペツク州',
#     'name:lt': 'Lipecko sritis',
#     'name:pl': 'Obwód lipiecki',
#     'name:ru': 'Липецкая область',
#     'name:tt': 'Липецк өлкәсе',
#     'name:uk': 'Липецька область',
#     'place': 'state',
#     'ref': 'ЛИП',
#     'ref:en': 'LIP',
#     'wikidata': 'Q3510',
#     'wikipedia': 'ru:Липецкая область'}},
#   {'type': 'node',
#    'id': 648753998,
#    'lat': 50.9800393,
#    'lon': 40.1506507,
#    'tags': {'name': 'Воронежская область',
#     'name:be': 'Варонежская вобласць',
#     'name:de': 'Oblast Woronesch',
#     'name:en': 'Voronezh Oblast',
#     'name:eo': 'Voroneĵa Provinco',
#     'name:es': 'Óblast de Vorónezh',
#     'name:fr': 'Oblast de Voronej',
#     'name:hu': 'Voronyezsi terület',
#     'name:it': "Oblast' di Voronež",
#     'name:ja': 'ヴォロネジ州',
#     'name:lt': 'Voronežo sritis',
#     'name:nl': 'Oblast Voronezj',
#     'name:pl': 'Obwód woroneski',
#     'name:pt': 'Oblast de Voronej',
#     'name:ru': 'Воронежская область',
#     'name:sv': 'Voronezj oblast',
#     'name:tt': 'Воронеж өлкәсе',
#     'name:uk': 'Воронезька область',
#     'name:zh': '沃罗涅日州',
#     'place': 'state',
#     'population': '2328959',
#     'ref': 'ВОР',
#     'ref:en': 'VOR',
#     'wikidata': 'Q3447',
#     'wikipedia': 'ru:Воронежская область'}},
#   {'type': 'node',
#    'id': 648753999,
#    'lat': 52.9019574,
#    'lon': 41.3578918,
#    'tags': {'name': 'Тамбовская область',
#     'name:be': 'Тамбоўская вобласць',
#     'name:de': 'Oblast Tambow',
#     'name:en': 'Tambov Oblast',
#     'name:eo': 'Tambova Provinco',
#     'name:es': 'Óblast de Tambov',
#     'name:fr': 'Oblast de Tambov',
#     'name:hu': 'Tambovi terület',
#     'name:ja': 'タンボフ州',
#     'name:lt': 'Tambovo sritis',
#     'name:pl': 'Obwód tambowski',
#     'name:ru': 'Тамбовская область',
#     'name:tt': 'Тамбов өлкәсе',
#     'name:uk': 'Тамбовська область',
#     'place': 'state',
#     'ref': 'ТАМ',
#     'ref:en': 'TAM',
#     'wikidata': 'Q3550',
#     'wikipedia': 'ru:Тамбовская область'}},
#   {'type': 'node',
#    'id': 658312593,
#    'lat': 55.5043158,
#    'lon': 38.0353929,
#    'tags': {'is_in:country_code': 'RU',
#     'name': 'Московская область',
#     'name:af': 'Moskou-oblast',
#     'name:ar': 'محافظة موسكو',
#     'name:az': 'Moskva vilayəti',
#     'name:ba': 'Мәскәү өлкәһе',
#     'name:be': 'Маскоўская вобласць',
#     'name:bg': 'Московска област',
#     'name:br': 'Oblast Moskov',
#     'name:bs': 'Moskovska oblast',
#     'name:ca': 'Província de Moscou',
#     'name:ce': 'Москван область',
#     'name:cs': 'Moskevská oblast',
#     'name:cu': 'Москъвьска область',
#     'name:cv': 'Мускав облаçĕ',
#     'name:cy': 'Oblast Moscfa',
#     'name:da': 'Moskva oblast',
#     'name:de': 'Oblast Moskau',
#     'name:el': 'Περιφέρεια Μόσχας',
#     'name:en': 'Moscow Oblast',
#     'name:eo': 'Moskva Provinco',
#     'name:es': 'Óblast de Moscú',
#     'name:et': 'Moskva oblast',
#     'name:eu': 'Moskuko oblasta',
#     'name:fa': 'استان مسکو',
#     'name:fi': 'Moskovan alue',
#     'name:fr': 'Oblast de Moscou',
#     'name:ga': 'Cúige Mhoscó',
#     'name:he': 'מוסקבה (מחוז)',
#     'name:hr': 'Moskovska oblast',
#     'name:hu': 'Moszkvai terület',
#     'name:hy': 'Մոսկվայի մարզ',
#     'name:id': 'Oblast Moskwa',
#     'name:it': "Oblast' di Mosca",
#     'name:ja': 'モスクワ州',
#     'name:ka': 'მოსკოვის ოლქი',
#     'name:ko': '모스크바 주',
#     'name:kv': 'Мӧскуа обласьт',
#     'name:ky': 'Москва областы',
#     'name:la': 'Regio Moscuensis',
#     'name:lt': 'Maskvos sritis',
#     'name:lv': 'Maskavas apgabals',
#     'name:mk': 'Московска област',
# ...
#     'name:de': 'Inguschetien',
#     'name:en': 'Ingushetia',
#     'name:eo': 'Inguŝio',
#     'name:et': 'Inguššia',
#     'name:fr': 'Ingouchie',
#     'name:hu': 'Ingusföld',
#     'name:inh': 'ГІалгІай Мохк',
#     'name:ku': 'Îngûşetya',
#     'name:ru': 'Ингушетия',
#     'name:zh': '印古什共和国',
#     'official_name:be': 'Рэспубліка Інгушэція',
#     'official_name:ru': 'Республика Ингушетия',
#     'place': 'state',
#     'ref': 'ИНГ',
#     'ref:en': 'IN',
#     'wikidata': 'Q5219',
#     'wikipedia': 'ru:Ингушетия'}},
#   {'type': 'node',
#    'id': 869609085,
#    'lat': 42.9920711,
#    'lon': 44.2636348,
#    'tags': {'is_in': 'Россия',
#     'name': 'Северная Осетия — Алания',
#     'name:af': 'Noord-Ossetië-Alanië',
#     'name:av': 'Шималияб Гьиристан',
#     'name:az': 'Şimali Osetiya',
#     'name:ba': 'Төньяҡ Осетия — Алания',
#     'name:be': 'Паўночная Асеція',
#     'name:bg': 'Северна Осетия',
#     'name:ca': 'Ossètia del Nord - Alània',
#     'name:ce': 'Къилбаседа ХӀирийчоь',
#     'name:cs': 'Severní Osetie-Alanie',
#     'name:cv': 'Çурçĕр Осети',
#     'name:da': 'Nordossetien–Alania',
#     'name:de': 'Nordossetien-Alanien',
#     'name:el': 'Δημοκρατία της Βόρειας Οσετίας - Αλανίας',
#     'name:en': 'North Ossetia-Alania',
#     'name:eo': 'Nord-Osetio',
#     'name:es': 'Osetia del Norte-Alania',
#     'name:et': 'Põhja-Osseetia',
#     'name:fi': 'Pohjois-Ossetia-Alania',
#     'name:fr': 'Ossétie du Nord-Alanie',
#     'name:gl': 'Osetia do Norte-Alania',
#     'name:hi': 'उत्तर ओसेतिया-आलानिया',
#     'name:hsb': 'Sewjerna Osetiska-Alanska',
#     'name:hu': 'Észak-Oszétia',
#     'name:hy': 'Հյուսիսային Օսիա',
#     'name:it': 'Ossezia Settentrionale-Alania',
#     'name:ja': '北オセチア共和国',
#     'name:ka': 'ჩრდილოეთი ოსეთი',
#     'name:kbd': 'Ишхъэрэ Iэсетиэ',
#     'name:krc': 'Шимал Тегей',
#     'name:ku': 'Osetyaya Bakur-Alanya',
#     'name:la': 'Ossetia Septentrionalis',
#     'name:lv': 'Ziemeļosetija-Alānija',
#     'name:nl': 'Noord-Ossetië',
#     'name:os': 'Цæгат Ирыстон',
#     'name:pl': 'Osetia Północna',
#     'name:pt': 'Ossétia do Norte-Alânia',
#     'name:ru': 'Северная Осетия',
#     'name:sk': 'Severné Osetsko',
#     'name:sv': 'Nordossetien',
#     'name:tt': 'Төньяк Осетия',
#     'name:uk': 'Північна Осетія',
#     'name:xal': 'Оседин таңһч',
#     'name:zh': '北奥塞梯-阿兰共和国',
#     'official_name': 'Республика Северная Осетия—Алания',
#     'official_name:be': 'Рэспубліка Паўночная Асеція',
#     'official_name:de': 'Republik Nordossetien-Alanien',
#     'official_name:os': 'Республикӕ Цӕгат Ирыстон-Алани',
#     'official_name:ru': 'Республика Северная Осетия—Алания',
#     'official_name:sk': 'Republika Severné Osetsko – Alánsko',
#     'place': 'state',
#     'ref': 'СЕВ',
#     'ref:en': 'NO',
#     'wikidata': 'Q5237',
#     'wikipedia': 'ru:Северная Осетия'}},
#   {'type': 'node',
#    'id': 869609474,
#    'lat': 43.4428286,
#    'lon': 43.4204809,
#    'tags': {'is_in': 'Россия',
#     'name': 'Кабардино-Балкария',
#     'name:be': 'Кабардзіна-Балкарыя',
#     'name:de': 'Kabardino-Balkarien',
#     'name:en': 'Kabardino-Balkaria',
#     'name:eo': 'Kabardio-Balkario',
#     'name:fr': 'Kabardino-Balkarie',
#     'name:hu': 'Kabardino-Balkaria',
#     'name:kbd': 'Къэбэрдей-Балъкъэр Республикэ',
#     'name:krc': 'Къабарты-Малкъар Республика',
#     'name:ku': 'Kabardîno-Balkarya',
#     'name:ru': 'Кабардино-Балкария',
#     'name:tt': 'Кабарда-Балкария',
#     'name:zh': '卡巴尔达—巴尔卡尔共和国',
#     'official_name': 'Кабардино-Балкарская Республика',
#     'official_name:be': 'Кабардзіна-Балкарская Рэспубліка',
#     'official_name:ru': 'Кабардино-Балкарская Республика',
#     'place': 'state',
#     'ref': 'КАБ',
#     'ref:en': 'KB',
#     'wikidata': 'Q5267',
#     'wikipedia': 'ru:Кабардино-Балкария'}},
#   {'type': 'node',
#    'id': 933435715,
#    'lat': 57.9665589,
#    'lon': 49.4074599,
#    'tags': {'alt_name': 'Кировская область',
#     'int_name': 'Kirov Oblast',
#     'is_in': 'Россия',
#     'name': 'Кировская область',
#     'name:be': 'Кіраўская вобласць',
#     'name:cs': 'Kirovská oblast',
#     'name:de': 'Oblast Kirow',
#     'name:en': 'Kirov Oblast',
#     'name:eo': 'Kirova Provinco',
#     'name:es': 'Óblast de Kírov',
#     'name:fr': 'Oblast de Kirov',
#     'name:hu': 'Kirovi terület',
#     'name:ja': 'キーロフ州',
#     'name:lt': 'Kirovo sritis',
#     'name:pl': 'Obwód kirowski',
#     'name:ru': 'Кировская область',
#     'name:sk': 'Kirovská oblasť',
#     'name:tt': 'Киров өлкәсе',
#     'name:uk': 'Кіровська область',
#     'place': 'state',
#     'ref': 'КИР',
#     'ref:en': 'KIR',
#     'wikidata': 'Q5387',
#     'wikipedia': 'ru:Кировская область'}},
#   {'type': 'node',
#    'id': 1103648780,
#    'lat': 54.4223954,
#    'lon': 61.1865846,
#    'tags': {'contact:facebook': 'https://www.facebook.com/gov74',
#     'contact:ok': 'https://ok.ru/gov74',
#     'contact:phone': '+7 351 2642504',
#     'contact:vk': 'https://vk.com/gov74',
#     'contact:website': 'https://pravmin74.ru',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/ce/Flag_of_Chelyabinsk_Oblast.svg',
#     'int_name': "Chelyabinskaya oblast'",
#     'name': 'Челябинская область',
#     'name:ace': 'Oblast Chelyabinsk',
#     'name:af': 'Tsjeljabinsk oblast',
#     'name:ar': 'أوبلاست تشيليابنسك',
#     'name:az': 'Çelyabinsk vilayəti',
#     'name:azb': 'چلیابینسک اوبلاستی',
#     'name:ba': 'Силәбе өлкәһе',
#     'name:be': 'Чалябінская вобласць',
#     'name:be-tarask': 'Чалябінская вобласьць',
#     'name:bg': 'Челябинска област',
#     'name:br': 'Oblast Tchelyabinsk',
#     'name:bs': 'Čeljabinska oblast',
#     'name:bxr': 'Челябинскын можо',
#     'name:ca': 'Província de Txeliàbinsk',
#     'name:cdo': 'Chelyabinsk Ciŭ',
#     'name:ce': 'Челябинскан область',
#     'name:ceb': "Chelyabinskaya Oblast'",
#     'name:cs': 'Čeljabinská oblast',
#     'name:cv': 'Челепи облаçĕ',
#     'name:cy': 'Oblast Chelyabinsk',
#     'name:da': 'Tjeljabinsk oblast',
#     'name:de': 'Oblast Tscheljabinsk',
#     'name:el': 'Όμπλαστ του Τσελιάμπινσκ',
#     'name:en': 'Chelyabinsk Oblast',
#     'name:eo': 'Ĉeljabinska Provinco',
#     'name:es': 'Óblast de Cheliábinsk',
#     'name:et': 'Tšeljabinski oblast',
#     'name:eu': 'Txeliabinsk oblasta',
#     'name:fa': 'استان چلیابینسک',
#     'name:fi': 'Tšeljabinskin alue',
#     'name:fr': 'Oblast de Tcheliabinsk',
#     'name:ga': 'Cúige Chelyabinsk',
#     'name:hak': 'Chelyabinsk-chû',
#     'name:hi': 'चेल्याबिन्स्क ओब्लास्त',
#     'name:hr': 'Čeljabinska oblast',
#     'name:hsb': 'Oblasć Čeljabinsk',
#     'name:hu': 'Cseljabinszki terület',
#     'name:hy': 'Չելյաբինսկի մարզ',
#     'name:id': 'Oblast Chelyabinsk',
#     'name:is': 'Tsjeljabinskfylki',
#     'name:it': "Oblast' di Čeljabinsk",
#     'name:ja': 'チェリャビンスク州',
#     'name:ka': 'ჩელიაბინსკის ოლქი',
#     'name:kaa': "Chelyabinsk wa'layatı",
#     'name:kk': 'Челябі облысы',
#     'name:ko': '첼랴빈스크주',
#     'name:kv': 'Челябинск обласьт',
#     'name:la': 'Regio Celiabinscensis',
#     'name:lrc': 'آستوݩ چلیابینسک',
#     'name:lt': 'Čeliabinsko sritis',
#     'name:lv': 'Čeļabinskas apgabals',
#     'name:mhr': 'Челябинск вел',
#     'name:mk': 'Чељабинска област',
#     'name:mn': 'Челябинск муж',
#     'name:mr': 'चेलियाबिन्स्क ओब्लास्त',
#     'name:ms': 'Wilayah Chelyabinsk',
#     'name:myv': 'Челябань ёнкс',
#     'name:nl': 'Oblast Tsjeljabinsk',
#     'name:nn': 'Tsjeljabinsk oblast',
#     'name:no': 'Tsjeljabinsk oblast',
#     'name:oc': 'Óblast de Cheliabinsk',
#     'name:os': 'Челябинсчы облæст',
#     'name:pam': 'Chelyabinsk Oblast',
#     'name:pl': 'Obwód czelabiński',
#     'name:pnb': 'چیلیابنسک اوبلاست',
#     'name:pt': 'Oblast de Tcheliabinsk',
#     'name:ro': 'Regiunea Celeabinsk',
#     'name:ru': 'Челябинская область',
#     'name:sah': 'Челябинскай уобалас',
#     'name:sco': 'Chelyabinsk Oblast',
#     'name:se': 'Tjeljabinsk oblast',
#     'name:sh': 'Čeljabinska oblast',
#     'name:simple': 'Chelyabinsk Oblast',
#     'name:sk': 'Čeľabinská oblasť',
#     'name:sl': 'Čeljabinska oblast',
#     'name:sr': 'Чељабинска област',
#     'name:sv': 'Tjeljabinsk oblast',
#     'name:sw': 'Chelyabinsk Oblast',
#     'name:ta': 'செல்யாபின்சுக் மாகாணம்',
#     'name:tg': 'Вилояти Челябинск',
#     'name:tl': 'Chelyabinsk Oblast',
#     'name:tr': 'Çelyabinsk Oblastı',
#     'name:tt': 'Чиләбе өлкәсе',
#     'name:udm': 'Челябинск улос',
#     'name:uk': 'Челябінська область',
#     'name:ur': 'چیلیابنسک اوبلاست',
#     'name:uz': 'Chelyabinsk viloyati',
#     'name:vep': 'Čeläbinskan agj',
#     'name:vi': 'Chelyabinsk tỉnh',
#     'name:war': 'Chelyabinsk Oblast',
#     'name:wuu': '车里雅宾斯克州',
#     'name:xal': 'Челябинска төгәлң',
#     'name:xmf': 'ჩელიაბინსკიშ ოლქი',
#     'name:yue': '車里雅賓斯克州',
#     'name:zh': '车里雅宾斯克州',
#     'name:zh_min_nan': 'Chelyabinsk Chiu',
#     'place': 'state',
#     'population': '3466369',
#     'population:date': '2020',
#     'ref': 'ЧЕЛ',
#     'wikidata': 'Q5714',
#     'wikipedia': 'ru:Челябинская область'}},
#   {'type': 'node',
#    'id': 1806706046,
#    'lat': 56.9167446,
#    'lon': 41.4352137,
#    'tags': {'is_in': 'Российская Федерация',
#     'name': 'Ивановская область',
#     'name:be': 'Іванаўская вобласць',
#     'name:de': 'Oblast Iwanowo',
#     'name:en': 'Ivanovo Oblast',
#     'name:eo': 'Ivanova Provinco',
#     'name:es': 'Óblast de Ivánovo',
#     'name:fr': "Oblast d'Ivanovo",
#     'name:hu': 'Ivanovói terület',
#     'name:ja': 'イヴァノヴォ州',
#     'name:lt': 'Ivanovo sritis',
#     'name:pl': 'Obwód iwanowski',
#     'name:ru': 'Ивановская область',
#     'name:uk': 'Івановська область',
#     'place': 'state',
#     'ref': 'ИВА',
#     'wikidata': 'Q2654',
#     'wikipedia': 'ru:Ивановская область'}},
#   {'type': 'node',
#    'id': 2050243275,
#    'lat': 59.9606739,
#    'lon': 30.1586551,
#    'tags': {'name': 'Санкт-Петербург',
#     'name:ab': 'Санқт-Петербург',
#     'name:de': 'Sankt Petersburg',
#     'name:en': 'Saint Petersburg',
#     'name:eo': 'Sankt-Peterburgo',
#     'name:fi': 'Pietari',
#     'name:os': 'Бетъырбух',
#     'name:ru': 'Санкт-Петербург',
#     'name:sk': 'Petrohrad',
#     'official_status': 'ru:город федерального значения',
#     'okato:user': '40000000000',
#     'place': 'state',
#     'ref': 'СПБ',
#     'ref:en': 'SPE',
#     'ref:ru': 'СПБ',
#     'wikidata': 'Q656',
#     'wikipedia': 'ru:Санкт-Петербург'}},
#   {'type': 'node',
#    'id': 2452912060,
#    'lat': 55.4792046,
#    'lon': 37.3273304,
#    'tags': {'int_name': 'Moscow',
#     'name': 'Москва',
#     'name:de': 'Moskau',
#     'name:en': 'Moscow',
#     'name:eo': 'Moskvo',
#     'name:es': 'Moscú',
#     'name:fr': 'Moscou',
#     'name:hu': 'Moszkva',
#     'name:it': 'Mosca',
#     'name:ja': 'モスクワ連邦市',
#     'name:nl': 'Moskou',
#     'name:pl': 'Moskwa',
#     'name:pt': 'Moscovo',
#     'name:ru': 'Москва',
#     'name:sk': 'Moskva',
#     'name:sv': 'Moskva',
#     'official_status': 'ru:город федерального значения',
#     'place': 'state',
#     'ref': 'МСК',
#     'ref:en': 'MSK',
#     'ref:ru': 'МСК',
#     'wikidata': 'Q649',
#     'wikipedia': 'ru:Москва'}},
#   {'type': 'node',
#    'id': 2898654909,
#    'lat': 45.1890034,
#    'lon': 34.7401104,
#    'tags': {'addr:country': 'RU',
#     'name': 'Республика Крым',
#     'name:crh': 'Qırım Cumhuriyeti',
#     'name:cs': 'Republika Krym',
#     'name:de': 'Republik Krim',
#     'name:en': 'Republic of Crimea',
#     'name:fr': 'République de Crimée',
#     'name:nl': 'Republiek de Krim',
#     'name:pl': 'Republika Krymu',
#     'name:ru': 'Республика Крым',
#     'name:sk': 'Republika Krym',
#     'name:tr': 'Kırım Cumhuriyeti',
#     'name:uk': 'Республіка Крим',
#     'name:zh': '克里米亚共和国',
#     'place': 'state',
#     'ref': 'КРЫ',
#     'wikidata': 'Q15966495',
#     'wikipedia': 'ru:Республика Крым',
#     'wikipedia:ru': 'Республика Крым',
#     'wikipedia:uk': 'Республіка Крим'}},
#   {'type': 'node',
#    'id': 3140016266,
#    'lat': 45.7684014,
#    'lon': 39.0261044,
#    'tags': {'admin_level': '4',
#     'name': 'Краснодарский край',
#     'name:af': 'Krasnodar-krai',
#     'name:ar': 'كراسنودار كراي',
#     'name:ca': 'Territori de Krasnodar',
#     'name:cs': 'Krasnodarský kraj',
#     'name:de': 'Region Krasnodar',
#     'name:el': 'Κράι Κρασνοντάρ',
#     'name:en': 'Krasnodar Krai',
#     'name:eo': 'Krasnodara regiono',
#     'name:es': 'Krai de Krasnodar',
#     'name:fi': 'Krasnodarin aluepiiri',
#     'name:fr': 'Kraï de Krasnodar',
#     'name:he': 'קרסנודאר (מחוז)',
#     'name:hi': 'क्रास्नोदार क्राय',
#     'name:hr': 'Krasnodarski kraj',
#     'name:hu': 'Krasznodari határterület',
#     'name:is': 'Krasnodarfylki',
#     'name:it': 'Territorio di Krasnodar',
#     'name:ja': 'クラスノダール地方',
#     'name:ko': '크라스노다르 지방',
#     'name:ms': 'Jajahan Krasnodar',
#     'name:nn': 'Krasnodar kraj',
#     'name:no': 'Krasnodar kraj',
#     'name:pl': 'Kraj Krasnodarski',
#     'name:sk': 'Krasnodarský kraj',
#     'name:sr': 'Краснодарска Покрајина',
#     'name:sv': 'Krasnodar kraj',
#     'name:ta': 'கிராஸ்னதார் பிரதேசம்',
#     'name:tr': 'Krasnodar Krayı',
#     'name:uk': 'Краснодарський край',
#     'name:ur': 'کریسنوڈار کرائی',
#     'name:zh': '克拉斯诺达尔边疆区',
#     'place': 'state',
#     'ref': 'КРА',
#     'ref:en': 'KDA',
#     'wikidata': 'Q3680',
#     'wikipedia': 'ru:Краснодарский край'}},
#   {'type': 'node',
#    'id': 3674772325,
#    'lat': 44.5547288,
#    'lon': 33.4720239,
#    'tags': {'addr:postcode': '299000-299699',
#     'addr:region': 'Севастополь',
#     'addr:region:ru': 'Севастополь',
#     'addr:region:uk': 'Севастополь',
#     'int_name': 'Sevastopol',
#     'koatuu': '8500000000',
#     'name': 'Севастополь',
#     'name:ca': 'Sebastòpol',
#     'name:crh': 'Aqyar',
#     'name:cs': 'Sevastopol',
#     'name:de': 'Sewastopol',
#     'name:el': 'Σεβαστούπολη',
#     'name:en': 'Sevastopol',
#     'name:es': 'Sebastopol',
#     'name:fr': 'Sébastopol',
#     'name:hr': 'Sevastopolj',
#     'name:hu': 'Szevasztopol',
#     'name:it': 'Sebastopoli',
#     'name:kn': 'ಸೆವಸ್ತೋಪೊಲ್',
#     'name:la': 'Sebastopolis',
#     'name:lt': 'Sevastopolis',
#     'name:lv': 'Sevastopole',
#     'name:nl': 'Sebastopol',
#     'name:pl': 'Sewastopol',
#     'name:prefix': 'город',
#     'name:pt': 'Sebastopol',
#     'name:ro': 'Sevastopol',
#     'name:ru': 'Севастополь',
#     'name:sk': 'Sevastopoľ',
#     'name:tr': 'Sivastopol',
#     'name:uk': 'Севастополь',
#     'place': 'state',
#     'population': '402135',
#     'population:date': '2015',
#     'ref': 'СВС'}},
#   {'type': 'node',
#    'id': 4418300334,
#    'lat': 54.4419829,
#    'lon': 44.4661144,
#    'tags': {'ISO3166-2': 'RU-MO',
#     'addr:country': 'RU',
#     'int_name': 'Republic of Mordovia',
#     'int_ref': 'RU-MO',
#     'is_in:continent': 'Asia',
#     'is_in:country': 'Russia',
#     'is_in:country_code': 'RU',
#     'name': 'Мордовия',
#     'name:ca': 'Mordòvia',
#     'name:cs': 'Mordvinsko',
#     'name:de': 'Republik Mordwinien',
#     'name:en': 'Republic of Mordovia',
#     'name:fr': 'République de Mordovie',
#     'name:ja': 'モルドヴィア共和国',
#     'name:lt': 'Mordvijos Respublika',
#     'name:mhr': 'Мордовий',
#     'name:mrj': 'Мордови Республика',
#     'name:myv': 'Мордовия республикась',
#     'name:pl': 'Republika Mordowii',
#     'name:ru': 'Мордовия',
#     'name:sk': 'Mordviansko',
#     'official_name:sk': 'Mordvianska republika',
#     'official_status': 'ru:республика',
#     'place': 'state',
#     'ref': 'RU-MO',
#     'wikidata': 'Q5340',
#     'wikipedia': 'ru:Мордовия'}},
#   {'type': 'node',
#    'id': 6307688872,
#    'lat': 63.5589686,
#    'lon': 43.1221646,
#    'tags': {'ISO3166-2': 'RU-ARK',
#     'admin_level': '4',
#     'gost_7.67-2003': 'РОФ-АРХ',
#     'int_name': 'Arkhangelsk Oblast',
#     'int_ref': 'RU-ARK',
#     'is_in:country_code': 'RU',
#     'name': 'Архангельская область',
#     'name:be': 'Архангельская вобласць',
#     'name:ca': "Regió d'Arkhangelsk",
#     'name:cs': 'Archangelská oblast',
#     'name:de': 'Oblast Archangelsk',
#     'name:en': 'Arkhangelsk Oblast',
#     'name:eo': 'Regiono de Arkhangelsk',
#     'name:es': 'Región de Arkhangelsk',
#     'name:fi': 'Arkangelin alue',
#     'name:fr': "Région d'Arkhangelsk",
#     'name:hr': 'Arkhangelsk regija',
#     'name:hu': 'Arhangelszki terület',
#     'name:ja': 'アルハンゲリスク州',
#     'name:lt': 'Archangelsko sritis',
#     'name:pl': 'Obwód archangielski',
#     'name:ru': 'Архангельская область',
#     'name:sk': 'Archangeľská oblasť',
#     'name:sr': 'Аркхангелск регион',
#     'name:sv': 'Archangelsk oblast',
#     'name:uk': 'Архангельська область',
#     'place': 'state',
#     'ref': 'АРХ',
#     'ref:en': 'ARK',
#     'wikidata': 'Q1875',
#     'wikipedia': 'ru:Архангельская область'}}]}

# %%
len(data_regions['elements'])
# Out:
# 85

# %% [raw]
# with open("data_regions.json", "w") as f:
#     json.dump(data_8, f)

# %%
type_regions = []
lon_regions = []
lat_regions = []
name_regions = []
population_regions = []



for element in data_regions['elements']:
  

    if element['type'] == 'node':
        
        type_regions.append(element['type'])
        
        lon_regions.append(element['lon'])

        lat_regions.append(element['lat'])

        name_regions.append(element['tags']['name'])

        try:
            population_regions.append(element['tags']['population'])
        except Exception:
            population_regions.append(None)
 

    elif 'center' in element:

        type_regions.append(element['type'])
        
        lon_regions.append(element['center']['lon'])

        lat_regions.append(element['center']['lat'])

        name_regions.append(element['tags']['name'])

        try:
            population_regions.append(element['population'])
        except Exception:
            population_regions.append(None)
  


df_regions = pd.DataFrame(data={'type':type_regions,'lon':lon_regions,'lat':lat_regions,'name':name_regions,'population':population_regions})

# %%
df_regions
# Отутствует 'Дагестан'
# Out:
#     type         lon        lat                                      name  \
# 0   node  134.726645  45.081946                           Приморский край
# 1   node  128.437295  52.803237                          Амурская область
# 2   node   82.047532  58.612428                           Томская область
# 3   node   74.341549  67.147163           Ямало-Ненецкий автономный округ
# 4   node   68.641816  61.879343  Ханты-Мансийский автономный округ — Югра
# 5   node   70.365884  58.820649                         Тюменская область
# 6   node   73.509994  56.093526                            Омская область
# 7   node   79.481392  54.972017                     Новосибирская область
# 8   node   87.342861  54.533578                       Кемеровская область
# 9   node   82.693142  52.693224                            Алтайский край
# 10  node   86.857219  50.711410                          Республика Алтай
# 11  node   90.066430  53.439938                        Республика Хакасия
# 12  node   93.858259  51.401715                           Республика Тыва
# 13  node   97.097997  63.323381                         Красноярский край
# 14  node  104.719221  56.637012                         Иркутская область
# 15  node  109.492143  52.718243                                   Бурятия
# 16  node  115.956325  52.248521                        Забайкальский край
# 17  node  129.642371  66.941626                  Республика Саха (Якутия)
# 18  node   40.570525  54.422673                         Рязанская область
# 19  node  132.277566  48.560161              Еврейская автономная область
# 20  node  136.121524  51.631268                          Хабаровский край
# 21  node  143.448533  49.721967                       Сахалинская область
# 22  node  160.038382  57.191488                           Камчатский край
# 23  node  154.014726  63.551503                       Магаданская область
# 24  node  169.490087  66.000647                Чукотский автономный округ
# 25  node   21.148947  54.729304                   Калининградская область
# 26  node   32.516976  58.284383                      Новгородская область
# 27  node   50.891463  53.212881                         Самарская область
# 28  node   33.999915  68.000042                        Мурманская область
# 29  node   61.802155  58.641475                      Свердловская область
# 30  node   56.315955  58.595160                             Пермский край
# 31  node   54.332607  63.988142                                      Коми
# 32  node   33.492027  62.619403                        Республика Карелия
# 33  node   50.476359  55.448217                                 Татарстан
# 34  node   55.978458  54.474755                              Башкортостан
# 35  node   52.695983  57.196117                                  Удмуртия
# 36  node   43.121521  60.039146                       Вологодская область
# 37  node   47.232492  54.146318                       Ульяновская область
# 38  node   47.084943  55.425992                                   Чувашия
# 39  node   54.727665  52.026926                      Оренбургская область
# 40  node   47.881751  56.576750                                  Марий Эл
# 41  node   57.062685  67.678325                 Ненецкий автономный округ
# 42  node   32.392533  60.185330                     Ленинградская область
# 43  node   28.858683  57.535873                         Псковская область
# 44  node   35.174443  57.113447                          Тверская область
# 45  node   64.563268  55.765530                        Курганская область
# 46  node   39.112266  52.693518                          Липецкая область
# 47  node   40.150651  50.980039                       Воронежская область
# 48  node   41.357892  52.901957                        Тамбовская область
# 49  node   38.035393  55.504316                        Московская область
# 50  node   33.003199  45.535917                 Автономна Республіка Крим
# 51  node   40.795794  47.622245                        Ростовская область
# 52  node   44.787918  53.165542                        Пензенская область
# 53  node   44.253327  58.424756                       Костромская область
# 54  node   39.002110  57.778198                       Ярославская область
# 55  node   33.019207  55.034350                        Смоленская область
# 56  node   36.425171  52.839276                         Орловская область
# 57  node   33.415853  52.887332                          Брянская область
# 58  node   44.290358  49.604834                     Волгоградская область
# 59  node   47.608851  47.187819                      Астраханская область
# 60  node   45.327574  46.231302                       Республика Калмыкия
# 61  node   37.583762  50.708012                      Белгородская область
# 62  node   36.485270  51.656845                           Курская область
# 63  node   35.527285  54.438277                         Калужская область
# 64  node   37.369091  53.957070                          Тульская область
# 65  node   40.656163  56.050334                      Владимирская область
# 66  node   44.091159  55.471803                     Нижегородская область
# 67  node   46.863195  51.652056                       Саратовская область
# 68  node   43.440691  44.863258                       Ставропольский край
# 69  node   40.152042  44.693901                                    Адыгея
# 70  node   41.726799  43.736833                        Карачаево-Черкесия
# 71  node   45.698501  43.397615                                     Чечня
# 72  node   44.979682  43.165531                                 Ингушетия
# 73  node   44.263635  42.992071                  Северная Осетия — Алания
# 74  node   43.420481  43.442829                        Кабардино-Балкария
# 75  node   49.407460  57.966559                         Кировская область
# 76  node   61.186585  54.422395                       Челябинская область
# 77  node   41.435214  56.916745                        Ивановская область
# 78  node   30.158655  59.960674                           Санкт-Петербург
# 79  node   37.327330  55.479205                                    Москва
# 80  node   34.740110  45.189003                           Республика Крым
# 81  node   39.026104  45.768401                        Краснодарский край
# 82  node   33.472024  44.554729                               Севастополь
# 83  node   44.466114  54.441983                                  Мордовия
# 84  node   43.122165  63.558969                     Архангельская область
#
#    population
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21     490181
# 22     319864
# 23       None
# 24       None
# 25     937000
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
# 31       None
# 32       None
# 33       None
# 34       None
# 35       None
# 36       None
# 37       None
# 38       None
# 39       None
# 40       None
# 41       None
# 42       None
# 43       None
# 44       None
# 45       None
# 46       None
# 47    2328959
# 48       None
# 49       None
# 50       None
# 51       None
# 52       None
# 53       None
# 54       None
# 55       None
# 56       None
# 57       None
# 58       None
# 59       None
# 60       None
# 61       None
# 62       None
# 63       None
# 64       None
# 65       None
# 66       None
# 67       None
# 68       None
# 69       None
# 70       None
# 71       None
# 72       None
# 73       None
# 74       None
# 75       None
# 76    3466369
# 77       None
# 78       None
# 79       None
# 80       None
# 81       None
# 82     402135
# 83       None
# 84       None

# %%
df_regions['type'].unique()
# Out:
# array(['node'], dtype=object)

# %% [raw]
# df_regions.to_csv('data_regions.csv', sep=';')

# %%
r = 'abc'
a = '''
    [out:json];
    area
        ["boundary"="administrative"]
        ["name"="''' + r + '''"]
        ->.a;
    (
        node["place"~"town|city"](area.a);
        way["place"~"town|city"](area.a);
        relation["place"~"town|city"](area.a);
    );
    out center;
    '''

a
# Out:
# '\n    [out:json];\n    area\n        ["boundary"="administrative"]\n        ["name"="abc"]\n        ->.a;\n    (\n        node["place"~"town|city"](area.a);\n        way["place"~"town|city"](area.a);\n        relation["place"~"town|city"](area.a);\n    );\n    out center;\n    '

# %%
regions_to_load = ['Республика Бурятия', 'Республика Коми'] # 'Дагестан'

# %%
type_ = []
lon_ = []
lat_ = []
region_ = []
region2_ = []
name_ = []
population_ = []
u = []



for r in regions_to_load: # df_regions['name']: #[:3]: 


    response_ = requests.get(overpass_url, 
                        params={'data': 
                                    '''
                                    [out:json][timeout:1500];
                                    area
                                        ["boundary"="administrative"]
                                        ["name"="''' + r + '''"]
                                        ->.a;
                                    (
                                        node["place"~"town|city"](area.a);
                                        way["place"~"town|city"](area.a);
                                        relation["place"~"town|city"](area.a);
                                    );
                                    out center;
                                    '''
                                })


    try:
        data_ = response_.json()
    except Exception:
        data_ = None



    if data_:


        with open("data_cities_"+r+".json", "w") as f:
            json.dump(data_, f)


        for element in data_['elements']:


            if element['type'] == 'node':

                region_.append(r)

                type_.append(element['type'])

                lon_.append(element['lon'])

                lat_.append(element['lat'])

                try:
                    region2_.append(element['tags']['addr:region'])
                except Exception:
                    region2_.append(None)

                try:
                    name_.append(element['tags']['name'])
                except Exception:
                    name_.append(None)

                try:
                    population_.append(element['tags']['population'])
                except Exception:
                    population_.append(None)


            elif 'center' in element:

                region_.append(r)

                type_.append(element['type'])

                lon_.append(element['center']['lon'])

                lat_.append(element['center']['lat'])

                try:
                    region2_.append(element['tags']['addr:region'])
                except Exception:
                    region2_.append(None)

                try:
                    name_.append(element['tags']['name'])
                except Exception:
                    name_.append(None)

                try:
                    population_.append(element['population'])
                except Exception:
                    population_.append(None)


                    
df_cities = pd.DataFrame(data={'type':type_,'lon':lon_,'lat':lat_,'region':region_,'region2':region2_,'name':name_,'population':population_})

# %%
df_cities.head()
# Out:
#    type         lon        lat              region  region2             name  \
# 0  node  108.270615  51.834293  Республика Бурятия  Бурятия        Заиграево
# 1  node  109.335648  55.635967  Республика Бурятия  Бурятия  Северобайкальск
# 2  node  106.527008  51.289516  Республика Бурятия  Бурятия     Гусиноозёрск
# 3  node  106.449150  50.353176  Республика Бурятия  Бурятия            Кяхта
# 4  node  106.654320  52.055408  Республика Бурятия  Бурятия          Кабанск
#
#   population
# 0       5362
# 1      23673
# 2      23280
# 3      20013
# 4       6373

# %%
df_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   type        117 non-null    object
#  1   lon         117 non-null    float64
#  2   lat         117 non-null    float64
#  3   region      117 non-null    object
#  4   region2     79 non-null     object
#  5   name        117 non-null    object
#  6   population  58 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 6.5+ KB

# %%
df_cities.groupby('region').size()
# Out:
# region
# Республика Бурятия    58
# Республика Коми       59
# dtype: int64

# %%
directory = 'C:\\Users\\User\\data_cities'

# %%
files = os.listdir(directory)

# %%
len(files)
# Out:
# 86

# %%
files_json = [f for f in os.listdir(directory) if f.endswith('.json')]

# %%
len(files_json)
# Out:
# 86

# %%
type_ = []
lon_ = []
lat_ = []
region_ = []
region2_ = []
name_ = []
population_ = []
i=0



while i < len(files_json):
       
        
    with open(directory + '\\' + files_json[i], "r") as file_json_i:
        
        
        data_ = json.load(file_json_i)

        
        for element in data_['elements']:


            if element['type'] == 'node':

                region_.append(files_json[i][12:-5])
                
                type_.append(element['type'])

                lon_.append(element['lon'])

                lat_.append(element['lat'])

                try:
                    region2_.append(element['tags']['addr:region'])
                except Exception:
                    region2_.append('n/d')

                try:
                    name_.append(element['tags']['name'])
                except Exception:
                    name_.append('n/d')

                try:
                    population_.append(element['tags']['population'])
                except Exception:
                    population_.append('n/d')


            elif 'center' in element:

                region_.append(files_json[i][12:-5])
                
                type_.append(element['type'])

                lon_.append(element['center']['lon'])

                lat_.append(element['center']['lat'])

                try:
                    region2_.append(element['tags']['addr:region'])
                except Exception:
                    region2_.append('n/d')

                try:
                    name_.append(element['tags']['name'])
                except Exception:
                    name_.append('n/d')

                try:
                    population_.append(element['population'])
                except Exception:
                    population_.append('n/d')
                    
                    
                    
    i+=1
                    
                    
                    
df_cities2 = pd.DataFrame(data={'type':type_,'lon':lon_,'lat':lat_,'region':region_,'region2':region2_,'name':name_,'population':population_})

# %%
df_cities2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5386 entries, 0 to 5385
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   type        5386 non-null   object
#  1   lon         5386 non-null   float64
#  2   lat         5386 non-null   float64
#  3   region      5386 non-null   object
#  4   region2     5386 non-null   object
#  5   name        5386 non-null   object
#  6   population  5386 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 294.7+ KB

# %%
df_cities2.groupby('region').size()
# Out:
# region
# Автономна Республіка Крим                   142
# Адыгея                                       24
# Алтайский край                              122
# Амурская область                             46
# Архангельская область                        50
# Астраханская область                         25
# Башкортостан                                117
# Белгородская область                         58
# Брянская область                             56
# Владимирская область                         56
# Волгоградская область                        80
# Вологодская область                          54
# Воронежская область                          74
# Дагестан                                     98
# Еврейская автономная область                 14
# Забайкальский край                           62
# Ивановская область                           46
# Ингушетия                                    26
# Иркутская область                            95
# Кабардино-Балкария                           32
# Калининградская область                      48
# Калужская область                            64
# Камчатский край                              12
# Карачаево-Черкесия                           18
# Кемеровская область                          74
# Кировская область                           104
# Костромская область                          50
# Краснодарский край                          194
# Красноярский край                           112
# Курганская область                           51
# Курская область                              58
# Ленинградская область                       124
# Липецкая область                             28
# Магаданская область                          20
# Марий Эл                                     32
# Мордовия                                     38
# Москва                                       18
# Московская область                          254
# Мурманская область                           44
# Ненецкий автономный округ                     6
# Нижегородская область                       128
# Новгородская область                         32
# Новосибирская область                        74
# Омская область                               68
# Оренбургская область                         77
# Орловская область                            45
# Пензенская область                           65
# Пермский край                               104
# Приморский край                              87
# Псковская область                            48
# Республика Алтай                             22
# Республика Бурятия                           58
# Республика Калмыкия                          24
# Республика Карелия                           32
# Республика Коми                              59
# Республика Крым                             142
# Республика Саха (Якутия)                     78
# Республика Тыва                              15
# Республика Хакасия                           30
# Ростовская область                          104
# Рязанская область                            60
# Самарская область                            69
# Санкт-Петербург                              34
# Саратовская область                          74
# Сахалинская область                          38
# Свердловская область                        146
# Севастополь                                   8
# Северная Осетия — Алания                     14
# Смоленская область                           50
# Ставропольский край                          69
# Тамбовская область                           41
# Татарстан                                   101
# Тверская область                             90
# Томская область                              41
# Тульская область                             60
# Тюменская область                            48
# Удмуртия                                     50
# Ульяновская область                          56
# Хабаровский край                             52
# Ханты-Мансийский автономный округ — Югра     82
# Челябинская область                         105
# Чечня                                        70
# Чувашия                                      44
# Чукотский автономный округ                    8
# Ямало-Ненецкий автономный округ              30
# Ярославская область                          28
# dtype: int64

# %%
def f_space(text):
    if pd.isnull(text):
        b = None
    elif text == 'n/d':
        b = None
    else:
        b = text.split()
        b = ''.join(b)
    return b

# %%
df_cities2['population']=df_cities2['population'].apply(f_space)

# %%
df_cities2['population']=pd.to_numeric(df_cities2['population'], downcast='float')

# %%
df_cities2.to_csv('data_cities.csv', sep=';')

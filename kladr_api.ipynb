# %%
# !pip install requests-cache folium
# !pip install git+https://github.com/python-visualization/branca.git@master
# Out:
# Collecting requests-cache
#   Downloading requests_cache-0.5.2-py2.py3-none-any.whl (22 kB)
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
# Requirement already satisfied: requests>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from requests-cache) (2.22.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\anaconda3\lib\site-packages (from folium) (2.11.1)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=1.1.0->requests-cache) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=1.1.0->requests-cache) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=1.1.0->requests-cache) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=1.1.0->requests-cache) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: requests-cache, branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0 requests-cache-0.5.2
# Collecting git+https://github.com/python-visualization/branca.git@master
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to c:\users\user\appdata\local\temp\pip-req-build-4c7ci9la
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from branca==0.4.1+3.g5887b9b) (2.11.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->branca==0.4.1+3.g5887b9b) (1.1.1)
# Building wheels for collected packages: branca
#   Building wheel for branca (setup.py): started
#   Building wheel for branca (setup.py): finished with status 'done'
#   Created wheel for branca: filename=branca-0.4.1+3.g5887b9b-py3-none-any.whl size=24648 sha256=5fe63322c0e5c2984dd9db777e80106606519a5682437347885c49f015deb565
#   Stored in directory: C:\Users\User\AppData\Local\Temp\pip-ephem-wheel-cache-7sa_vqxl\wheels\85\a6\81\3e8d0268702f43fb673810ff4073542c67206538348984335b
# Successfully built branca
# Installing collected packages: branca
#   Attempting uninstall: branca
#     Found existing installation: branca 0.4.1
#     Uninstalling branca-0.4.1:
#       Successfully uninstalled branca-0.4.1
# Successfully installed branca-0.4.1+3.g5887b9b
#   Running command git clone -q https://github.com/python-visualization/branca.git 'C:\Users\User\AppData\Local\Temp\pip-req-build-4c7ci9la'

# %%
import requests
import requests_cache

import pandas as pd
import numpy as np

import folium
from folium.plugins import MarkerCluster
from folium.plugins import HeatMap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-8dc0256f8930> in <module>
#       9 from folium.plugins import HeatMap
#      10
# ---> 11 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
requests_cache.install_cache('api_cache', backend='sqlite', expire_after=900)

# %%
def kladr_to_address_api(kladr_id):   
  
    data = {
        "query": kladr_id
    }

    api_url = 'https://suggestions.dadata.ru/suggestions/api/4_1/rs/findById/fias'
    headers = {
        'content-type': 'application/json',
        'Authorization': 'Token 79abf89d58871ed1df79b83126f8f8c2362e51db'
    }
    response = requests.post(api_url, json=data, headers=headers)
    adress_json = response.json()
    adress_str = adress_json['suggestions'][0]['value']
    return adress_str

# %%
def address_to_geo_coord_api(address):
    r = requests.get(f'http://search.maps.sputnik.ru/search/addr?q={address}')
    response = r.json()
    coordinates = response['result']['address'][0]['features'][0]['geometry']['geometries'][0]['coordinates']
    coordinates = coordinates[::-1]
    return coordinates

# %%
kladr_list = [
    '0200000101500',
#     2700000100000,
#     5501900001100,
#     5501900001100,
#     2801800001600,
#     2801800001600,
#     2800000400000,
#     2800000400000,
#     3301000006100,
#     3800000300000,
#     5401700005600,
#     5003200002100,
#     5003200003000,
#     5401800000600,
#     5401800001000,
#     3813300000700,
#     3813300001000,
#     5003200003100,
#     5003200005100,
#     5401800001200,
#     5401900000200,
#     5003200006500,
#     5003200007300,
#     3813300001100,
#     3813300001200,
#     5401900001500,
#     5401900002800,
#     3813300001500,
#     3813300002000,
#     5003200009200,
#     5003200010000,
#     5401900002900,
#     5402000000400,
#     3813300003300,
#     3813300003600,
#     5003200010400,
#     5003200010700,
#     5402000000500,
#     5402000000800,
#     3813300003700,
#     3813300003800,
#     3813300004500,
#     4000000107200,
    '5003200011900'
]
df = pd.DataFrame({'kladr': kladr_list})
df
# Out:
#            kladr
# 0  0200000101500
# 1  5003200011900

# %%
addresses = []
coordinates = []
for kladr_id in kladr_list:
    address = kladr_to_address_api(kladr_id)
    addresses.append(address)
    coord = address_to_geo_coord_api(address)
    coordinates.append(coord)
    print(address, coord)
df['address'] = addresses
df['coordinates'] = coordinates
# Out:
# Респ Башкортостан, г Уфа, деревня Жилино [54.656384, 56.06246]
# Московская обл, г Серпухов, деревня Паниково [54.95071, 37.388958]

# %%
df['Rand'] = np.random.randint(0,2,size=(len(df), 1))

# %%
df['Color'] = 'green'
df['Color'].loc[df['Rand']==1] = 'red'
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['count']  = 1

# %%
df['latitude'],df['longitude']=zip(*df['coordinates'])

# %%
df
# Out:
#             kladr                                            address  \
# 0   2700000100000                      Хабаровский край, г Хабаровск
# 1   5501900001100            Омская обл, Одесский р-н, село Желанное
# 2   5501900001100            Омская обл, Одесский р-н, село Желанное
# 3   2801800001600      Амурская обл, Тамбовский р-н, село Муравьевка
# 4   2801800001600      Амурская обл, Тамбовский р-н, село Муравьевка
# 5   2800000400000                                Амурская обл, г Зея
# 6   2800000400000                                Амурская обл, г Зея
# 7   3301000006100  Владимирская обл, Меленковский р-н, деревня Ле...
# 8   3800000300000                           Иркутская обл, г Иркутск
# 9   5401700005600   Новосибирская обл, Кыштовский р-н, деревня Ядкан
# 10  5003200002100        Московская обл, г Серпухов, деревня Арнеево
# 11  5003200003000       Московская обл, г Серпухов, деревня Борисово
# 12  5401800000600  Новосибирская обл, Маслянинский р-н, село Боль...
# 13  5401800001000  Новосибирская обл, Маслянинский р-н, село Дубр...
# 14  3813300000700  Иркутская обл, Эхирит-Булагатский р-н, деревня...
# 15  3813300001000  Иркутская обл, Эхирит-Булагатский р-н, село Захал
# 16  5003200003100      Московская обл, г Серпухов, деревня Бутурлино
# 17  5003200005100       Московская обл, г Серпухов, деревня Дашковка
# 18  5401800001200   Новосибирская обл, Маслянинский р-н, село Елбань
# 19  5401900000200   Новосибирская обл, Мошковский р-н, деревня Балта
# 20  5003200006500        Московская обл, г Серпухов, деревня Зиброво
# 21  5003200007300          Московская обл, г Серпухов, село Игумново
# 22  3813300001100  Иркутская обл, Эхирит-Булагатский р-н, село Ка...
# 23  3813300001200  Иркутская обл, Эхирит-Булагатский р-н, деревня...
# 24  5401900001500      Новосибирская обл, Мошковский р-н, село Локти
# 25  5401900002800  Новосибирская обл, Мошковский р-н, поселок Радуга
# 26  3813300001500  Иркутская обл, Эхирит-Булагатский р-н, деревня...
# 27  3813300002000  Иркутская обл, Эхирит-Булагатский р-н, село Ту...
# 28  5003200009200      Московская обл, г Серпухов, деревня Лукьяново
# 29  5003200010000     Московская обл, г Серпухов, деревня Михайловка
# 30  5401900002900  Новосибирская обл, Мошковский р-н, село Сарапулка
# 31  5402000000400   Новосибирская обл, Ордынский р-н, село Вагайцево
# 32  3813300003300  Иркутская обл, Эхирит-Булагатский р-н, деревня...
# 33  3813300003600  Иркутская обл, Эхирит-Булагатский р-н, деревня...
# 34  5003200010400       Московская обл, г Серпухов, деревня Нефедово
# 35  5003200010700     Московская обл, г Серпухов, деревня Никифорово
# 36  5402000000500  Новосибирская обл, Ордынский р-н, село Верх-Алеус
# 37  5402000000800       Новосибирская обл, Ордынский р-н, село Кирза
# 38  3813300003700  Иркутская обл, Эхирит-Булагатский р-н, деревня...
# 39  3813300003800  Иркутская обл, Эхирит-Булагатский р-н, деревня...
# 40  3813300004500  Иркутская обл, Эхирит-Булагатский р-н, деревня...
# 41  4000000107200           Калужская обл, г Калуга, поселок Резвань
# 42  5003200011900       Московская обл, г Серпухов, деревня Паниково
#
#                 coordinates  Rand  Color  count   latitude   longitude
# 0    [48.481403, 135.07693]     1    red      1  48.481403  135.076930
# 1    [54.166344, 72.575775]     0  green      1  54.166344   72.575775
# 2    [54.166344, 72.575775]     0  green      1  54.166344   72.575775
# 3    [49.837215, 127.73236]     0  green      1  49.837215  127.732360
# 4    [49.837215, 127.73236]     1    red      1  49.837215  127.732360
# 5    [53.740356, 127.27162]     0  green      1  53.740356  127.271620
# 6    [53.740356, 127.27162]     1    red      1  53.740356  127.271620
# 7     [55.31677, 41.793613]     0  green      1  55.316770   41.793613
# 8    [52.289597, 104.28059]     1    red      1  52.289597  104.280590
# 9    [56.733883, 76.515045]     1    red      1  56.733883   76.515045
# 10    [54.915524, 37.41955]     1    red      1  54.915524   37.419550
# 11    [55.35957, 38.047356]     0  green      1  55.359570   38.047356
# 12    [54.514095, 84.27022]     0  green      1  54.514095   84.270220
# 13    [54.46441, 84.721375]     1    red      1  54.464410   84.721375
# 14   [52.92196, 104.562065]     1    red      1  52.921960  104.562065
# 15   [52.602913, 104.73313]     0  green      1  52.602913  104.733130
# 16    [54.92471, 37.484756]     1    red      1  54.924710   37.484756
# 17    [54.915524, 37.41955]     1    red      1  54.915524   37.419550
# 18    [54.318886, 84.59383]     0  green      1  54.318886   84.593830
# 19     [55.51369, 83.87484]     0  green      1  55.513690   83.874840
# 20    [54.915524, 37.41955]     0  green      1  54.915524   37.419550
# 21    [55.617462, 38.30447]     0  green      1  55.617462   38.304470
# 22    [52.68694, 104.64108]     1    red      1  52.686940  104.641080
# 23  [52.791546, 105.007935]     0  green      1  52.791546  105.007935
# 24    [55.268402, 83.18381]     1    red      1  55.268402   83.183810
# 25    [55.49763, 83.734474]     0  green      1  55.497630   83.734474
# 26   [52.671654, 104.71901]     1    red      1  52.671654  104.719010
# 27   [52.683163, 104.81234]     1    red      1  52.683163  104.812340
# 28   [54.872475, 37.424114]     0  green      1  54.872475   37.424114
# 29   [55.966698, 36.817646]     0  green      1  55.966698   36.817646
# 30   [55.158222, 83.750015]     1    red      1  55.158222   83.750015
# 31    [54.364994, 81.86246]     1    red      1  54.364994   81.862460
# 32    [53.229027, 105.3168]     1    red      1  53.229027  105.316800
# 33   [53.246384, 104.94238]     1    red      1  53.246384  104.942380
# 34     [56.14782, 36.29156]     0  green      1  56.147820   36.291560
# 35     [55.84437, 38.08948]     0  green      1  55.844370   38.089480
# 36   [54.175667, 81.268394]     1    red      1  54.175667   81.268394
# 37    [54.240887, 81.65425]     0  green      1  54.240887   81.654250
# 38   [53.274044, 104.95596]     1    red      1  53.274044  104.955960
# 39   [52.61272, 104.782265]     1    red      1  52.612720  104.782265
# 40  [52.803078, 104.557274]     0  green      1  52.803078  104.557274
# 41   [54.530582, 36.106823]     0  green      1  54.530582   36.106823
# 42    [54.95071, 37.388958]     0  green      1  54.950710   37.388958

# %%
map = folium.Map(location=[63, 75], zoom_start=3, width=900, height=400, control_scale=True)

for index, row in df.iterrows():
    folium.Marker(row['coordinates'], popup=row['address'], tooltip='click', icon=folium.Icon(color=row['Color'])).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_947841e5734a455d9e5271e5d4471815%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20900.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20400.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_947841e5734a455d9e5271e5d4471815%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_947841e5734a455d9e5271e5d4471815%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_947841e5734a455d9e5271e5d4471815%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B63.0%2C%2075.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20cr ...

# %%
map = folium.Map(location=[63, 75], zoom_start=3, width=900, height=400, control_scale=True)

for index, row in df.iterrows():
    folium.CircleMarker(location=row['coordinates'], radius = 3, popup=row['address'], fill_color=row['Color'], color=None, fill_opacity = 0.5).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4d162f257b434c959e58d096e5a4eea6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20900.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20400.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4d162f257b434c959e58d096e5a4eea6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4d162f257b434c959e58d096e5a4eea6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4d162f257b434c959e58d096e5a4eea6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B63.0%2C%2075.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20cr ...

# %%
map = folium.Map(location=[63, 75], zoom_start=3, width=900, height=400, control_scale=True)

marker_cluster = MarkerCluster().add_to(map)

for index, row in df.iterrows():
    folium.CircleMarker(location=row['coordinates'], radius = 3, popup=row['address'], fill_color=row['Color'], color=None, fill_opacity = 0.5).add_to(marker_cluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_72914c7a9c604f0896cfcf99ce655fe9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20900.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20400.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_72914c7a9c604f0896cfcf99ce655fe9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %%
map = folium.Map(location=[63, 75], zoom_start=3, width=900, height=400, control_scale=True)

HeatMap(data=df[['latitude','longitude','count']].groupby(['latitude','longitude']).sum().reset_index().values.tolist(), radius=3, max_zoom=13).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b6adf6d62c4644cf802c85d9a0db20c3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20900.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20400.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//leaflet.github.io/Leaflet.heat/dist/leaflet-heat.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b6adf6d62c4644cf802c85d9a0db20c3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b6adf6d62c4644cf802c85d9a0db20c3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b6adf6d62c4644cf802c85d9a0db20c3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

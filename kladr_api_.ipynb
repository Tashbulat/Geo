# %%
# !pip install requests-cache folium
# !pip install git+https://github.com/python-visualization/branca.git@master
# Out:
# ...
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to c:\users\user\appdata\local\temp\pip-req-build-4c7ci9la
# ...
#   Created wheel for branca: filename=branca-0.4.1+3.g5887b9b-py3-none-any.whl size=24648 sha256=5fe63322c0e5c2984dd9db777e80106606519a5682437347885c49f015deb565
#   Stored in directory: C:\Users\User\AppData\Local\Temp\pip-ephem-wheel-cache-7sa_vqxl\wheels\85\a6\81\3e8d0268702f43fb673810ff4073542c67206538348984335b
# Successfully built branca
# ...
#   Attempting uninstall: branca
#     Found existing installation: branca 0.4.1
#     Uninstalling branca-0.4.1:
#       Successfully uninstalled branca-0.4.1
# ...
#   Running command git clone -q https://github.com/python-visualization/branca.git 'C:\Users\User\AppData\Local\Temp\pip-req-build-4c7ci9la'

# %%
# !conda install geopandas

# %%
import requests
import requests_cache

import pandas as pd
import numpy as np

import folium
from folium.plugins import MarkerCluster
from folium.plugins import HeatMap

#import geopandas as gpd

# %%
requests_cache.install_cache('api_cache', backend='sqlite', expire_after=900)

# %%
def kladr_to_address_api(kladr_id):   
  
    data = {
        "query": kladr_id
    }

    api_url = 'https://suggestions.dadata.ru/suggestions/api/4_1/rs/findById/fias'
    headers = {
        'content-type': 'application/json',
        'Authorization': 'Token 79abf89d58871ed1df79b83126f8f8c2362e51db'
    }
    response = requests.post(api_url, json=data, headers=headers)
    adress_json = response.json()
    adress_str = adress_json['suggestions'][0]['value']
    return adress_str

# %%
def address_to_geo_coord_api(address):
    r = requests.get(f'http://search.maps.sputnik.ru/search/addr?q={address}')
    response = r.json()
    coordinates = response['result']['address'][0]['features'][0]['geometry']['geometries'][0]['coordinates']
    coordinates = coordinates[::-1]
    return coordinates

# %%
kladr_list = [
    '0200000101500',
    2700000100000,
    5501900001100,
    5501900001100,
    2801800001600,
    2801800001600,
    2800000400000,
    2800000400000,
    3301000006100,
    3800000300000,
    5401700005600,
    5003200002100,
    5003200003000,
    5401800000600,
    5401800001000,
    3813300000700,
    3813300001000,
    5003200003100,
    5003200005100,
    5401800001200,
    5401900000200,
    5003200006500,
    5003200007300,
    3813300001100,
    3813300001200,
    5401900001500,
    5401900002800,
    3813300001500,
    3813300002000,
    5003200009200,
    5003200010000,
    5401900002900,
    5402000000400,
    3813300003300,
    3813300003600,
    5003200010400,
    5003200010700,
    5402000000500,
    5402000000800,
    3813300003700,
    3813300003800,
    3813300004500,
    4000000107200,
    5003200011900
]
df = pd.DataFrame({'kladr': kladr_list})
df
# Out:
#             kladr
# 0   0200000101500
# 1   2700000100000
# 2   5501900001100
# 3   5501900001100
# 4   2801800001600
# 5   2801800001600
# 6   2800000400000
# 7   2800000400000
# 8   3301000006100
# 9   3800000300000
# 10  5401700005600
# 11  5003200002100
# 12  5003200003000
# 13  5401800000600
# 14  5401800001000
# 15  3813300000700
# 16  3813300001000
# 17  5003200003100
# 18  5003200005100
# 19  5401800001200
# 20  5401900000200
# 21  5003200006500
# 22  5003200007300
# 23  3813300001100
# 24  3813300001200
# 25  5401900001500
# 26  5401900002800
# 27  3813300001500
# 28  3813300002000
# 29  5003200009200
# 30  5003200010000
# 31  5401900002900
# 32  5402000000400
# 33  3813300003300
# 34  3813300003600
# 35  5003200010400
# 36  5003200010700
# 37  5402000000500
# 38  5402000000800
# 39  3813300003700
# 40  3813300003800
# 41  3813300004500
# 42  4000000107200
# 43  5003200011900

# %%
addresses = []
coordinates = []
for kladr_id in kladr_list:
    address = kladr_to_address_api(kladr_id)
    addresses.append(address)
    coord = address_to_geo_coord_api(address)
    coordinates.append(coord)
    print(address, coord)
df['address'] = addresses
df['coordinates'] = coordinates
# Out:
# Респ Башкортостан, г Уфа, деревня Жилино [54.656384, 56.06246]
# Хабаровский край, г Хабаровск [48.481403, 135.07693]
# Омская обл, Одесский р-н, село Желанное [54.166344, 72.575775]
# Омская обл, Одесский р-н, село Желанное [54.166344, 72.575775]
# Амурская обл, Тамбовский р-н, село Муравьевка [49.837215, 127.73236]
# Амурская обл, Тамбовский р-н, село Муравьевка [49.837215, 127.73236]
# Амурская обл, г Зея [53.740356, 127.27162]
# Амурская обл, г Зея [53.740356, 127.27162]
# Владимирская обл, Меленковский р-н, деревня Левенда [55.31677, 41.793613]
# Иркутская обл, г Иркутск [52.289597, 104.28059]
# Новосибирская обл, Кыштовский р-н, деревня Ядкан [56.733883, 76.515045]
# Московская обл, г Серпухов, деревня Арнеево [54.915524, 37.41955]
# Московская обл, г Серпухов, деревня Борисово [55.35957, 38.047356]
# Новосибирская обл, Маслянинский р-н, село Большой Изырак [54.514095, 84.27022]
# Новосибирская обл, Маслянинский р-н, село Дубровка [54.46441, 84.721375]
# ...

# %%
df['Rand'] = np.random.randint(0,2,size=(len(df), 1))

# %%
df['Color'] = 'green'
df['Color'].loc[df['Rand']==1] = 'red'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['count']  = 1

# %%
df['latitude'],df['longitude']=zip(*df['coordinates'])

# %%
df
# Out:
#             kladr                                            address  \
# 0   0200000101500           Респ Башкортостан, г Уфа, деревня Жилино
# 1   2700000100000                      Хабаровский край, г Хабаровск
# 2   5501900001100            Омская обл, Одесский р-н, село Желанное
# 3   5501900001100            Омская обл, Одесский р-н, село Желанное
# 4   2801800001600      Амурская обл, Тамбовский р-н, село Муравьевка
# 5   2801800001600      Амурская обл, Тамбовский р-н, село Муравьевка
# 6   2800000400000                                Амурская обл, г Зея
# 7   2800000400000                                Амурская обл, г Зея
# 8   3301000006100  Владимирская обл, Меленковский р-н, деревня Ле...
# 9   3800000300000                           Иркутская обл, г Иркутск
# 10  5401700005600   Новосибирская обл, Кыштовский р-н, деревня Ядкан
# 11  5003200002100        Московская обл, г Серпухов, деревня Арнеево
# 12  5003200003000       Московская обл, г Серпухов, деревня Борисово
# ...

# %%
map_1 = folium.Map(location=[63, 75], zoom_start=3, width=900, height=400, control_scale=True)

for index, row in df.iterrows():
    folium.Marker(row['coordinates'], popup=row['address'], tooltip='click', icon=folium.Icon(color=row['Color'])).add_to(map_1)

map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
map_1.save("map_1.htm")

# %%
map_2 = folium.Map(location=[63, 75], zoom_start=3, width=900, height=400, control_scale=True)

for index, row in df.iterrows():
    folium.CircleMarker(location=row['coordinates'], radius = 3, popup=row['address'], fill_color=row['Color'], color=None, fill_opacity = 0.5).add_to(map_2)

map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
map_2.save("map_2.htm")

# %%
map = folium.Map(location=[63, 75], zoom_start=3, width=900, height=400, control_scale=True)

marker_cluster = MarkerCluster().add_to(map)

for index, row in df.iterrows():
    folium.CircleMarker(location=row['coordinates'], radius = 3, popup=row['address'], fill_color=row['Color'], color=None, fill_opacity = 0.5).add_to(marker_cluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
map = folium.Map(location=[63, 75], zoom_start=3, width=900, height=400, control_scale=True)

HeatMap(data=df[['latitude','longitude','count']].groupby(['latitude','longitude']).sum().reset_index().values.tolist(), radius=3, max_zoom=13).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...
